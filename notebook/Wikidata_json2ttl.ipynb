# %%
# %%capture 
# !pip install wikidataintegrator
from rdflib import Graph, URIRef, Literal, Namespace, BNode
from rdflib.namespace import RDF, RDFS, SKOS, XSD, OWL, PROV
from wikidataintegrator import wdi_core, wdi_config
import uuid
import urllib.parse

# %%
uriformat = dict()
query = """
   SELECT DISTINCT ?prop ?format WHERE {
   # ?prop wdt:P1921 ?format .
}
"""
df = wdi_core.WDFunctionsEngine.execute_sparql_query(query, as_dataframe=True)
for index, row in df.iterrows():
    if row["prop"].replace("http://www.wikidata.org/entity/", "") not in uriformat.keys():
        uriformat[row["prop"].replace("http://www.wikidata.org/entity/", "")] = []
    uriformat[row["prop"].replace("http://www.wikidata.org/entity/", "")].append(row["format"])

# %%
uriformat
# Out:
# {'Q43649390': ['http://www.wikidata.org/entity/$1'],
#  'Q2013': ['http://www.wikidata.org/entity/$1'],
#  'P220': ['http://lexvo.org/id/iso639-3/$1'],
#  'P665': ['https://www.kegg.jp/entry/$1'],
#  'P950': ['http://datos.bne.es/resource/$1'],
#  'P981': ['http://bag.basisregistraties.overheid.nl/bag/id/woonplaats/$1'],
#  'P957': ['urn:ISBN:$1'],
#  'P1006': ['http://data.bibliotheken.nl/id/thes/p$1'],
#  'P1025': ['http://www.sudoc.fr/$1/id'],
#  'P212': ['urn:ISBN:$1'],
#  'P1422': ['http://ta.sandrart.net/-person-$1'],
#  'P1566': ['http://sws.geonames.org/$1/'],
#  'P2410': ['http://identifiers.org/wikipathways/$1'],
#  'P2950': ['http://nomisma.org/id/$1'],
#  'P3153': ['https://doi.org/10.13039/$1'],
#  'P3224': ['https://bartoc-skosmos.unibas.ch/naics/en/page/$1'],
#  'P3916': ['http://vocabularies.unesco.org/thesaurus/$1'],
#  'P4104': ['https://data.carnegiehall.org/names/$1/about'],
#  'P5587': ['https://libris.kb.se/$1'],
#  'P5739': ['http://catalogo.pusc.it/auth/$1'],
#  'P5813': ['http://musicbrainz.org/release/$1'],
#  'P6140': ['http://www.wordnet.dk/owl/instance/2009/03/instances/word-$1'],
#  'P6423': ['http://musicbrainz.org/event/$1'],
#  'P6854': ['http://scigraph.springernature.com/grant.$1'],
#  'P8393': ['http://qudt.org/vocab/quantitykind/$1'],
#  'P8408': ['http://kbpedia.org/kko/rc/$1'],
#  'P8540': ['http://id.loc.gov/vocabulary/ethnographicTerms/$1'],
#  'P486': ['http://id.nlm.nih.gov/mesh/$1'],
#  'P672': ['http://id.nlm.nih.gov/mesh/$1'],
#  'P6680': ['http://id.nlm.nih.gov/mesh/$1'],
#  'P6694': ['http://id.nlm.nih.gov/mesh/$1'],
#  'P269': ['http://www.idref.fr/$1/id'],
#  'P244': ['https://id.loc.gov/authorities/names/$1',
#   'https://id.loc.gov/authorities/subjects/$1'],
#  'P508': ['http://purl.org/bncf/tid/$1'],
#  'P592': ['http://rdf.ebi.ac.uk/resource/chembl/molecule/$1'],
#  'P650': ['https://data.rkd.nl/artists/$1'],
#  'P683': ['http://purl.obolibrary.org/obo/CHEBI_$1'],
#  'P982': ['http://musicbrainz.org/area/$1'],
#  'P1015': ['https://livedata.bibsys.no/authority/$1'],
#  'P1407': ['http://musicbrainz.org/series/$1'],
#  'P2732': ['http://data.persee.fr/person/$1'],
#  'P3133': ['http://nektar.oszk.hu/data/auth/$1'],
#  'P4404': ['http://musicbrainz.org/recording/$1'],
#  'P4963': ['https://skbl.se/en/artikel/$1.json'],
#  'P5063': ['http://globalwordnet.org/ili/$1'],
#  'P5097': ['http://data.logainm.ie/place/$1'],
#  'P5208': ['http://bag.basisregistraties.overheid.nl/bag/id/pand/$1'],
#  'P5229': ['http://data.carnegiehall.org/works/$1'],
#  'P5437': ['http://eurovoc.europa.eu/$1'],
#  'P6821': ['http://www.alvin-portal.org/alvin/view.jsf?pid=$1'],
#  'P850': ['urn:lsid:marinespecies.org:taxname:$1'],
#  'P8172': ['https://www.sejm-wielki.pl/b/$1'],
#  'P8519': ['https://data.rkd.nl/thesau/$1'],
#  'P245': ['http://vocab.getty.edu/ulan/$1'],
#  'P594': ['http://rdf.ebi.ac.uk/resource/ensembl/$1'],
#  'P704': ['http://rdf.ebi.ac.uk/resource/ensembl/$1'],
#  'P638': ['https://rdf.wwpdb.org/pdb/$1'],
#  'P827': ['https://www.bbc.co.uk/programmes/$1#programme'],
#  'P1260': ['http://kulturarvsdata.se/$1'],
#  'P1278': ['https://lei.info/$1'],
#  'P1292': ['https://d-nb.info/$1'],
#  'P1341': ['http://dati.camera.it/ocd/persona.rdf/p$1'],
#  'P1667': ['http://vocab.getty.edu/tgn/$1'],
#  'P1936': ['https://imperium.ahlfeldt.se/places/$1'],
#  'P2153': ['http://rdf.ncbi.nlm.nih.gov/pubchem/substance/SID$1'],
#  'P2581': ['http://babelnet.org/rdf/s$1'],
#  'P646': ['http://g.co/kg$1'],
#  'P2671': ['http://g.co/kg$1'],
#  'P2968': ['http://qudt.org/vocab/unit/$1'],
#  'P3120': ['http://data.ordnancesurvey.co.uk/id/$1'],
#  'P3217': ['https://sok.riksarkivet.se/sbl/Presentation.aspx?id=$1'],
#  'P4285': ['http://www.theses.fr/$1/id'],
#  'P5005': ['http://www.theses.fr/$1/id'],
#  'P4380': ['http://ta.sandrart.net/-artwork-$1'],
#  'P4616': ['http://purl.uniprot.org/journals/$1'],
#  'P5266': ['http://urn.fi/URN:NBN:fi:au:cn:$1'],
#  'P5331': ['http://worldcat.org/entity/work/id/$1'],
#  'P6366': ['http://ma-graph.org/entity/$1'],
#  'P7033': ['http://vocabulary.curriculum.edu.au/$1.rdf'],
#  'P8574': ['https://arcade.nyarc.org/record=$1'],
#  'P8980': ['https://urn.fi/URN:NBN:fi:au:finaf:$1'],
#  'P402': ['https://www.openstreetmap.org/relation/$1'],
#  'P268': ['http://data.bnf.fr/ark:/12148/cb$1#about'],
#  'P349': ['http://id.ndl.go.jp/auth/ndlna/$1'],
#  'P352': ['http://purl.uniprot.org/uniprot/$1'],
#  'P637': ['http://purl.uniprot.org/refseq/$1'],
#  'P1149': ['http://id.loc.gov/authorities/classification/$1'],
#  'P1150': ['http://rvk.uni-regensburg.de/nt/$1'],
#  'P1330': ['http://musicbrainz.org/instrument/$1'],
#  'P1741': ['http://data.beeldengeluid.nl/gtaa/$1'],
#  'P2034': ['http://www.gutenberg.org/ebooks/$1'],
#  'P2347': ['http://www.yso.fi/onto/yso/p$1'],
#  'P2409': ['https://ci.nii.ac.jp/naid/$1#article'],
#  'P2456': ['https://dblp.org/pid/$1.rdf'],
#  'P2799': ['http://data.cervantesvirtual.com/person/$1'],
#  'P2948': ['https://register.muinas.ee/rest/v1/monuments/$1'],
#  'P3186': ['http://taxref.mnhn.fr/lod/taxon/$1/13.0'],
#  'P4762': ['http://eunis.eea.europa.eu/sites/$1'],
#  'P7963': ['http://purl.obolibrary.org/obo/$1'],
#  'P9409': ['https://libcat.aub.edu.lb/record=$1'],
#  'P1992': ['http://treatment.plazi.org/id/$1.rdf'],
#  'P1687': ['https://www.wikidata.org/entity/$1'],
#  'P1187': ['http://purl.dila.edu.tw/resource/$1'],
#  'P2477': ['http://purl.bdrc.io/resource/$1'],
#  'P4276': ['https://data.cinematheque.qc.ca/data/Work$1'],
#  'P8971': ['http://data.cinematheque.qc.ca/data/Person$1'],
#  'P4138': ['https://api.treasuryoflives.org/resource/TOLP$1'],
#  'P4525': ['http://opendata.muis.ee/object/$1'],
#  'P5037': ['http://lsid.tdwg.org/$1'],
#  'P5504': ['http://data.rism.info/id/rismid/$1'],
#  'P5748': ['http://uri.gbv.de/terminology/bk/$1'],
#  'P6721': ['http://uri.gbv.de/document/opac-de-627:ppn:$1'],
#  'P8661': ['https://dolnoserbski.de/mjenja/pokaz/$1/'],
#  'P5417': ['http://cpv.data.ac.uk/turtle/code-$1.ttl'],
#  'P8984': ['http://cpv.data.ac.uk/turtle/code-$1.ttl'],
#  'P214': ['http://viaf.org/viaf/$1'],
#  'P227': ['https://d-nb.info/gnd/$1'],
#  'P350': ['https://data.rkd.nl/images/$1'],
#  'P351': ['http://purl.uniprot.org/geneid/$1'],
#  'P356': ['http://dx.doi.org/$1'],
#  'P434': ['http://musicbrainz.org/artist/$1'],
#  'P436': ['http://musicbrainz.org/release-group/$1'],
#  'P661': ['http://rdf.chemspider.com/$1'],
#  'P662': ['http://rdf.ncbi.nlm.nih.gov/pubchem/compound/CID$1'],
#  'P1004': ['http://musicbrainz.org/place/$1'],
#  'P1394': ['http://glottolog.org/resource/languoid/id/$1'],
#  'P1938': ['http://www.gutenberg.org/ebooks/author/$1'],
#  'P3328': ['http://www.wurvoc.org/vocabularies/om-1.8/$1'],
#  'P4466': ['http://astrothesaurus.org/uat/$1'],
#  'P4953': ['http://id.loc.gov/authorities/genreForms/$1'],
#  'P5207': ['http://bag.basisregistraties.overheid.nl/bag/id/openbare-ruimte/$1'],
#  'P6307': ['http://wikibase-registry.wmflabs.org/entity/$1'],
#  'P6702': ['http://data.library.sh.cn/entity/person/$1'],
#  'P7704': ['http://data.europeana.eu/$1'],
#  'P8769': ['http://www.ontology-of-units-of-measure.org/resource/om-2/$1'],
#  'P8978': ['https://dblp.org/rec/$1.rdf'],
#  'P218': ['http://id.loc.gov/vocabulary/iso639-1/$1.rdf'],
#  'P243': ['http://www.worldcat.org/oclc/$1'],
#  'P906': ['http://libris.kb.se/resource/auth/$1'],
#  'P920': ['http://id.sgcb.mcu.es/Autoridades/$1/concept'],
#  'P966': ['http://musicbrainz.org/label/$1'],
#  'P1256': ['http://iconclass.org/$1'],
#  'P1329': ['tel:$1'],
#  'P2900': ['tel:$1'],
#  'P1795': ['http://edan.si.edu/saam/id/person-institution/$1'],
#  'P2452': ['http://www.geonames.org/ontology#$1'],
#  'P3234': ['http://id.loc.gov/vocabulary/organizations/$1'],
#  'P3348': ['http://data.nlg.gr/resource/authority/record$1'],
#  'P3817': ['https://www.sotasampo.fi/en/persons/person_$1'],
#  'P4455': ['http://numismatics.org/crro/id/rrc-$1'],
#  'P5034': ['http://lod.nl.go.kr/resource/$1'],
#  'P5176': ['http://km.aifb.kit.edu/projects/numbers/n$1'],
#  'P6177': ['http://eunis.eea.europa.eu/species/$1'],
#  'P6698': ['https://jpsearch.go.jp/entity/chname/$1'],
#  'P8424': ['https://www.openhistoricalmap.org/relation/$1'],
#  'P236': ['urn:ISSN:$1'],
#  'P435': ['http://musicbrainz.org/work/$1'],
#  'P496': ['https://orcid.org/$1'],
#  'P685': ['http://purl.uniprot.org/taxonomy/$1'],
#  'P961': ['http://ipni.org/urn:lsid:ipni.org:names:$1'],
#  'P1014': ['http://vocab.getty.edu/aat/$1'],
#  'P1042': ['http://ld.zdb-services.de/resource/$1'],
#  'P2733': ['http://data.persee.fr/collection/$1'],
#  'P3181': ['https://w3id.org/oc/corpus/br/$1'],
#  'P3212': ['urn:isan:$1'],
#  'P3347': ['https://permid.org/1-$1'],
#  'P3911': ['http://zbw.eu/stw/descriptor/$1'],
#  'P3976': ['http://data.cervantesvirtual.com/work/$1'],
#  'P5580': ['https://www.vegvesen.no/nvdb/api/v2/vegobjekt?id=$1'],
#  'P8024': ['https://api.nobelprize.org/2.0/laureate/$1'],
#  'P648': ['http://openlibrary.org/works/$1'],
#  'P1182': ['http://libris.kb.se/resource/bib/$1'],
#  'P1248': ['https://kulturnav.org/$1'],
#  'P1584': ['https://pleiades.stoa.org/places/$1'],
#  'P1617': ['http://www.bbc.co.uk/things/$1#id'],
#  'P2163': ['http://id.worldcat.org/fast/$1'],
#  'P2263': ['http://www.isocat.org/datcat/DC-$1'],
#  'P2689': ['http://bartoc.org/en/node/$1'],
#  'P3285': ['http://msc2010.org/resources/MSC/2010/$1'],
#  'P3832': ['http://thesaurus.europeanafashion.eu/thesaurus/$1'],
#  'P4889': ['http://opendata.muis.ee/person-group/$1'],
#  'P5227': ['http://data.carnegiehall.org/events/$1'],
#  'P5361': ['https://bnb.data.bl.uk/doc/person/$1'],
#  'P5429': ['http://cv.iptc.org/newscodes/$1'],
#  'P5656': ['http://www.muis.ee/rdf/collection/$1'],
#  'P5782': ['http://dati.beniculturali.it/mibact/luoghi/resource/CulturalInstituteOrSite/$1.rdf'],
#  'P5806': ['http://snomed.info/id/$1'],
#  'P6703': ['http://data.library.sh.cn/entity/place/$1']}

# %%
rdf_item = Graph()
ns = dict()
for prefix in wdi_config.prefix.keys():
    ns[prefix] = Namespace( wdi_config.prefix[prefix])
    rdf_item.namespace_manager.bind(prefix, ns[prefix])
ns['schema'] = Namespace('http://schema.org/') # can be removed since it will be in WDI version 0.8.21

# %%
qid = "Q35869"
#qid = "Q38"
item = wdi_core.WDItemEngine(wd_item_id=qid)
json_item = item.get_wd_json_representation()
rdf_item.add((ns["wd"][qid], RDF.type, ns["wikibase"].Item))

# %%
import requests
import json

json_item = json.loads(requests.get("http://www.wikidata.org/entity/"+qid+".json").text)["entities"][qid]

# %%
properties = dict()
linked_items = []

def owlPropertyTypes(owlType):
    rdf_item.add((ns["wd"][pid], RDF.type, owlType))
    rdf_item.add((ns["p"][pid], RDF.type, owlType))
    rdf_item.add((ns["wdtn"][pid], RDF.type, owlType))
    rdf_item.add((ns["wdt"][pid], RDF.type, owlType))
    rdf_item.add((ns["pq"][pid], RDF.type, owlType))
    rdf_item.add((ns["pqn"][pid], RDF.type, owlType))
    rdf_item.add((ns["pqv"][pid], RDF.type, owlType))
    rdf_item.add((ns["pr"][pid], RDF.type, owlType))
    rdf_item.add((ns["prn"][pid], RDF.type, owlType))
    rdf_item.add((ns["prv"][pid], RDF.type,owlType))
    rdf_item.add((ns["ps"][pid], RDF.type, owlType))
    rdf_item.add((ns["psn"][pid], RDF.type, owlType))
    rdf_item.add((ns["psv"][pid], RDF.type, owlType))

def propdefs(pid, item, datatype):
    ## Properties and their derivatives
    object_properties = ["wikibase-item", 'external-id', 'string', 'commonsMedia',  'time', 'edtf', 'globe-coordinate', 'url', 'quantity', 'wikibase-property', 'monolingualtext', 'math', 'tabular-data', 'form', 'lexeme', 'geo-shape', 'musical-notation', 'sense']
    data_properties = ['external-id', 'string', 'time', 'edtf', 'globe-coordinate', 'quantity', 'monolingualtext', 'math', 'geo-shape', 'form', 'lexeme', 'musical-notation', 'sense' ]
    print(pid)  
    # ObjectProperty
    if datatype in object_properties:
        owlPropertyTypes(OWL.ObjectProperty)
    # Data Properties
    if datatype in data_properties:
        owlPropertyTypes(OWL.DatatypeProperty)  
    rdf_item.add((ns["wd"][pid], RDF.type, ns["wikibase"].Property))
    rdf_item.add((ns["wd"][pid], ns["wikibase"].directClaim, ns["wdt"][pid]))
    rdf_item.add((ns["wd"][pid], ns["wikibase"].claim, ns["p"][pid]))
    rdf_item.add((ns["wd"][pid], ns["wikibase"].statementProperty, ns["ps"][pid]))
    rdf_item.add((ns["wd"][pid], ns["wikibase"].statementValue, ns["psv"][pid]))
    rdf_item.add((ns["wd"][pid], ns["wikibase"].qualifier, ns["pq"][pid]))
    rdf_item.add((ns["wd"][pid], ns["wikibase"].qualifierValue, ns["pqv"][pid]))
    rdf_item.add((ns["wd"][pid], ns["wikibase"].reference, ns["pr"][pid]))
    rdf_item.add((ns["wd"][pid], ns["wikibase"].referenceValue, ns["prv"][pid]))
    rdf_item.add((ns["wd"][pid], ns["wikibase"].novalue, ns["wdno"][pid]))
    rdf_item.add((ns["wd"][pid], ns["wikibase"].directClaimNormalized, ns["wdtn"][pid]))
    rdf_item.add((ns["wd"][pid], ns["wikibase"].qualifierValueNormalized, ns["pqn"][pid]))
    rdf_item.add((ns["wd"][pid], ns["wikibase"].referenceValueNormalized, ns["prn"][pid]))
    rdf_item.add((ns["wd"][pid], ns["wikibase"].statementValueNormalized, ns["psn"][pid]))
    rdf_item.add((ns["wd"][pid], ns["wikibase"].propertyType, URIRef(wdi_config.property_value_types[datatype])))
    rdf_item.add((ns["wdno"][pid], RDF.type, OWL.Class))
    owl_restriction = BNode()
    rdf_item.add((owl_restriction, RDF.type, OWL.Restriction))
    rdf_item.add((owl_restriction, OWL.onProperty, ns["wdt"][pid]))
    rdf_item.add((owl_restriction, OWL.someValuesFrom, OWL.Thing))    
    rdf_item.add((ns["wdno"][pid], OWL.complementOf, owl_restriction)) 
    
def parseSnak(statement):
    value = statement["datavalue"]["value"]
    if statement["datatype"] == "commonsMedia":
        return URIRef("http://commons.wikimedia.org/wiki/Special:FilePath/"+value.replace(" ", "_"))
    elif statement["datatype"] == "string": return Literal(value)   
    elif statement["datatype"] == "external-id": return Literal(value)
    elif statement["datatype"] == "wikibase-item": 
        if value["id"] not in linked_items:
            linked_items.append(value["id"])
        return ns["wd"][value["id"]]
    elif statement["datatype"] == "monolingualtext": return Literal(value["text"], value["language"])
    elif statement["datatype"] == "geo-shape": return URIRef("http://commons.wikimedia.org/data/main/"+value)
    elif statement["datatype"] == "globe-coordinate":
        latitude = value["latitude"]
        longitude = value["longitude"]
        # altitude = claim["mainsnak"]["datavalue"]["value"]["altitude"] # not used
        precision = value["precision"] # not used
        globe = value["globe"]   # not used
        return Literal("Point("+str(longitude)+","+str(latitude)+")", datatype=ns["geo"].wktLiteral)
    elif statement["datatype"] == "quantity":
        amount = value["amount"]
        unit =  value["unit"] 
        return Literal(value["amount"], datatype=XSD.decimal)
    elif statement["datatype"] == "time": 
        
        return Literal(value["time"].replace("+", "").replace("Z", "+00:00"), datatype=XSD.dateTime)
    
    elif statement["datatype"] == "url": return URIRef(value) 
    else: raise ValueError('unknown snak datatype ' + statement["datatype"])

for pid in json_item['claims'].keys():
    if pid not in properties.keys():
        properties[pid] = json_item['claims'][pid][0]["mainsnak"]["datatype"]
    ## Ststements 
    for claim in json_item['claims'][pid]: 
        statement_uri = ns["s"][claim["id"].replace("$","-")]
        #rank
        if claim["rank"] == "normal": 
            rdf_item.add((statement_uri, ns["wikibase"].rank, ns["wikibase"].NormalRank))
        if claim["rank"] == "preferred":
            rdf_item.add((statement_uri, ns["wikibase"].rank, ns["wikibase"].PreferredRank))
        if claim["rank"] == "deprecated":
            rdf_item.add((statement_uri, ns["wikibase"].rank, ns["wikibase"].DeprecatedRank))
        
        # values   
        for claim2 in json_item['claims'][pid]:
            if claim2["rank"] == "preferred":
                preferredSet = True
                break
        else:
            preferredSet = False
        
        ## first no value
        
        if claim["mainsnak"]["snaktype"] == "novalue":
            rdf_item.add((statement_uri, RDF.type, ns["wdno"][pid]))
        else: 
            objectValue = parseSnak(claim["mainsnak"])
            rdf_item.add((statement_uri, ns["ps"][pid], objectValue))
            if pid in uriformat.keys():
                for normProp in uriformat[pid]:
                    rdf_item.add((statement_uri, ns["psn"][pid], URIRef(normProp.replace("$1", objectValue))))
            if preferredSet:
                if claim["rank"] == "preferred":
                    rdf_item.add((ns["wd"][qid], ns["wdt"][pid], objectValue))
                    if pid in uriformat.keys():
                        rdf_item.add((ns["wd"][qid], ns["wdtn"][pid], URIRef(uriformat[pid].replace("$1", objectValue))))
            else:
                if claim["rank"] == "normal":
                    rdf_item.add((ns["wd"][qid], ns["wdt"][pid], objectValue))
                    if pid in uriformat.keys():
                        rdf_item.add((ns["wd"][qid], ns["wdtn"][pid], URIRef(uriformat[pid].replace("$1", objectValue))))
        
        rdf_item.add((ns["wd"][qid],ns["p"][pid], statement_uri))
        rdf_item.add((statement_uri,RDF.type, ns["wikibase"].Statement))
        if preferredSet:
            if claim["rank"] == "preferred":
                  rdf_item.add((statement_uri,RDF.type, ns["wikibase"].BestRank))
        else:
            if claim["rank"] == "normal":
                  rdf_item.add((statement_uri,RDF.type, ns["wikibase"].BestRank))
                    
        
        #qualifiers
        if "qualifiers" in claim.keys():
            for qualifier in claim["qualifiers"].keys():
                if qualifier not in properties.keys():
                    properties[qualifier] = claim["qualifiers"][qualifier][0]["datatype"]
                for qualifier_prop in claim["qualifiers"][qualifier]:
                    object = parseSnak(qualifier_prop)
                    rdf_item.add((statement_uri, ns["pq"][qualifier], object))
                
        #references
        if "references" in claim.keys():
            for reference in claim["references"]:
                reference_uri = ns["ref"][reference["hash"]]
                rdf_item.add((reference_uri, RDF.type, ns["wikibase"].Reference))
                rdf_item.add((statement_uri, PROV.wasDerivedFrom, reference_uri))

                for ref_prop in reference["snaks"].keys():
                    if ref_prop not in properties.keys():
                        properties[ref_prop] = reference["snaks"][ref_prop][0]["datatype"]
                    for ref_prop_statement in reference["snaks"][ref_prop]:
                        object = parseSnak(ref_prop_statement)
                        rdf_item.add((reference_uri, ns["pr"][ref_prop], object))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-c3616a259166> in <module>
#     121                     rdf_item.add((ns["wd"][qid], ns["wdt"][pid], objectValue))
#     122                     if pid in uriformat.keys():
# --> 123                         rdf_item.add((ns["wd"][qid], ns["wdtn"][pid], URIRef(uriformat[pid].replace("$1", objectValue))))
#     124
#     125         rdf_item.add((ns["wd"][qid],ns["p"][pid], statement_uri))
#
# AttributeError: 'list' object has no attribute 'replace'

# %%
# sitelinks
for sitelink in json_item['sitelinks'].keys():
    wiki = URIRef(json_item['sitelinks'][sitelink]["url"])
    #print(json_item['sitelinks'][sitelink]["url"])
    partof = URIRef(json_item['sitelinks'][sitelink]["url"].split("wiki/")[0])
    if "commons" in str(partof):
        group = str(partof).split(".")[0].replace("https://", "")
        print(group)
    else:
        group = str(partof).split(".")[1]
    rdf_item.add((partof, ns["wikibase"].wikiGroup, Literal(group)))
    if "quote" in sitelink:
        language = sitelink.replace("wikiquote", "")
    elif sitelink == "simplewiki":
        language = "en-simple"
    elif sitelink == "commonswiki":
        language = "en"
    elif sitelink == "zh_yuewiki":
        language = "yue"
    elif sitelink == "zh_min_nanwiki":
        language = "nan"
    elif sitelink == "nowiki":
        language = "nb"
    else:
        language = sitelink.replace("wiki", "")
    rdf_item.add((wiki, RDF.type, ns["schema"].Article))
    rdf_item.add((wiki, ns['schema'].about, ns["wd"][qid]))
    rdf_item.add((wiki, ns['schema'].isPartOf, URIRef(partof)))
    for badge in json_item['sitelinks'][sitelink]["badges"]:
        ns["wikibase"].badge
        rdf_item.add((wiki, ns["wikibase"].badge, ns["wd"][badge]))
    try:
        rdf_item.add((wiki, ns['schema'].name, Literal(json_item['sitelinks'][sitelink]["title"], language)))
        rdf_item.add((wiki, ns['schema'].inLanguage, Literal(language)))
    except:
        print(language)
# Out:
# commons

# %%
def transformLabels(qid, json_item):
    # Heading
    for language in json_item["labels"].keys():
        rdf_item.add((ns["wd"][qid], RDFS.label, Literal(json_item["labels"][language]["value"], language)))
        rdf_item.add((ns["wd"][qid], ns["schema"].name, Literal(json_item["labels"][language]["value"], language)))
        rdf_item.add((ns["wd"][qid], ns["skos"].prefLabel, Literal(json_item["labels"][language]["value"], language)))

    for language in json_item["descriptions"].keys():
        rdf_item.add((ns["wd"][qid], ns["schema"].description, Literal(json_item["descriptions"][language]["value"], language)))

    for language in json_item["aliases"].keys():
        for label in json_item["aliases"][language]:
            rdf_item.add((ns["wd"][qid], SKOS.altLabel, Literal(label["value"], language))) 
                          
transformLabels(qid, json_item)     
    
for pid in properties.keys():
    pid_item = wdi_core.WDItemEngine(wd_item_id=pid).get_wd_json_representation()
    transformLabels(pid, pid_item)
    propdefs(pid, pid_item, properties[pid])
# Out:
# 氣喘 zh
# 哮喘病 zh
# 气喘病 zh
# 支气管哮喘 zh
# astma pl
# dychawica oskrzelowa pl
# Qarqayuy qu
# Qharqa unquy qu
# Asthma qu
# Asma qu
# Qharqaykuy qu
# Asthma bronchiale qu
# Astma qu
# Qarqaykuy qu
# Astmatični napad bs
# ataque de asma es
# asmático es
# asmatico es
# asma bronquial es
# ஆஸ்த்துமா ta
# மூச்சுத்தடை நோய் ta
# ஈழைநோய் ta
# lelah ms
# penyakit asma ms
# Kopsuastma et
# Múchadh ga
# Barnastma sv
# Asthma nl
# asthma bronchiale nl
# asma brônquica pt
# Asma is
# Mengi su
# Ampeg su
# Bengék su
# Астма бронхиальная ru
# Бронхијална астма sr
# Астматични напад sr
# yelpik tr
# kronik obstrüktif astım tr
# ڕەبۆ ckb
# astmaatikko fi
# astmapotilas fi
# keuhkoastma fi
# астма uk
# Asthma si
# ඇදුම රෝගය si
# Asthma episode tl
# Hikain tl
# Asmatiko tl
# Asthma tl
# Hagok tl
# Asthma attack tl
# Nakapagpapahika tl
# Sumpong ng hika tl
# Nagpapahika tl
# Asthmatic tl
# Pampahika tl
# Hingal tl
# Asthma bronchiale tl
# Sigasig pam
# Asse wa
# Anti-asthmatique fr
# Crise d'asthme fr
# Asthmatiforme fr
# Antiasthmatique fr
# asthmatique fr
# גנחת הסימפונות he
# אסטמה he
# גנחת he
# קצרת he
# 기관지 천식 ko
# Astma lv
# crisi asmatica it
# asma bronchiale it
# استما ps
# Sesak nafas id
# Asthma id
# Bengek id
# Astma id
# Bronchiale Hyperreagibilität de
# Bronchialasthma de
# Asthmaanfall de
# Belastungsasthma de
# Asthma bronchiale de
# ആസ്മാ ml
# ആസ്ത്മ ml
# Asthma ml
# ആസ്തമ ml
# ആസ്ത്‌മ ml
# 喘息 ja
# ぜんそく ja
# アスピリン喘息 ja
# suyễn vi
# bệnh suyễn vi
# hen vi
# hen suyễn vi
# bệnh hen suyễn vi
# hệnh hen vi
# अस्तमा sa
# अस्थमा hi
# Záduch sk
# Բրոնխիալ աստմա hy
# Բրոնխային հեղձուկ hy
# exercise-induced asthma en
# chronic obstructive asthma en
# chronic obstructive asthma with status asthmaticus en
# chronic obstructive asthma with acute exacerbation en
# bronchial hyperreactivity en
# Exercise induced asthma en
# Asthma en
# asthma brionchiole en
# Astm bronşic ro
# Astm ro
# Astmă ro
# Astma ro
# โรคหืดหอบ th
# โรคหอบหืด th
# Asmàtic ca
# Asthma la
# Asma cy
# Naduha sl
# Asthma cs
# Asthma bronchiale cs
# रजनीश mr
# ఆస్తమా te
# ఉబ్బసం te
# Asthma ur
# ایزما ur
# تضیق النفس ur
# Bronchinė astma lt
# Astmasykdom nb
# Asthma nb
# Reversibel obstruktiv luftveissjukdom nb
# Astmatiker nb
# Reversibel obstruktiv luftveissykdom nb
# Asma nb
# Reversibel obstruktiv luftvegssjukdom nb
# Asthma bronchiale nb
# Astma nb
# задув mk
# ଶ୍ଵାସ,ଦମା or
# Asthma hu
# نسمة ar
# ربو ar
# أزمة ar
# 哮喘 zh-hant
# commonscat ca
# Commons gl
# categoría de Commons gl
# categoría Commons gl
# Commons categoría gl
# Commons ru
# commonscat ru
# Викисклад ru
# склад ru
# катэгорыя на Commons be
# катэгорыя на Команз be
# makmak tl
# Commons fr
# commonscat fr
# categorie Commons ro
# commonscat ro
# commonscat bs
# commonscat ast
# categoría en Commons ast
# kategorio en la Komunejo eo
# commonscat eo
# kategori på Commons nb
# comcat nb
# Wikimedia Commons nb
# CominCat cy
# commonscat sv
# commonscat en
# category Commons en
# 공용분류 ko
# 공용 분류 ko
# 커먼즈 분류 ko
# 위키미디어 커먼즈 분류 ko
# 위키미디어 공용 분류 문서 ko
# 위키미디어 커먼즈 분류 문서 ko
# 공용 분류 문서 ko
# 커먼즈 분류 문서 ko
# 위키미디어 공용의 분류 문서 ko
# 위키미디어 공용에서의 분류 ko
# 이 주제를 다룬 공용 분류 ko
# commons category el
# commonscat el
# Commonscat nl
# categorie op Commons nl
# afbeeldingencategorie op Commons nl
# Commons categorie nl
# cc nl
# Commonskat af
# Kategorie op Commons af
# Commonscat min
# c区分类 zh-hans
# commons it
# categoria di Commons it
# categoria su Wikimedia Commons it
# කොමන්ස් ප්‍රවර්ගය si
# commonscat de
# kategoria w Wikimedia Commons pl
# Commonscat cs
# kategorie ve Wikimedia Commons cs
# Commons kategorie cs
# Commonscat nds-nl
# commonscat ja
# commons pt
# categoria no Wikimedia Commons pt
# Kategorya ning Commons pam
# Bólkur á Commons fo
# Commonscat id
# categoría Commons es
# categoría de Commons es
# Commons es
# Commons categoría es
# commonscat fy
# commonscat en-gb
# Commonscat uk
# commonscat uk
# Вікісховище: категорія uk
# หมวดหมู่ในคอมมอนส์ th
# หมวดหมู่บนคอมมอนส์ th
# Commons kategoria eu
# Commons eu
# commonscat eu
# تصنيف كومونز ar
# Commons az
# commonscat az
# Vikianbar az
# categoria na Commons pt-br
# ߞߐߡߐ߲ ߦߌߟߡߊ nqo
# commonscat vec
# commonscat sh
# ڪامنز ڪيٽيگري sd
# ڪانمزڪيٽيگري sd
# P373
# Thesaurus della Biblioteca Nazionale Centrale di Firenze it
# Nuovo soggettario it
# soggettario BNCF it
# Thesaurus BNCF it
# identifiant du thésaurus de la BNCF fr
# identifiant Thesaurus BNCF fr
# identificador del tesauro de la BNCFC es
# tesauro BNCF es
# BNFC ja
# BNCF he
# קוד הספרייה הלאומית של איטליה he
# BNCF vi
# BNCF eo
# код BNCF uk
# BNCF uk
# BNCF ro
# идентификатор BNCF ru
# BNCF ru
# المكتبة المركزية الوطنية في فلورنسا ar
# BNCF nl
# tesauru BNCF ast
# BNCF идентификатор sr
# БНЦФ sr
# BNCF ba
# BNCF идентификаторы ba
# BNCF tr
# BNCF kimliği tr
# BNCF Tesarus kimliği tr
# BNCF-id nn
# ідэнтыфікатар тэзаўрусу BNCF be-tarask
# ідэнтыфікатар тэзаўрусу Нацыянальнай цэнтральнай бібліятэкі Флярэнцыі be-tarask
# BNCF ID br
# BNCF коды tt-cyrl
# BNCF коды tt
# ID BNCF ms
# P508
# tuyên bố trong vi
# declarado en es
# fuente de la afirmación es
# referido en es
# крыніца be
# сообщается в ru
# по мнению ru
# согласно ru
# заявлено в ru
# как было заявлено в ru
# по версии ru
# 声明于 zh
# 載於 zh
# 声称来源 zh
# 主張來源 zh
# steht in de
# belegt durch de
# zu finden bei de
# angeführt in de
# Quelle de
# behauptet in de
# angegeben in de
# Fundstelle de
# gefunden in de
# originating source en
# source of claim en
# in statement en
# 来源 zh-hans
# 载于 zh-hans
# מצוטט ב he
# מקור הטענה he
# מאושר ב he
# bron nl
# geregistreerd door nl
# المصدر ar
# المرجع ar
# جاء في ar
# source en-ca
# originating source en-ca
# stated by en-ca
# стверджується в uk
# за версією uk
# згідно з uk
# fonte de la afirmación ast
# 서술된 곳 ko
# 언급된 곳 ko
# 출전 ko
# 명시된 곳 ko
# 원전 ko
# 적혀있던 곳 ko
# 출처 ko
# 정보원 ko
# 다음에 서술되어 있음 ko
# 다음 문헌에 서술되어 있음 ko
# 声明于 zh-cn
# 载于 zh-cn
# 聲明於 zh-tw
# tercantum pada id
# sumber situs id
# source en-gb
# source of claim en-gb
# originating source en-gb
# 載於 zh-hant
# source originale fr
# indiqué dans fr
# exprimé dans fr
# écrit dans fr
# attesté dans fr
# étayé dans fr
# confirmé dans fr
# affirmé dans fr
# revendiqué dans fr
# proposé dans fr
# source fr
# source de la déclaration fr
# 載於 zh-hk
# 载于 zh-my
# 载于 zh-sg
# dichiarato da it
# autore dell'affermazione it
# fonte dell'affermazione it
# dichiarato in it
# riferimento it
# affermato in it
# origine ia
# fonte ia
# står i nb
# belagt i nb
# angitt i nb
# kilde for påstanden nb
# referanse for påstanden nb
# zdroj cs
# ritt ra nap
# ritt int nap
# chi l'ha ritt nap
# l'ha ritt nap
# ఇక్కడ ప్రస్తావించబడింది te
# ifade edildiği yer tr
# ifade eden kişi tr
# iddia eden kişi tr
# açıklandığı yer tr
# beyan edildiği yer tr
# beyan eden kişi tr
# açıklayan kişi tr
# iddianın kaynak yeri tr
# kaynak kişi tr
# kaynak yeri tr
# referans yeri tr
# referans kişisi tr
# cyhoeddwyd yn cy
# ffynhonnell cy
# llyfr cy
# ਸਰੋਤ pa
# ਸਟੇਟਮੈਂਟ pa
# sursa afirmației ro
# conform ro
# după ro
# fonte da información gl
# declarado en gl
# indicado en gl
# segundo a fonte gl
# sumber rujukan ms
# rujukan ms
# disebut dalam ms
# disentuh dalam ms
# didapati dalam ms
# ditemui dalam ms
# dijumpai dalam ms
# sumber dakwaan ms
# asal sumber ms
# asal rujukan ms
# rujukan dakwaan ms
# állítva itt hu
# സ്രോതസ് ml
# ഉറവിടം ml
# хабар дода шудааст tg
# steji w hsb
# žórło hsb
# declarà in vec
# diciarà in vec
# fonte de l'afermasion vec
# adierazpenaren kokalekua eu
# schdet in pfl
# beleet derch pfl
# zu finne bei pfl
# angefirt in pfl
# Quell pfl
# behaubtet in pfl
# angegewe in pfl
# Fundstell pfl
# zdroj sk
# källa sv
# referens sv
# står i sv
# P248
# MedlinePlus it
# MedlinePlus es
# MedlinePlus-identigilo eo
# MedlinePlus идентификатор sr
# A.D.A.M. Medical Encyclopedia ID en
# A.D.A.M. Tibbî Ansiklopedi kimliği tr
# MedlinePlus gl
# P604
# importado de pt
# importada de pt
# importada do projeto Wikimedia pt
# prenita el eo
# kopiita el eo
# depuis fr
# importé fr
# importé de fr
# importé depuis le projet Wikimédia fr
# Datenvorlage de
# Datenherkunft de
# Quelle de
# übernommen aus de
# importiert aus de
# importiert aus WM-Projekt de
# Import aus Wikimedia-Projekt de
# Import aus WM-Projekt de
# geimporteerd uit nl
# インポート元 ja
# importerat från sv
# importerades från Wikimediaprojekt sv
# 들여온 곳 ko
# 가져온 곳 ko
# 다음에서 들여온 서술임 ko
# ਪਰਮ ਮੁੰਡੇ pa
# source en-ca
# from en-ca
# imported from en-ca
# source en-gb
# from en-gb
# imported from en-gb
# ที่มา th
# ดึงข้อมูลจาก th
# 來自 zh
# 来源 zh
# 導入自 zh
# स्रोतातून mr
# kaynağı tr
# referansı tr
# preluată din ro
# sursă ro
# sursa ro
# din ro
# provine din ro
# proveniență ro
# উৎস থেকে bn
# যেখান থেকে আমদানিকৃত bn
# আমদানিকৃত bn
# увезено из sr
# ماخذ ur
# pochad podaćow hsb
# žórło hsb
# importowane z hsb
# imported from en
# imported from WM project en
# import from Wikimedia project en
# import from WM project en
# Wikimedia project en
# imported from Wikipedia project en
# Wikipedia project en
# importálva innen hu
# importado de es
# fonte es
# dari ms
# sumber ms
# diimport dari ms
# крыніца be-tarask
# з be-tarask
# узята з be-tarask
# взято из проекта Викимедиа ru
# взято из ru
# импорт из проекта Викимедиа ru
# من ar
# مصدر ar
# مستورد من ar
# імпортовано з uk
# importato da it
# progetto Wikimedia di importazione it
# progetto di importazione it
# převzato z cs
# převzato z projektu Wikimedia cs
# importováno z cs
# da: vec
# de: vec
# inportà da on projeto Wikimedia vec
# projeto de inportasion vec
# z pl
# źródło pl
# pobrano z pl
# zaimportowano z pl
# diimpor dari id
# dari id
# sumber id
# importado de pt-br
# importada do projeto Wikimedia pt-br
# importada de pt-br
# importado de gl
# fonte gl
# P143
# identificador DiseasesDB es
# DiseasesDB cs
# DiseasesDB it
# P557
# identificador eMedicine es
# 이메디슨 ko
# P673
# catégorie principale de l'élément fr
# категория ru
# maincat ru
# категория статьи ru
# основная категория статьи ru
# основная категория Викимедиа ru
# соответствующая категория ru
# соответствующая категория для элемента ru
# категория, соответствующая понятию ru
# категория понятия ru
# 中心カテゴリ ja
# 主カテゴリ ja
# カテゴリ ja
# Hauptkategorie des Themas de
# Wikimedia-Kategorie de
# Kategorie de
# ప్రధాన వర్గం te
# 분류 ko
# 주 분류 ko
# 주제의 주 분류 ko
# 주제를 다룬 주요 분류 ko
# 주제를 다루는 주요 분류 ko
# 주제로 다룬 분류 ko
# 다음 분류가 이 주제를 다룸 ko
# 이 주제에 관한 위키미디어 분류 ko
# 이 주제의 분류 문서 ko
# 위키미디어 분류 ko
# 이 주제에 관한 분류 ko
# 이것에 관한 분류 ko
# 이것을 다루는 분류 ko
# 이것과 관련된 것을 다루는 분류 ko
# 이것과 관련된 것을 다룬 분류 ko
# 이것을 주제로 다룬 분류 ko
# 다음이 이것을 다룬 분류임 ko
# 다음 분류가 이것을 다루는 분류임 ko
# 다음이 이것을 다루는 분류임 ko
# 이것을 주제로 다루는 분류 ko
# 이 주제와 관련된 것을 다루는 분류 ko
# 주제와 관련된 것을 다루는 분류 ko
# 이 주제와 연관된 것을 다루는 분류 ko
# 다음 분류에서 이 주제를 다룸 ko
# 이 주제를 다룬 위키미디어 분류 ko
# 위키미디어 분류 문서 ko
# 이 주제의 위키미디어 분류 ko
# 위키미디어에서의 분류 ko
# 이 주제를 다룬 분류 ko
# hlavním článkem cs
# kategorie tématu cs
# 主分類 zh
# 主分类 zh
# 話題的主分類 zh
# 用于此话题的分类 zh
# 用於此話題的分類 zh
# 主题分类 zh
# 主題分類 zh
# catigurìa principali scn
# kategori, huvudsaklig sv
# pagrindinė kategorija lt
# hovedkategori nb
# kategori nb
# emnets hovedkategori nb
# emnets kategori nb
# categoría principal ast
# kategoria e artikullit sq
# kategoria e temës sq
# kategoria kryesore sq
# categoria principal do assunto do item pt-br
# categoria principal do item pt-br
# kategória hu
# fő kategória hu
# κατηγορία el
# main category en
# category for this topic en
# subject category en
# has category en
# category en
# kategorio ĉefa de la temo eo
# ana kategori tr
# bu başlığın kategorisi tr
# konu kategorisi tr
# категория ba
# мәҡәлә категорияһы ba
# мәҡәләнең төп категорияһы ba
# pääluokka fi
# головна категорія uk
# категорія:головна uk
# відповідна категорія uk
# тема зібрана в категорії uk
# стаття є основною для такої категорії uk
# сторінка має відповідну центральну категорію uk
# центральна категорія uk
# 主分類 yue
# төркем tt
# баш төркем tt
# мәкалә төркеме tt
# төп төркем tt
# төшенчә төркеме tt
# төркем tt-cyrl
# баш төркем tt-cyrl
# мәкалә төркеме tt-cyrl
# төп төркем tt-cyrl
# төшенчә төркеме tt-cyrl
# törkem tt-latn
# baş törkem tt-latn
# mäqälä törkeme tt-latn
# töp törkem tt-latn
# töşençä törkeme tt-latn
# hovudkategori nn
# emnekategori nn
# 主分类 zh-hans
# 用于此话题的分类 zh-hans
# 主题分类 zh-hans
# 主分类 zh-cn
# 用于此话题的分类 zh-cn
# 主题分类 zh-cn
# 主分类 zh-sg
# 用于此话题的分类 zh-sg
# 主题分类 zh-sg
# 主分類 zh-hant
# 用於此話題的分類 zh-hant
# 主題分類 zh-hant
# 主分類 zh-hk
# 用於此話題的分類 zh-hk
# 主題分類 zh-hk
# 主分類 zh-mo
# 用於此話題的分類 zh-mo
# 主題分類 zh-mo
# 主分類 zh-tw
# 用於此話題的分類 zh-tw
# 主題分類 zh-tw
# categoria principală a articolului ro
# הערך הראשי בקטגוריה he
# קטגוריה לערך זה he
# glavna kategorija bs
# kategorija teme bs
# kategorija o temi bs
# prif gategori'r testun cy
# kategorija teme sl
# kategorija članka sl
# 主分類 zh-my
# 用於此話題的分類 zh-my
# 主題分類 zh-my
# categorie van onderwerp nl
# categoria eponima it
# cat eponima it
# التصنيف الرئيسي ar
# التصنيف لهذا الموضوع ar
# temata galvenā kategorija lv
# гурӯҳи асосӣ tg
# váldokategoriija se
# válduluokka smn
# vueiʹvvkategoria sms
# ߦߌߟߡߊ ߓߊߖߎߡߊ nqo
# ߝߐߡߊ ߦߟߌߡߊ nqo
# ߊ߬ ߦߌߟߡߊ nqo
# مُک زمرو sd
# асноўная катэгорыя be-tarask
# тэматычная катэгорыя be-tarask
# катэгорыя be-tarask
# катэгорыя артыкулу be-tarask
# катэгорыя be
# P910
# freebase fr
# Freebase-ID es
# identificador en Freebase es
# MID es
# Freebase it
# Freebase identifier en
# MID en
# Freebase en
# Freebase-identigilo eo
# Freebase ru
# идентификатор Freebase ru
# شناسه فری‌باز fa
# شناسۀ فیریباز fa
# شناسۀ ب.د. فری‌بیس fa
# ID Freebase scn
# ID de Freebase ast
# 프리베이스 ko
# 프리베이스 식별자 ko
# 프리베이스 ID ko
# Freebase lt
# Freebase ID lt
# ID Freebase id
# Freebase ID id
# معرف فريبيس ar
# ફ્રીબેઝ ઓળખ gu
# Freebase идентификатор sr
# Фрибејз идентификатор sr
# Freebase ID sr
# MID sr
# ফ্রিবেইস শনাক্তকারী bn
# MID de
# Freebase-ID de
# MID ms
# pengenal pasti Freebase ms
# pengecam Freebase ms
# Freebase tg
# Freebase tt-cyrl
# Freebase коды tt-cyrl
# Freebase tt-latn
# Freebase qodı tt-latn
# Freebase tt
# Freebase коды tt
# ایم آئی ڈی ur
# Freebase идентификаторы ba
# Freebase ba
# Freebase tanımlayıcı tr
# Freebase ID numarası tr
# Freebase kimliği tr
# Freebase ID kimliği tr
# ଫ୍ରିବେସ ପରିଚୟ or
# код у Freebase uk
# Freebase identifier si
# MID si
# Freebase ID si
# Freebase標識符 zh
# 自由基地標識符 zh
# Freebase identifier en-ca
# MID en-ca
# Freebase identifier en-gb
# MID en-gb
# Freebase pt
# Freebase ID pt
# Freebase ID br
# Freebase標識符 zh-hant
# 自由基地標識符 zh-hant
# 自由基地标识符 zh-hans
# Freebase pl
# ID Freebase pl
# Freebase ID pl
# Freebase ID cs
# Freebase ID ca
# Freebase ID gsw
# Freebase ID sv
# Freebase ID vec
# pangalan ng Freebase tl
# pangalan sa Freebase tl
# P646
# datum uveřejnění cs
# vydáno (datum) cs
# utgitt nb
# publisert nb
# publiseringsdato nb
# dato publisert nb
# dato utgitt nb
# først utgitt nb
# Erscheinungsdatum de
# erschienen am de
# Erscheinungsjahr de
# Jahr de
# Publikationsdatum de
# Datum der Veröffentlichung de
# erschien am de
# Erstveröffentlichung de
# Erstveröffentlichungsdatum de
# veröffentlicht am de
# Veröffentlichung am de
# Veröffentlichung im Jahr de
# veröffentlicht im Jahr de
# erschien im Jahr de
# erschienen im Jahr de
# VÖ-Datum de
# ngày xuất bản vi
# ngày phát hành vi
# ngày ra mắt vi
# ngày công chiếu vi
# năm xuất bản vi
# publicatiedatum nl
# uitgebracht nl
# uitgegeven nl
# gepubliceerd op nl
# datum van eerste publicatie nl
# δημοσίευση el
# 출판일 ko
# 출판 날짜 ko
# 발행일 ko
# 발행 연도 ko
# 출판 연도 ko
# 개봉 연도 ko
# 개봉 날짜 ko
# 개봉일 ko
# 발행한 날짜 ko
# 출판한 날짜 ko
# 개봉한 날짜 ko
# 발행한 날 ko
# 출판한 날 ko
# 개봉한 날 ko
# 출시일 ko
# 출시 날짜 ko
# 출시한 날 ko
# 출시한 날짜 ko
# 출시 연도 ko
# 발매 날짜 ko
# 발매일 ko
# 발매한 날 ko
# 발매 연도 ko
# 발행 날짜 ko
# 나온 날 ko
# 낸 날 ko
# 실린 날 ko
# 게재일 ko
# 게재된 날 ko
# 발표된 날 ko
# 발표일 ko
# pubblicato il it
# rilasciato il it
# distribuito il it
# dato alle stampe it
# data della release it
# released it
# anno di pubblicazione it
# anno di rilascio it
# anno di distribuzione it
# anno di stampa it
# data di promulgazione it
# data della pubblicazione it
# 发表于 zh
# 发表年份 zh
# 发表 zh
# 开画 zh
# 开画日期 zh
# 公映日期 zh
# 日期 zh
# 发行日期 zh
# 发行 zh
# 发表时间 zh
# 上映日期 zh
# 发表日期 zh
# 出版時間 zh
# 播出日期 zh
# 發佈時間 zh
# שנת הוצאה לאור he
# תאריך דפוס he
# שנת דפוס he
# תאריך הוצאה he
# הקרנת בכורה he
# תאריך פרסום he
# publié le fr
# sortie le fr
# date de sortie fr
# publication fr
# année fr
# première publication fr
# daté du fr
# date de parution fr
# paru le fr
# fecha de lanzamiento es
# publicado el es
# publicada el es
# પ્રકાશનની તારીખ gu
# ปีที่เผยแพร่ th
# เผยแพร่เมื่อ th
# ปีที่ออก th
# เผยแพร่ th
# วันที่เผยแพร่ th
# ออกอากาศครั้งแรก th
# eldondato eo
# išleidimo data lt
# premjeros data lt
# išleista lt
# дата издания ru
# дата премьеры ru
# дата релиза ru
# дата выпуска ru
# release date en-gb
# date published en-gb
# date released en-gb
# published en-gb
# year of publication en-gb
# initial release en-gb
# date of release en-gb
# released en-gb
# publication date en-gb
# pubdate en-gb
# data de lançamento pt-br
# lançado em pt-br
# publicado em pt-br
# lançamento pt-br
# data da publicação pt-br
# release date en-ca
# date published en-ca
# date released en-ca
# published en-ca
# date of release en-ca
# ପ୍ରକାଶନ ତାରିଖ or
# diterbitkan pada id
# tahun terbitan id
# tanggal publikasi id
# tanggal penerbitan id
# tahun terbit id
# విడుదల తేదీ te
# data d'asoleyamientu ast
# asoleyada ast
# publicada ast
# asoleyáu ast
# publicáu ast
# 発行日 ja
# リリース日 ja
# 発刊日 ja
# 刊行日 ja
# 公開日 ja
# 発表日 ja
# 公表日 ja
# 発売日 ja
# 販売日 ja
# 上映日 ja
# 公布日 ja
# санаи интишор tg
# таърихи нашр tg
# 發行日期 yue
# 上映日期 yue
# udgivet da
# publiceret da
# dato for udgivelsen da
# تاريخ الإصدار ar
# صدر في ar
# نشر في ar
# تم نشره في ar
# تم إصداره في ar
# تاريخ الاصدار ar
# تم اصداره في ar
# منشور في ar
# صادر في ar
# سنة النشر ar
# data e botimit sq
# data e lëshimit sq
# botimi sq
# publikimi sq
# viti i botimit sq
# viti sq
# viti i publikimit sq
# ọjọ́ àgbéjáde yo
# àgbéjáde yo
# àtẹ̀jáde yo
# data premiery pl
# data publikacji pl
# petsa ng publikasyon tl
# 發行日期 zh-tw
# yayınlandığı tarih tr
# serbest bırakıldığı tarih tr
# yayın yılı tr
# ilk sürümü tr
# yayınlanma zamanı tr
# yayın zamanı tr
# avaldamisaeg et
# публикацияләү датасы tt
# бастырылу датасы tt
# релиз датасы tt
# публикацияләү датасы tt-cyrl
# бастырылу датасы tt-cyrl
# релиз датасы tt-cyrl
# ਜਾਰੀ ਕਰਨ ਦੀ ਮਿਤੀ pa
# ਪਬਲਿਸ਼ ਕਰਨ ਦੀ ਮਿਤੀ pa
# датум објављивања sr
# објављен sr
# објављено sr
# година издавања sr
# година објављивања sr
# почетно издање sr
# датум изласка sr
# издат sr
# издато sr
# време издавања sr
# време објављивања sr
# публикација sr
# време публикације sr
# први пут издат sr
# први пут издато sr
# први пут објављен sr
# први пут објављено sr
# дата выпуску be-tarask
# дата выхаду be-tarask
# utgjeve nn
# publisert nn
# utgjevingsdato nn
# cyhoeddi cy
# Бат ачаар датасы ky
# Премьеры ky
# публікація (дата) uk
# час публікації uk
# реліз-дата uk
# опубліковано (дата) uk
# дата випуску uk
# рік публікації uk
# перша публікація uk
# tarikh keluaran ms
# terbitan ms
# keluaran ms
# tanggal penerbitan ms
# tanggal keluaran ms
# tarikh pengeluaran ms
# tanggal pengeluaran ms
# tahun terbitan ms
# tahun penerbitan ms
# hari bulan penerbitan ms
# tahun keluaran ms
# haribulan penerbitan ms
# hari bulan keluaran ms
# haribulan keluaran ms
# masa penerbitan ms
# waktu penerbitan ms
# diterbitkan pada ms
# dikeluarkan pada ms
# hb penerbitan ms
# hb keluaran ms
# hb terbitan ms
# ဖြန်ချီသည့် နေ့စွဲ my
# ဖြန့်ချီသည့် နှစ် my
# ထုတ်ဝေသည့် နှစ် my
# تاریخ اشاعت ur
# تاریخ نمائش ur
# publiceringsdatum sv
# premiär sv
# ߊ߬ ߟߊߥߊ߲߬ߞߊ߬ ߘߊ߫ nqo
# ߟߊ߬ߥߊ߲߬ߞߊ߬ߟߌ ߛߊ߲߭ nqo
# ߟߊ߬ߖߍ߲߬ߛߍ߲߬ߠߌ߲ ߕߎ߬ߡߊ߬ߘߊ nqo
# publegà vec
# publicà vec
# lansà vec
# 發行日期 zh-hant
# 開畫 zh-hant
# 開畫日期 zh-hant
# 公映日期 zh-hant
# 發表日期 zh-hant
# 上映日期 zh-hant
# 首播日期 zh-hant
# 播出日期 zh-hant
# 發佈時間 zh-hant
# 發行 zh-hant
# 發表 zh-hant
# first released en
# first published en
# air date en
# pubdate en
# date of first publication en
# first publication en
# airdate en
# release date en
# date published en
# date released en
# published en
# dop en
# year of publication en
# initial release en
# date of release en
# date of publication en
# released en
# time of publication en
# publication en
# publication time en
# launched en
# launch date en
# released in en
# was published in en
# be published in en
# be published during en
# was published during en
# بەرواری بڵاوکردنەوە ckb
# ڕێکەوتی دەرچوون ckb
# дата выдання be
# год выдання be
# ano de publicação pt
# data de lançamento pt
# data da primeira publicação pt
# publicado em pt
# lançado em pt
# estreado em pt
# data de estreia pt
# ano de estreia pt
# lançamento pt
# Première lb
# P577
# GND en
# GND identifier en
# Universal Authority File en
# Integrated Authority File en
# dbpedia:IndividualisedGnd en
# DNB authorities en
# GND-IDN en
# GND ID en
# Deutschen Nationalbibliothek ID en
# German National Library ID en
# GND fr
# gnd fr
# Integrated Authority File fr
# Gemeinsame Normdatei fr
# identifiant GND fr
# GND-IDN fr
# GND-Identifier de
# Gemeinsame Normdatei de
# GND-Nummer de
# GND-IDN de
# GND de
# Gemeinsame Normdatei nb
# DNB autoridades es
# Gemeinsame Normdatei mk
# GND mk
# Gemeinsame Normdatei nn
# GND pl
# Gemeinsame Normdatei pl
# GND ru
# Integrated Authority File ru
# Gemeinsame Normdatei ru
# ГНД ru
# Integrated Authority File be
# Gemeinsame Normdatei be
# GND sv
# Integrated Authority File sv
# Gemeinsame Normdatei sv
# GND-identifikator sv
# GND it
# Gemeinsame Normdatei it
# GND-tunnus fi
# Gemeinsame Normdatei hu
# 統合典拠ファイル ja
# GND de-at
# GND-Identifier de-at
# Gemeinsame Normdatei de-at
# GND de-ch
# GND-Identifier de-ch
# Gemeinsame Normdatei de-ch
# GND bar
# GND-Identifier bar
# GND-IDN bar
# identigi Gemeinsame Normdatei eo
# GND sk
# GND da
# GND la
# auctoritas GND la
# GND uk
# GND identifier uk
# Universal Authority File uk
# DNB authorities uk
# PND uk
# Gemeinsame Normdatei nl
# DNB-identificatiecode nl
# GND ca
# număr GND ro
# Integrated Authority File ro
# Fișier de Autoritate Integrat ro
# Identificator Gemeinsame Normdatei ro
# cod GND ro
# GND pt-br
# Integrated Authority File pt-br
# GND pt
# Gemeinsame Normdatei pt
# GND 식별자 ko
# 게마인자메 노름다타이 ID ko
# 통합 전거 파일(GND) ID ko
# 통합 전거 파일(GND) 식별자 ko
# 독일 통합 전거 파일 ID ko
# 독일 국립도서관 ID ko
# 독일 국가도서관 ID ko
# 독일 전거데이터 ID ko
# 독일 전거 데이터 ID ko
# GND идентификатор sr
# ГНД sr
# ГНД идентификатор sr
# Немачка национална библиотека sr
# معرف ملف استنادي متكامل (GND) ar
# pengenal pasti GND ms
# pengecam GND ms
# Fail Kewibawaan Semesta ms
# Fail Kewibawaan Bersepadu ms
# PND ms
# Integrated Authority File tg
# Gemeinsame Normdatei tg
# ГНД tg
# इंटिग्रेटेड अथॉरिटी फाईल mr
# जीएनडी mr
# जीएनडी ओळखण mr
# जीएनडी आयडी mr
# GND tanımlayıcısı tr
# GND tanımlayıcı tr
# Evrensel Yetki Dosyası tr
# dbpedia:IndividualisedGnd tr
# GND ఐడీ te
# GND標識符 zh
# 整合规范文档标识符 zh
# GND識別碼 zh
# GND zh
# 整合規範文檔標識符 zh
# GND識別碼 zh-tw
# GND zh-tw
# GND标识符 zh-cn
# GND zh-cn
# GND識別碼 zh-hant
# GND zh-hant
# GND冧把 yue
# 整合規範文檔冧把 yue
# GND yue
# 整合權威檔案冧把 yue
# GND标识符 zh-hans
# GND zh-hans
# identifikátor GND cs
# GND ID cs
# anaouder GND br
# GND標識符 zh-hk
# 整合規範文檔標識符 zh-hk
# GND識別碼 zh-hk
# GND zh-hk
# GND標識符 zh-mo
# GND識別碼 zh-mo
# GND zh-mo
# 整合規範文檔標識符 zh-mo
# GND标识符 zh-my
# GND zh-my
# GND标识符 zh-sg
# GND zh-sg
# GND коды tt-cyrl
# GND коды tt
# GND szl
# Gemeinsame Normdatei szl
# P227
# Library of Congress Name Authority File en
# Library of Congress Subject Headings en
# LCAuth identifier en
# SACO ID en
# NACO ID en
# LC/NACO/SACO Authority File ID en
# LoC identifier en
# Library of Congress Subject Headings ID en
# LCSH ID en
# LoC Authorities ID en
# LCAuth ID en
# LCNAF ID en
# LOC ID en
# LCCN en
# Authority LCCN en
# LC Subject Heading ID en
# LC Name Authority ID en
# LC Name Authority File ID en
# LC Control Number en
# LC Subject ID en
# LC Name ID en
# LCCN (Name Authority) en
# LCCN (Subject Authority) en
# Library of Congress Control Number (Authorities) en
# Library of Congress Control Number (Name Authority) en
# Library of Congress Control Number (Subject Authority) en
# LCCN (NACO) en
# LCCN (SACO) en
# LCCN (NAF) en
# LCCN (LCSH) en
# NAF LCCN en
# LCSH LCCN en
# NACO LCCN en
# LC/NACO LCCN en
# LC/NACO Authority File ID en
# LCSH Authority File ID en
# Library of Congress Control Number ru
# ЛЦЦН ru
# идентификатор ЛЦЦН ru
# LCSH ru
# код LCNAF ru
# код LCSH ru
# numéro de contrôle de la Bibliothèque du Congrès fr
# LCNAF fr
# lc fr
# identifiant LC fr
# LCSH fr
# http://id.loc.gov fr
# LoC fr
# LCCN sv
# LCNAF-ID sv
# LCSH-ID sv
# LCAuth fi
# LCAuth ID fi
# LCNAF fi
# LCNAF-tunniste fi
# Library of Congress Name Authority File fi
# NACO ID fi
# số kiểm soát của Thư viện Quốc hội Mĩ vi
# định danh LCNAF vi
# Library of Congress Control Number it
# LCCN it
# Library of Congress Name Authority File it
# 米国議会図書館管理番号 ja
# LCコントロール番号 ja
# LC番号 ja
# LCCN ja
# LCNAF識別子 ja
# LCCN識別子 ja
# LCSH識別子 ja
# LCCN pt
# Library of Congress Control Number pt
# LCCN zh
# 美国国会图书馆标识符 zh
# 國會圖書館識別碼 zh
# 美國國會圖書館識別碼 zh
# LOC ID zh
# 国会图书馆标识符 zh
# LCNAF ID zh
# 国会图书馆规范标识符 zh
# 美国国会图书馆规范标识符 zh
# شناسهٔ کتابخانهٔ کنگره fa
# LCCN be
# Library of Congress Control Number be
# ідэнтыфікатар LCNAF be
# ідэнтыфікатар LCSH be
# autoridades LoC es
# Biblioteca del Congreso de EE. UU. es
# identificador autoridades de la Biblioteca del Congreso de EE. UU. es
# identificador autoridades Biblioteca del Congreso de EE. UU. es
# lccn tr
# Library of Congress Control Number tr
# Kongre Kütüphanesi yetki kimliği tr
# Library of Congress Name Authority File de
# Library of Congress Authorities de
# LCNAF de
# Library of Congress Subject Headings de
# LoC-Normdaten de
# LCAuth de
# LCSH-Normdaten de
# LCCN de
# Library of Congress Control Number pt-br
# Library of Congress Name Authority File pt-br
# LCNAF pt-br
# LCCN pt-br
# LCCN eo
# Library of Congress Name Authority File eo
# LCCN ca
# identificador LCNAF ca
# identificador LCSH ca
# Library of Congress Name Authority File cs
# LCNAF cs
# LCAuth cs
# LCSH cs
# Library of Congress Subject Headings cs
# identifikátor LCCN cs
# identifikátor LCNAF cs
# identifikátor LCSH cs
# Library of Congress Name Authority File de-at
# LCNAF de-at
# Library of Congress Subject Headings de-at
# LCSH de-at
# Library of Congress Name Authority File et
# LCNAF et
# LCSH et
# Library of Congress Subject Headings et
# Library of Congress Name Authority File sco
# LCNAF identifier sco
# Library of Congress Subject Headings sco
# LCSH identifier sco
# Library of Congress Name Authority File sl
# LCNAF sl
# LCSH sl
# Library of Congress Subject Headings sl
# Library of Congress Name Authority File jam
# LCNAF jam
# Library of Congress Subject Headings jam
# LCSH jam
# Library of Congress Name Authority File ka
# LCNAF  იდენტიფიკატორი ka
# LCSH  იდენტიფიკატორი ka
# Library of Congress Subject Headings ka
# Library of Congress Name Authority File hr
# LCNAF hr
# LCSH hr
# Library of Congress Subject Headings hr
# Library of Congress Name Authority File is
# LCNAF is
# Library of Congress Subject Headings is
# LCSH is
# LCNAF ID pl
# identyfikator LCNAF pl
# Library of Congress Name Authority File ID pl
# identyfikator LCSH pl
# Library of Congress Subject Headings ID pl
# LCCN-identificatiecode nl
# Library of Congress Name Authority File-identificatiecode nl
# LCNAF-identificatiecode nl
# LCSH-identificatiecode nl
# Library of Congress Subject Headings-identificatiecode nl
# LCNAF ar
# LCCN-szerzőazonosító hu
# 미국 의회도서관 식별자 ko
# 미 의회도서관 식별자 ko
# 미국 의회도서관 ID ko
# 미 의회도서관 ID ko
# LCCN 식별자 ko
# LCNAF 식별자 ko
# LCAuth 식별자 ko
# 미국 의회도서관 제어 번호 ko
# 미 의회도서관 제어 번호 ko
# LCCN идентификатор sr
# ЛЦЦН sr
# контролни број Конгресне библиотеке sr
# LCCN nb
# LCAuth nb
# Library of Congress Name Authority File nb
# LCnames nb
# LCNAF nb
# Library of Congress autoritetsidentifikator nb
# LCSH nb
# Library of Congress Subject Headings nb
# LCCN nn
# Library of Congress Name Authority File nn
# Library of Congress Control Number en-gb
# LCCN ପରିଚୟ or
# ଲାଇବ୍ରେରୀ ଅଫ କଂଗ୍ରେସ ଅଭିଜ୍ଞାପକ or
# LCCN tg
# Library of Congress Control Number tg
# ЛССН tg
# идентификатори ЛССН tg
# लायब्ररी ऑफ काँग्रेस कंट्रोल नंबर mr
# एलसीसीएन mr
# एलसीसीएन ओळखण mr
# एलसीसीएन आयडी mr
# cod LCCN ro
# număr LCCN ro
# LCCN ro
# LCNAF ast
# LCAuth ast
# identificador LCCN ast
# Library of Congress lb
# Library of Congress Name Authority File lb
# ID LCCN ms
# pengenal pasti LCCN ms
# pengecam LCCN ms
# Nombor kawalan Perpustakaan Kongres ms
# Kewibawaan LoC ms
# LCAuth ms
# ID SACO ms
# ID NACO ms
# Rexistro de Autoridade LoC gl
# Library of Congress Name Authority File ID af
# LCNAF ID af
# LCSH af
# Library of Congress Subject Heading ID af
# Library of Congress Name Authority File коды ba
# LCNAF коды ba
# LCSH коды ba
# Library of Congress Subject Headings коды ba
# Library of Congress Name Authority File identifikator bs
# LCNAF bs
# Library of Congress Subject Headings identifikator bs
# Library of Congress Name Authority File da
# Library of Congress Name Authority File eu
# Library of Congress Name Authority File gsw
# Library of Congress Name Authority File hsb
# Library of Congress Subject Headings hsb
# Library of Congress Name Authority File ksh
# Library of Congress Name Authority File lmo
# Library of Congress Name Authority File lv
# Library of Congress Name Authority File mg
# Library of Congress Name Authority File min
# Library of Congress Name Authority File mk
# Library of Congress Name Authority File nds
# Library of Congress Name Authority File nds-nl
# Library of Congress Name Authority File pcd
# Library of Congress Name Authority File rm
# Library of Congress Name Authority File sk
# Library of Congress Name Authority File sr-el
# Library of Congress Name Authority File stq
# Library of Congress Name Authority File th
# 美国国会图书馆标识符 zh-cn
# LCCN zh-cn
# 国会图书馆标识符 zh-cn
# LOC ID zh-cn
# 美国国会图书馆规范标识符 zh-cn
# LCCN zh-tw
# 美國國會圖書館識別碼 zh-tw
# 美國國會圖書館權威識別碼 zh-tw
# anaouder Library of Congress br
# LCNAF коды tt
# LCNAF коды tt-cyrl
# LCCN zh-hant
# LOC ID zh-hant
# LCNAF ID zh-hant
# 美國國會圖書館權威識別碼 zh-hant
# 美國國會圖書館規範標識符 zh-hant
# 國會圖書館規範標識符 zh-hant
# 美国国会图书馆标识符 zh-hans
# 国会图书馆标识符 zh-hans
# LOC ID zh-hans
# LCCN zh-hans
# LCNAF ID zh-hans
# 美国国会图书馆规范标识符 zh-hans
# 美國國會圖書館規範控制標識符 zh-hk
# 國會圖書館規範控制標識符 zh-hk
# LOC ID zh-hk
# 美國國會圖書館權威識別碼 zh-hk
# 美國國會圖書館規範控制標識符 zh-mo
# 國會圖書館規範控制標識符 zh-mo
# LOC ID zh-mo
# 美國國會圖書館權威識別碼 zh-mo
# 国会图书馆标识符 zh-my
# 美国国会图书馆标识符 zh-my
# 美国国会图书馆规范标识符 zh-my
# 国会图书馆标识符 zh-sg
# 美国国会图书馆标识符 zh-sg
# 美国国会图书馆规范标识符 zh-sg
# ідэнтыфікатар LCNAF be-tarask
# ідэнтыфікатар LCSH be-tarask
# LCNAF ID en-ca
# LCSH ID en-ca
# Library of Congress authority ID en-ca
# LCCN frr
# idyntyfikatōr LCNAF szl
# idyntyfikatōr LCSH szl
# P244
# Patient UK es
# identificador Patientplus ID es
# Patient UK en
# Patient UK fr
# identifikátor Patientplus cs
# Patientplus identifikátor cs
# Patientplus it
# Patient UK it
# Patientplus cy
# Patient UK cy
# Patientplus-tunniste fi
# Patientplus идентификатор sr
# مرض في مريض المملكة المتحدة ar
# معرف مريض المملكة المتحدة ar
# P1461
# URL ko
# 출처 ko
# 출처 주소 ko
# 출처 URL ko
# 참고한 웹사이트 ko
# 참고한 곳 ko
# 참고한 주소 ko
# 참고 URL ko
# 참고한 사이트 ko
# 서술할 때 참고한 URL ko
# 서술에 참고한 사이트 ko
# 서술에 참고한 URL ko
# 다음 주소에서 참고함 ko
# 참고용 URL ko
# 다음 URL에서 참고함 ko
# lien web fr
# hyperlien fr
# site web fr
# adresse internet fr
# URL de référence fr
# URL es
# referencia web es
# refweb es
# afirmado en la url es
# dirección web de referencia es
# afirmado en la página web es
# afirmado en el sitio web es
# localitzador uniforme de recursos ca
# pàgina web ca
# website nl
# bron websiteadres nl
# URL bronvermelding nl
# URL nb
# nettside nb
# kilde-URL nb
# kildenettside nb
# địa chỉ Web vi
# URL vi
# địa chỉ URL vi
# URL tham chiếu vi
# 网站 zh-hans
# 统一资源定位符 zh-hans
# URL zh-hans
# URL da referência pt
# site pt
# website pt
# veebiaadress et
# internetiaadress et
# ιστοσελίδα el
# url el
# zdroj cs
# zdroj jako URL adresa cs
# reference url cs
# ウェブページ ja
# ホームページ ja
# URL ja
# ссылка ru
# URL ru
# URL для справки ru
# ссылка на источник ru
# ссылка-URL на источник ru
# адрес веб-страницы ru
# источник (URL) ru
# url sv
# internetadresser sv
# webbplats sv
# webbsida sv
# Uniform Resource Locator sv
# webbref sv
# מקור באינטרנט he
# URL כמקור he
# מקור URL he
# посилання на джерело uk
# універсальний локатор ресурсів джерела uk
# адреса джерела в інтернеті uk
# інтернет-адреса джерела uk
# URL fi
# Հղում hy
# sitiu web ast
# referencia web ast
# ref ast
# url ast
# svetainė lt
# URL lt
# nuoroda lt
# internetni naslov sl
# spletna stran sl
# internetna stran sl
# URL sl
# naslov spletne strani sl
# naslov spletišča sl
# situs web sumber id
# URL id
# Website de
# Webseite de
# Quelle de
# Beleg de
# URL de
# Referenz de
# Fundstelle de
# Quellen-URL de
# URL des Einzelnachweises de
# URL sr
# УРЛ sr
# URL della fonte it
# url it
# URL fonte it
# riferimento URL it
# ref URL it
# ref it
# Uniform Resource Locator it
# URL riferimento it
# heimasíða fo
# vevsíðs fo
# webgune eu
# url eu
# web orria eu
# URL zh-mo
# URL zh-hk
# URL zh-my
# URL zh-sg
# موقع ويب ar
# مسار ar
# مسار مرجع ar
# referenco-URL eo
# URL da
# URL nn
# ที่มา th
# อ้างอิง th
# url th
# URL th
# ref th
# URL ia
# ligamine web ia
# webfaqja e referencës sq
# webfaqja sq
# URL sq
# ref sq
# URL e referencës sq
# URL pt-br
# संकेतस्थळ mr
# यूआरएल mr
# स्रोत संकेतस्थळ mr
# संदर्भ संकेतस्थळ mr
# URL zh-hant
# һылтанма ba
# URL ba
# URL-һылтанма ba
# یو آر ال fa
# وبگاه fa
# URL cy
# forrás internetcíme hu
# referencia URL hu
# URL źródła pl
# сылтама tt
# URL tt
# чыганакка сылтама tt
# сылтама tt-cyrl
# URL tt-cyrl
# чыганакка сылтама tt-cyrl
# ওয়েবসাইট bn
# ਸੰਦਰਭ pa
# ਰੈਫਰੈਂਸ pa
# ਵੈੱਬਸਾਈਟ pa
# url en
# Uniform Resource Locator en
# webref en
# URL en
# ref en
# ref URL en
# source URL en
# website en
# вэб-бачына be-tarask
# URL be-tarask
# Шилтеме ky
# URL ky
# url ky
# Булак (URL) ky
# alamat rujukan ms
# tapak web ms
# tapak sesawang ms
# laman web ms
# laman sesawang ms
# rujukan web ms
# sumber web ms
# alamat internet ms
# URL ms
# URL на източник bg
# URL lv
# ୱେବସାଇଟ or
# ୟୁଆରଏଲ or
# ମୂଳ ଆଧାର or
# ဝက်ဘ်ဆိုက် my
# ကွန်ရက်လိပ်စာ my
# 网站 zh
# 來源網址 zh
# 網站 zh
# 统一资源定位符 zh
# 参考地址 zh
# 參考地址 zh
# 来源地址 zh
# 來源地址 zh
# žórło jako URL hsb
# 來源網址 yue
# 出典網址 yue
# website en-gb
# url en-gb
# Uniform Resource Locator en-gb
# webref en-gb
# URL en-gb
# ref en-gb
# ref URL en-gb
# source URL en-gb
# Tekdüzen Kaynak Bulucu tr
# url tr
# web referansı tr
# referans URL tr
# internet sitesi tr
# ref URL tr
# сілтеме kk
# URL сілтеме kk
# дереккөзге сілтеме kk
# URL sco
# P854
# PSH pt-br
# BTT pt-br
# identificador BTT pt-br
# PSH ilo
# identificador PSH ast
# PSH ast
# 체코 기술 도서관 ID ko
# PSH 식별자 ko
# 체코 국립기술도서관 ID ko
# 체코국립기술도서관ID ko
# 체코기술도서관 ID ko
# 체코 국립기술도서관 식별자 ko
# 체코국립기술도서관 식별자 ko
# 체코기술도서관 식별자 ko
# 체코 기술 도서관 식별자 ko
# PSH ID id
# PSH id
# ID PSH id
# PSH идентификатор sr
# ПСХ sr
# PSH oc
# PSH id es
# PSH ba
# PSH идентификаторы ba
# نظام عناوين الموضوعات المنظم ar
# Czech Technical Library-id nn
# PSH ID eu
# PSH en
# Czech Technical Library ID en
# PSH identifier en
# PSH-ID de
# PSH коды tt-cyrl
# PSH коды tt
# PSH kimliği tr
# PSH tanımlayıcı tr
# identifiant PSH fr
# P1051
# 진료과 ko
# 진료하는 과 ko
# 진료할 수 있는 과 ko
# 이 병을 진단할 수 있는 과 ko
# 이 병을 치료할 수 있는 과 ko
# 진단할 수 있는 과 ko
# 치료할 수 있는 과 ko
# 진료 가능한 과 ko
# 진료가 가능한 과 ko
# 진단이 가능한 과 ko
# 치료가 가능한 과 ko
# 치료 가능한 과 ko
# 진단 가능한 과 ko
# spécialisation médicale fr
# domaine médical fr
# medisinsk fagområde nn
# medisinsk spesialitet nn
# medical speciality en
# medical specialty en
# medical field en
# especialidad médica es
# especialidad de la salud es
# especialidad de salud es
# specializzazione medica it
# specialità sanitaria it
# especialidá médica ast
# медицинская профессия ru
# medicinskt fackområde sv
# specjalizacja medyczna pl
# veselības specialitāte lv
# spesialisasi kesehatan id
# tıbbi uzmanlık tr
# tıbbi alan tr
# bidang perubatan ms
# медыцынская спецыялізацыя be
# P1995
# rdfs:subClassOf en
# hyponym of en
# has superclass en
# is also a en
# subtype of en
# is a subtype of en
# subcategory of en
# is a category of en
# is thereby also a en
# is necessarily also a en
# whose instances are among en
# whose instances ⊆ those of en
# ⊆ en
# ⊂ en
# is a type of en
# is a class of en
# subset of en
# type of en
# form of en
# sc en
# Hyponym von de
# ist Unterklasse von de
# ist eine Unterklasse von de
# Oberklasse de
# übergeordnete Klasse de
# является гипонимом по отношению к ru
# надмножества этого понятия ru
# является подклассом для ru
# гипоним от ru
# подмножество от ru
# подкласс в ru
# подпонятие от ru
# подпонятие в ru
# относится как подкласс к ru
# гипероним ru
# надмножество ru
# 上位概念 ja
# 親分類 ja
# スーパークラス ja
# 上位分類 ja
# một trong những vi
# ⊆ vi
# ⊂ vi
# specialisatie nl
# variant nl
# subcategorie nl
# subtype nl
# subklasse av nb
# hyponym av nb
# подмножество на bg
# подвид на bg
# je podtřídou (čeho) cs
# nadskupina cs
# падклас ад be
# надмноства be
# надмноствам з'яўляецца be
# rdfs:subClassOf fr
# est un type de fr
# sous classe de fr
# est une sous-classe de fr
# est une sous classe de fr
# type de fr
# est une variété de fr
# variété de fr
# est une sorte de fr
# sorte de fr
# est un hyponyme de fr
# hyponyme de fr
# fait partie de la catégorie de fr
# 상위분류 ko
# 분류 ko
# 상위범주 ko
# 상위 범주 ko
# 상위 분류 ko
# 상위 부류 ko
# 다음의 하위 부류임 ko
# 다음의 세부 부류임 ko
# 상위 종류 ko
# 상위갈래 ko
# 다음 갈래에서 뻗어나옴 ko
# 상위 갈래 ko
# 고급 개념 ko
# 상위 개념 ko
# 유개념 ko
# 이 개념의 상위 개념 ko
# 다음 개념의 하위 개념임 ko
# 다음 개념의 하위개념임 ko
# 상위개념 ko
# 다음의 하위개념임 ko
# typ nadrzędny pl
# yleistys fi
# è na sorta di scn
# és subclasse de ca
# isddosbarth o cy
# гіпонім від uk
# гіперонім: uk
# підмножина від uk
# надмножина: uk
# підклас від uk
# hiponim dari id
# jenis dari id
# adalah sebuah jenis dari id
# varietas dari id
# macam dari id
# 父类 zh
# 上一级分类 zh
# 父類 zh
# 父类 zh-hans
# tipo de pt
# é um tipo de pt
# generalização pt
# generalizado por pt
# hipônimo de pt
# rdfs:subClassOf pt
# é uma subclasse de pt
# é subclasse de pt
# sottoinsieme it
# è sottoinsieme it
# è incluso in it
# incluso in it
# è sottoclasse di it
# è sottoinsieme di it
# sottoinsieme di it
# iponimo di it
# نوع فرعي من ar
# فئة فرعية من ar
# jé ara yo
# ಕಿನ್ಯ ಪುದರ್ tcy
# ಉಪವಿಬಾಗೊ tcy
# ಸಂಕ್ಷಿಪ್ತ ಹೆಸರು kn
# ಉಪವಿಭಾಗ kn
# ⊆ tt-cyrl
# ⊂ tt-cyrl
# ассыйныф шикелле моңа катнаша tt-cyrl
# ассыйныф кебек моңа катнаша tt-cyrl
# менә моның гипонимы tt-cyrl
# менә моңа ассыйныф була tt-cyrl
# ⊆ tt-latn
# ⊂ tt-latn
# assıynıf şikelle moña qatnaşa tt-latn
# assıynıf kebek moña qatnaşa tt-latn
# menä monıñ giponimı tt-latn
# menä moña assıynıf bula tt-latn
# ⊆ tt
# ⊂ tt
# ассыйныф шикелле моңа катнаша tt
# ассыйныф кебек моңа катнаша tt
# менә моның гипонимы tt
# менә моңа ассыйныф була tt
# rdfs:subClassOf pt-br
# é um subgrupo de pt-br
# possui uma superclasse pt-br
# é um subtipo de pt-br
# é uma categoria de pt-br
# ਸਬਸੈੱਟ pa
# ਉਪ-ਕਿਸਮ pa
# ଏହାର ଉପରଶ୍ରେଣୀ or
# ଏହାର ମୂଳଶ୍ରେଣୀ or
# rdfs:subClassOf en-ca
# hyponym of en-ca
# has superclass en-ca
# is also a en-ca
# subtype of en-ca
# is a subtype of en-ca
# subcategory of en-ca
# is a category of en-ca
# is thereby also a en-ca
# is necessarily also a en-ca
# whose instances are among en-ca
# whose instances ⊆ those of en-ca
# ⊆ en-ca
# ⊂ en-ca
# rdfs:subClassOf en-gb
# hyponym of en-gb
# has superclass en-gb
# is also a en-gb
# subtype of en-gb
# is a subtype of en-gb
# subcategory of en-gb
# is a category of en-gb
# is thereby also a en-gb
# is necessarily also a en-gb
# whose instances are among en-gb
# whose instances ⊆ those of en-gb
# ⊆ en-gb
# ⊂ en-gb
# rdfs:subClassOf ms
# mempunyai kelas besar ms
# subjenis ms
# ialah subjenis ms
# subkategori ms
# ialah subkategori ms
# ialah kategori ms
# ⊆ ms
# ⊂ ms
# падтып ад be-tarask
# падкатэгорыя ад be-tarask
# ⊂ be-tarask
# ⊆ be-tarask
# мае надклясу be-tarask
# rdfs:subClassOf sv
# har föräldraklass sv
# är också en sv
# undertyp av sv
# är en undertyp av sv
# underkategori av sv
# är en kategori av sv
# är därför även en sv
# är nödvändigtvis även en sv
# vars instanser är bland sv
# vars instanser ⊆  de av sv
# ⊆ sv
# ⊂ sv
# är en typ av sv
# är en klass av sv
# undermängd av sv
# typ av sv
# je aj sk
# je typom sk
# je špecifickým typom sk
# je konkrétnym typom sk
# patrí do sk
# er ein underklasse av nn
# ߦߌߟߡߊߙߋ߲ nqo
# ߓߏߟߏ߲ߟߋ߲ nqo
# ߓߏߟߏ߲ߝߘߊߟߋ߲ nqo
# 父類 zh-hk
# 父类 zh-cn
# 父類 zh-hant
# 父類 zh-mo
# 父类 zh-sg
# 父類 zh-tw
# 上級的分類 zh-tw
# 此分類隸屬於 zh-tw
# 隸屬於 zh-tw
# sotoinsieme vec
# l'è sotoinsieme vec
# ژێرپۆلی ckb
# جۆرێکی ckb
# sub-aro de eo
# je podklasa od sh
# kategorisidir tr
# bir türü tr
# bir sınıfı tr
# bir kümesi tr
# bir çeşidi tr
# formu tr
# zorunlu olarak ayrıca bir tr
# dolayısıyla aynı zamanda bir tr
# alt sınıfı tr
# جو اندريون درجو sd
# zersahifa az tg-latn
# төменгі сынып kk
# субкласс kk
# подкласс kk
# irin, kalar, rukunin, dangin ha
# سوبکلس باݢي ms-arab
# P279
# access date en
# date accessed en
# accessdate en
# retrieved at en
# date retrieved en
# date of retrieval en
# time of retrieval en
# accessed en
# consulted en
# visited at en
# fecha de consulta es
# consultado el es
# consultado en es
# Abrufdatum de
# Abfragedatum de
# abgefragt am de
# Zugriff am de
# Zugriffsdatum de
# eingesehen am de
# aufgerufen am de
# abruf de
# zugriff de
# アクセス日 ja
# accesso it
# acceduto il it
# visionato il it
# data di consultazione it
# ultimo accesso it
# ngày truy nhập vi
# lúc truy cập vi
# lúc truy nhập vi
# consulté le fr
# vu le fr
# consultation fr
# date de la consultation fr
# 访问日期 zh
# 获取日期 zh
# 訪問日期 zh
# 檢索日期 zh
# 访问日期 zh-hans
# dato de aliro eo
# data de consulta gl
# consultado o gl
# consultado en gl
# consultado em pt-br
# acessado em pt-br
# data de acesso pt-br
# data da consulta pt-br
# 접근한 날짜 ko
# 접근일 ko
# 접근한 날 ko
# 확인한 날 ko
# 확인했던 날 ko
# 확인함 ko
# 확인했던 날짜 ko
# 확인했음 ko
# 확인 날짜 ko
# 확인날짜 ko
# 확인일 ko
# 확인한 날짜 ko
# aksessdato nb
# تاریخ دستیابی fa
# data d'accesu ast
# تاريخ الوصول ar
# الوصول في ar
# توقيت الوصول ar
# datum dostopa sl
# dostopano sl
# pridobljeno sl
# obiskano sl
# data d'accés ca
# calendata de consulta an
# access date en-gb
# date accessed en-gb
# accessdate en-gb
# retrieved at en-gb
# date retrieved en-gb
# date of retrieval en-gb
# time of retrieval en-gb
# accessed en-gb
# access date en-ca
# date accessed en-ca
# accessdate en-ca
# retrieved at en-ca
# date retrieved en-ca
# date of retrieval en-ca
# time of retrieval en-ca
# accessed en-ca
# recuperate le ia
# проверено ru
# тикшерелгән ba
# เรียกดูเมื่อ th
# erişim tr
# alındığı tarih tr
# ulaşılabildiği tarih tr
# erişilebildiği tarih tr
# ulaşılabildiği zaman tr
# erişilebildiği zaman tr
# zamanı tr
# preuzeto hr
# перевірено uk
# отримано uk
# процитовано uk
# час цитування uk
# цитата від uk
# дата перевірки uk
# тикшерелгән tt
# тикшерелгән tt-cyrl
# dikembali ms
# tarikh dicapai ms
# tarikh dikembali ms
# diperolehi ms
# tarikh diperolehi ms
# didapati ms
# tarikh didapati ms
# masa dicapai ms
# masa dikembali ms
# masa diperolehi ms
# masa didapati ms
# tanggal akses id
# data e marrë sq
# data e qasjes sq
# acessodata pt
# data de consulta pt
# wotwołane hsb
# přistup hsb
# datum přistupa hsb
# датум преузимања sr
# датум приступања sr
# приступљено sr
# Приступљено sr
# прибављено sr
# преузето sr
# посећено sr
# консултовано sr
# Abrufsdadum pfl
# Abfrodadum pfl
# abgefrot am pfl
# Zugrif am pfl
# Zugrifsdadum pfl
# ingesie am pfl
# uffgeruf am pfl
# Abruf pfl
# Zugrif pfl
# bezocht op nl
# datum van raadpleging nl
# ggg nl
# viitattu fi
# P813
# Disease Ontology de
# DO de
# Disease Ontology es
# Ontología de enfermedades es
# DO es
# identificador Disease Ontology es
# DOID da
# Disease Ontology it
# Disease-Ontology-identigilo eo
# DOID eo
# Disease Ontology eo
# код Disease Ontology be-tarask
# Disease Ontology be-tarask
# Disease Ontology идентификатор sr
# DOID nn
# DOID-identifikator nn
# أنطولوجية المرض ar
# Disease Ontology uk
# DOID nb
# P699
# Commonsgalerie de
# Commons gallery ja
# Галерэя ў Вікісховішчы be-tarask
# tập ảnh Commons vi
# album Commons vi
# କମନ୍ସ ଛବିମାଳା or
# galeri Comin cy
# gallery en
# 공용 화랑 ko
# 위키미디어 공용의 화랑 ko
# 공용의 화랑 ko
# 위키미디어 공용 화랑 ko
# 공용 화랑 문서 ko
# 공용의 화랑 문서 ko
# 위키미디어 공용 화랑 문서 ko
# 이 주제를 다룬 공용 화랑 ko
# 이 주제를 다루는 위키미디어 공용 화랑 ko
# 이 주제를 다룬 위키미디어 공용 화랑 ko
# 이 주제를 다루는 화랑 ko
# 이 주제를 다룬 화랑 ko
# galerija lt
# galeri id
# ಗ್ಯಾಲರಿ kn
# galeria eu
# galería es
# galariá oc
# нигорхона дар Викианбор tg
# галлереяи Викианбор tg
# галлерея дар Викианбор tg
# معرض كومونز ar
# معرض ar
# galeri ms
# Àwon àwòrán yo
# ਗੈਲਰੀ pa
# نگارخانہ ur
# گیلری ur
# Викиһаҡлағыста галерея ba
# galerisi tr
# resim galerisi tr
# film galerisi tr
# dosyalar tr
# galeria Wikimedia Commons pl
# galeria multimediów Commons pl
# galeria pl
# сурәтханә tt
# сурәтханә tt-cyrl
# ߞߐߡߎ߮ nqo
# گالێریی کۆمنز ckb
# P935
# ICPC 2 en
# ICPC-2 en
# ICPC2 en
# ICPC 2 fr
# ICPC2 fr
# CISP2 fr
# CISP 2 fr
# identifiant CISP 2 fr
# ICPC2 hr
# identificador ICPC 2 es
# CIAP 2 es
# Clasificación Internacional de Atención Primaria es
# CIAP es
# ICPC-2 es
# ICPC 2 es
# ICPC 2 it
# ICPC-2 it
# ICPC 2 cy
# ICPC 2 be-tarask
# код ICPC 2 be-tarask
# ICPC-2 nn
# ICPC 2 nn
# ICPC 2 uk
# ICPC-2 uk
# ICPC 2 ko
# ICPC-2 eu
# CIAP 2 eu
# identificador ICPC 2 ca
# ICPC 2 коды tt-cyrl
# ICPC 2 коды tt
# ICPC 2 tr
# ICPC2 tr
# Uluslararası Birinci Basamak Sağlık Sınıflandırması kimliği tr
# ICPC 2 kimliği tr
# ICPC 2 sr
# ICPC-2 sr
# ICPC2 sr
# P667
# used for treatment en
# treatment en
# prescribed drug en
# treated by en
# traitement fr
# traité par fr
# medicamento usado es
# medicamente prescrito es
# usado para el tratamiento es
# tratamiento es
# remedio recetado es
# medicamento recetado es
# tratamiento médico es
# используется для лечения ru
# лекарство для лечения ru
# behandlet med da
# medikament da
# léčba cs
# předepisované léky cs
# léčeno cs
# лекі be-tarask
# прапанаваныя лекі be-tarask
# сродкі лекаваньня be-tarask
# دواء ar
# الدواء ar
# medikament nb
# legemiddel nb
# botikak eu
# medikamendua eu
# føreskriven medisin nn
# føreskrive lækjemiddel nn
# føreskrive legemiddel nn
# føreskrive medikament nn
# behandling nn
# medicamento gl
# використовується для лікування uk
# ліки для лікування uk
# лекі для лячэння be
# ārstēšanai izmantojamās zāles lv
# medikamenti lv
# ยารักษา th
# ยา th
# การใช้ยา th
# tedavi için kullanılan tr
# tedavisinde kullanılan tr
# reçeteli ilacı tr
# tarafından tedavi edilir tr
# tarafından tedavi edildi tr
# የፈውስ መድሃኒት am
# P2176
# NDF-RT ID ru
# NDF-RT id es
# National Drug File Reference Terminology es
# dynodwr NDF-RT cy
# المصطلحات المرجعية بملف المخدرات الوطني ar
# код NDF-RT be-tarask
# NDF-RT be-tarask
# identifiant NDF-RT fr
# NDF-RT-identifikator nb
# NDFRT ID pt-br
# Ulusal İlaç Dosyası kimliği tr
# P2115
# lengua es
# idioma es
# idioma de una obra es
# idioma it
# lingua it
# lingua del riferimento it
# lingua della fonte it
# lingua del nome it
# lingua del testo it
# lingua usata it
# lingua del sito web it
# llengua de l'obra ca
# llengua del nom ca
# llengua del terme ca
# llengua del lloc web ca
# idioma pt
# lingua pt
# língua da obra pt
# idioma do nome pt
# língua do nome pt
# Sprache des Werkes de
# Sprache des Namens de
# Sprache des Begriffes de
# jazyk jména cs
# jazyk díla cs
# langue de l'oeuvre fr
# langue du nom fr
# langue du terme fr
# langue du site web fr
# broadcasting language en
# audio language en
# available in en
# language of work en
# language of the reference en
# language of website en
# language of URL en
# used language en
# language of the name en
# language of name en
# language of spoken text en
# named in language en
# language en
# 작품의 언어 ko
# 명칭의 언어 ko
# 언어 ko
# 이름의 언어 ko
# 제목의 언어 ko
# 작품 언어 ko
# 저작물 또는 명칭의 언어 ko
# 저작물의 언어 ko
# 저작물/명칭의 언어 ko
# 명칭/저작물의 언어 ko
# 명칭·저작물의 언어 ko
# 저작물 언어 ko
# 명칭 언어 ko
# язык названия ru
# название на языке ru
# написано на языке ru
# создано на языке ru
# вещает на языке ru
# nyelv hu
# mű nyelve hu
# név nyelve hu
# alkotás nyelve hu
# bahasa dari suatu butir id
# bahasa butir id
# bahasa dari karya atau nama id
# створено мовою uk
# назва мовою uk
# написано мовою uk
# мова твору uk
# мовлення мовою uk
# твір мовою uk
# мовою uk
# اللغة للعمل أو الاسم ar
# لغة العمل أو الإسم ar
# متوفر ب ar
# لغة البث ar
# мова be
# на мове be
# lingua da obra gl
# taal van naam nl
# 作品の使用言語 ja
# 作品の言語 ja
# språk nb
# ভাষা bn
# 作品或名字的语言 zh
# 作品的语言 zh
# 作品的語言 zh
# 名字的语言 zh
# 名字的語言 zh
# 播放语言 zh
# 播放語言 zh
# 音频语言 zh
# 音頻語言 zh
# мова назвы be-tarask
# назва на мове be-tarask
# створана на мове be-tarask
# вяшчае мовай be-tarask
# Gjuha e punës sq
# Gjuha e emrit shqip sq
# eserin dili tr
# çalışmanın dili tr
# hangi dilde olduğu tr
# yayın dili tr
# yayım dili tr
# fonetiği tr
# yayımlandığı dil tr
# yayınlandığı dil tr
# dilinde tr
# dilindedir tr
# rěč twórby hsb
# rěč mjena hsb
# rěč zapřijeća hsb
# نام کی زبان ur
# براڈکاسٹنگ نام ur
# آڈیو نام ur
# کام کی زبان ur
# језик имена sr
# назван на језику sr
# доступан у sr
# доступно у sr
# језик дела sr
# jazyk názvu sk
# jazyk práce sk
# vytvorené v jazyku sk
# idioma pt-br
# língua pt-br
# idioma do nome pt-br
# língua do nome pt-br
# língua da obra pt-br
# زبان فیلم fa
# زبان بازی fa
# زبان کتاب fa
# ngôn ngữ của tên tác phẩm vi
# hizkuntza eu
# படைப்பின் மொழி ta
# படைப்பு மொழியில் பெயர் ta
# שפת היצירה he
# नाम या काम की भाषा hi
# забони китоб tg
# əsərin dili az
# yayımlandığı dil az
# bahasa karya ms
# bahasa rujukan ms
# bahasa nama ms
# lingvo de la verko eo
# dostępne w pl
# używany język pl
# broadcasting language en-gb
# audio language en-gb
# available in en-gb
# language of work en-gb
# language of the reference en-gb
# language of website en-gb
# language of URL en-gb
# used language en-gb
# language of the name en-gb
# language of name en-gb
# language of spoken text en-gb
# named in language en-gb
# language en-gb
# verkets/namnets språk sv
# språk sv
# łéngua de l'òpara vec
# łéngua del nome vec
# łéngua del tèrmano vec
# łéngua de ła fonte vec
# łéngua doparada vec
# ቋንቋ ti
# P407
# à partir de fr
# début fr
# commencement fr
# depuis fr
# à compter de fr
# depuis le fr
# date de départ fr
# from en
# starting en
# began en
# from time en
# since en
# from date en
# building date en
# starttime en
# introduced en
# introduction en
# started in en
# beginning en
# join date en
# join time en
# start date en
# startdato nn
# starta nn
# frå og med nn
# frå dtg nn
# تاریخ آغاز fa
# Startdatum de
# Von de
# Beginnend am de
# Start de
# seit de
# Beginn de
# begann de
# Anfang de
# Anfangszeit de
# ab de
# 始于 zh
# 始於 zh
# 开始于 zh
# 开始时间 zh
# 起始时间 zh
# 起始于 zh
# пачатак be
# starttid nb
# starttidspunkt nb
# fra nb
# fra dtg nb
# start dtg nb
# datum start nl
# startdatum nl
# sinds nl
# vanaf nl
# sedan sv
# starttid sv
# startades sv
# började sv
# תאריך ההתחלה he
# תה he
# start time en-gb
# from en-gb
# began en-gb
# data inizio it
# dal it
# a partire da it
# a cominciare da it
# valido a partire da it
# inizio it
# anno di inizio it
# data d'inizio it
# anno d'inizio it
# começou pt
# iniciou pt
# início pt
# desde pt
# data de início pt
# действует с ru
# применимо с ru
# началось в ru
# введено с ru
# дата введения ru
# существует с ru
# начиная с ru
# έναρξη el
# αρχή el
# kezdés ideje hu
# építés ideje hu
# építés éve hu
# bemutatás hu
# innentől hu
# ettől hu
# kezdő dátum hu
# ngày khánh thành vi
# ngày thành lập vi
# ngày sáng lập vi
# desde es
# primera emisión es
# inicio es
# lanzamiento es
# fecha inicio es
# comienzo es
# ଗଠିତ or
# ସ୍ଥାପନ or
# 開始年月日 ja
# 開始日時 ja
# 開始時刻 ja
# 開始日付 ja
# 始期 ja
# 結婚日 ja
# 就任日 ja
# 任期開始 ja
# 発生日 ja
# desde pt-br
# data inicial pt-br
# início pt-br
# principiu scn
# a pàrtiri di scn
# abaoe br
# bloaziad kregiñ br
# amzeriad kregiñ br
# nuo lt
# pradžios data lt
# oras ng simula tl
# старт з uk
# існує з uk
# час початку uk
# дата початку uk
# час старту uk
# дата старту uk
# дата відкриття uk
# час відкриття uk
# час започаткування uk
# дата започаткування uk
# від uk
# початок uk
# відкрито uk
# започатковано uk
# 부터 ko
# 시작일 ko
# 시작날짜 ko
# 이래 ko
# 시작일자 ko
# 시작된 날짜 ko
# 시작한 날 ko
# 시작한 날짜 ko
# 첫 방송일 ko
# 최초 방송일 ko
# 처음 방송한 날짜 ko
# 첫 방송한 날짜 ko
# 첫 화가 방송된 날 ko
# 첫 화가 방송된 날짜 ko
# 방송 개시일 ko
# 존재하기 시작한 날짜 ko
# 존재하기 시작한 날 ko
# 시작 날짜 ko
# ከ am
# የመነሻ ጊዚ am
# byrjan fo
# byrjunardagur fo
# থেকে bn
# তারিখ থেকে bn
# নির্মানের সময় bn
# শুরু তারিখ bn
# dari id
# dimulai tanggal id
# dimulai dari id
# mulai dari id
# tanggal mulai id
# waktu mulai id
# alkamisaika fi
# alkamispäivä fi
# alkaen fi
# lähtien fi
# voimassa alkaen fi
# dende ast
# aniciu ast
# principiu ast
# llanzamientu ast
# من ar
# منذ ar
# البداية ar
# بدأ ar
# توقيت البدء ar
# من تاريخ ar
# من توقيت ar
# تاريخ الإنشاء ar
# تاريخ التقديم ar
# fra da
# inici ca
# des de ca
# començament ca
# data de començament ca
# va començar ca
# ìbèrè yo
# ಸುರುವಾಪುನ ಸಮಯೊಡ್ದು ಅಕೇರಿಮುಟ್ಟೊ tcy
# ಆರಂಭವಾಗುವ ಸಮಯದಿಂದ ಕೊನೆಯ ವರೆಗೆ kn
# fillimi sq
# nga sq
# prej sq
# që nga sq
# që prej sq
# आरंभापासून mr
# पासून सुरू mr
# वेळेपासून सुरू mr
# पासून आरंभ mr
# शुभारंभ mr
# पासून प्रयुक्त mr
# început ro
# dată de început ro
# de la ro
# din ro
# 始於 yue
# 起於 yue
# start time si
# ඉදිකිරීම් දිනය si
# ආරම්භ වූයේ si
# začátek cs
# počátek cs
# 開始於 zh-tw
# 開始時間 zh-tw
# 起始於 zh-tw
# datum početka bs
# башлану датасы tt
# башлану датасы tt-cyrl
# เริ่มออกอากาศ th
# วันทีเริ่ม th
# เวลาที่เริ่ม th
# ออกอากาศครั้งแรก th
# ตอนแรก th
# ปีที่เริ่ม th
# วันที่เริ่มออกอากาศ th
# เริ่มตั้งแต่ th
# ตั้งแต่ th
# пачатак be-tarask
# стартавая дата be-tarask
# ад даты be-tarask
# alguskuupäev et
# Startdatum gsw
# vo gsw
# aagfange gsw
# sit gsw
# ab gsw
# sākuma datums lv
# no lv
# başlama tarihi tr
# başlangıç tr
# başlama tr
# မှစတင်ကာ my
# ကတည်းက my
# စတင်တာဝန်ယူချိန် my
# сол tg
# рӯз tg
# моҳ tg
# оғоз tg
# аввал tg
# сар tg
# ...
# identificador GEC ast
# Büyük Katalonya Ansiklopedisi kimliği tr
# Katalonya Ansiklopedisi kimliği tr
# identificador GEC pt
# identificador na GEC pt
# GEC pt
# Gran Enciclopèdia Catalana pt
# Grande Enciclopédia Catalã pt
# Große katalanische Enzyklopädie ID de
# GEC-Kennung de
# 加泰隆尼亞大百科全書編號 zh
# код па Gran Enciclopèdia Catalana be-tarask
# GEC ID pl
# GEC ID da
# GEC ID sk
# GEC ID pt-br
# GEC ID hsb
# Wulka katalanska encyklopedija hsb
# P1296
# مفردات التعليم الأسترالية ar
# AEV ID en
# SCOT ID en
# Schools Online Thesaurus ID en
# identificativo AEV it
# ID AEV it
# ідентифікатор AEV uk
# ID AEV pl
# AEV ID ca
# AEV-ID de
# AEV ID en-ca
# AEV ID en-gb
# AEV ID eo
# AEV ID fr
# AEV-ID nds
# AEV ID simple
# AEV-ID sv
# AEV ID vec
# P7033
# OmegaWiki-Kennung de
# شناسۀ اومگا ویکی fa
# OmegaWiki eo
# OmegaWiki it
# أوميغاويكي ar
# معنى معرفَّ في أوميغاويكي ar
# OmegaWiki DefinedMeaning nn
# OmegaWiki DM nn
# P1245
# تسمية منهجية للطب ar
# identifikátor SNOMED CT cs
# identifikátor SNOMED cs
# SCTID en
# finding en
# disorder en
# procedure en
# physical object en
# foundation metadata concept en
# P5806
# frvd en
# Vikidia article in French en
# article in French Vikidia en
# ідэнтыфікатар францускай Вікідыі be-tarask
# frvd ms
# rencana Vikidia dalam bahasa Perancis ms
# rencana di Vikidia Perancis ms
# Fransızca Vikidia makalesi tr
# Fransızca Vikidia maddesi tr
# Fransa Vikidia kimliği tr
# frvd zh
# 法國Vikidia標識符 zh
# identificador en Vikidia en francés gl
# identificador en Vikidia en francés es
# ID Vikidia pl
# Vikidia-ID bar
# Vikidia ID ca
# Vikidia-ID de
# Vikidia-ID de-at
# Vikidia-ID de-ch
# Vikidia ID en-ca
# Vikidia ID en-gb
# Vikidia-ID nds
# Vikidia ID simple
# P7818
# envd en
# Vikidia article in English en
# article in English Vikidia en
# İngilizce Vikidia makalesi tr
# İngilizce Vikidia maddesi tr
# identificador en Vikidia en inglés gl
# identificador en Vikidia en inglés es
# ID Vikidia pl
# Vikidia-ID bar
# Vikidia ID ca
# Vikidia-ID de
# Vikidia-ID de-at
# Vikidia-ID de-ch
# Vikidia ID en-ca
# Vikidia ID en-gb
# Vikidia ID fr
# Vikidia-ID nds
# Vikidia ID simple
# P7829
# esvd en
# Vikidia article in Spanish en
# article in Spanish Vikidia en
# İspanyolca Vikidia makalesi tr
# İspanyolca Vikidia maddesi tr
# ID Vikidia pl
# Vikidia ID en-ca
# Vikidia ID en-gb
# Vikidia ID simple
# Vikidia ID ca
# Vikidia-ID de
# Vikidia-ID de-at
# Vikidia-ID de-ch
# Vikidia-ID nds
# P7827
# القاموس الطبي الكبير ar
# ідэнтыфікатар ВМС be-tarask
# ідэнтыфікатар Store medisinske leksikon be-tarask
# ідэнтыфікатар SML be-tarask
# Sml ID en
# P5082
# тип взаимосвязи ru
# mapeado es
# SKOS mapping relation en
# mapping type en
# тип взаємозв'язку uk
# typ relacji SKOS pl
# typ zgodności zakresowej pl
# relacja mapowania SKOS pl
# typ relacji mapowania pl
# rodzaj zgodności pomiędzy powiązanymi pojęciami pl
# супастаўленьне SKOS be-tarask
# тып узаемасувязі be-tarask
# jenis pemetaan ms
# hubungan pemetaan ms
# 映射关系类型 zh
# SKOS haritalama ilişkisi tr
# haritalama bağlantısının türü tr
# haritalama bağlantısının tipi tr
# planlama türü tr
# haritalama türü tr
# haritayla ilişkilendirme türü tr
# P4390
# Nationalencyklopedin Online ID en
# NE.se en
# NE ID en
# Nationalencyklopedin ID en
# NE-ID sv
# Nationalencyklopedin es
# identificador Enciclopedia Nacional Sueca es
# Enciclopedia Nacional Sueca es
# Ne.se es
# NE id es
# Nationalencyklopedin Online ID fr
# NE.se cy
# NE.se-identigilo eo
# Ne.se it
# NE ID it
# Ne.se oc
# код NE.se be-tarask
# NE.se be-tarask
# NE.se-tunniste fi
# Nationalencyklopedin Online -tunniste fi
# NE-tunniste fi
# NE.se ru
# идентификатор NE.se ru
# Nationalencyklopedin ID nb
# Nationalencyklopedin Online ID nb
# NE ID nb
# NE.se uk
# الموسوعة الوطنية السويدية ar
# Nationalencyklopedin Online-id nn
# Nationalencyklopedin-id nn
# NE.se id
# Nationalencyklopedin ID id
# ID NE id
# Nationalencyklopedin-Online-ID de
# NE.se-ID de
# NE.se tanımlayıcısı tr
# NE.se ID tr
# NE.se numarası tr
# NE.se коды tt-cyrl
# NE.se коды tt
# P3222
# موسوعة بروكهوس على الإنترنت ar
# ідэнтыфікатар Brockhaus Enzyklopädie онлайн be-tarask
# Brockhaus Enzyklopädie online-id nn
# Brockhaus Enzyklopädie çevrimiçi kimliği tr
# P5019
# Hrvatska-enciklopedija-ID de
# Hrvatska enciklopedija ID de
# LZMK ID de
# Hrvatska enciklopedija ID es
# Hrvatska enciklopedija pl
# Hrvatska enciklopedija ID fr
# Hrvatska enciklopedija ID nn
# Hrvatska enciklopedija ID sv
# Hrvatska enciklopedija ID it
# Hrvatska enciklopedija ID ca
# P7982
# P7995
# YSO ID ru
# YSO ID fr
# YSO id es
# YSO it
# ALLFO-ID nb
# ALLFO-ID en
# YSO-ID sv
# код YSO be-tarask
# ALLFO-ID be-tarask
# الأنطولوجيا الفنلندية العامة ar
# YSO ID be
# ALLFO-ID fi
# YSO-ID fi
# ALLFO-ID ro
# YSO id ro
# YSO ro
# YSO коды tt-cyrl
# YSO коды tt
# YSO ID br
# YSO ID ca
# YSO ID cs
# YSO ID cy
# YSO ID eo
# YSO ID gl
# P2347
# Wikimedia project focus list en
# has Wikimedia project en
# focused on by Wikimedia project en
# catalog of Wikimedia project en
# focus list en
# part of Wikimedia project en
# included in Wikimedia project en
# created or edited for Wikimedia project en
# created or edited as part of Wikimedia project en
# item created or edited for Wikimedia project en
# item created or edited as part of Wikimedia project en
# Wikimedia projesi odak listesi tr
# Wikimedia projesinin bir parçasıdır tr
# odak listesi tr
# i fokus på Wikimedia-prosjektet nn
# fokusert på i prosjektet nn
# Wikimedia-fokusprosjekt nn
# fokusprosjekt nn
# liste d'intérêt pour le projet Wikimedia fr
# wikiprosjekt-liste nb
# wikiprosjekt-fokusliste nb
# llista d'interes pa un proyeutu de Wikimedia ast
# tien proyeutu de Wikimedia ast
# catálogu de proyeutu de Wikimedia ast
# di senarai fokus projek Wikimedia ms
# senarai tumpu projek Wikimedia ms
# senarai fokus projek Wikimedia ms
# P5008
# 不是 zh
# 区别于 zh
# 本条目的主题不是 zh
# 本页面的主题不是 zh
# 本條目的主題不是 zh
# 本頁面的主題不是 zh
# 相異物 zh
# 不同于 zh
# different than en
# different to en
# is not en
# distinct from en
# not the same as en
# isn't en
# distinguished from en
# to be distinguished from en
# disambiguated from en
# not same as en
# confused with en
# is different from en
# mistakenly taken for en
# differs from en
# differ from en
# often confused with en
# rejected match en
# not to be confused with en
# ≠ en
# not equal to en
# is not the same as en
# do not confuse with en
# not identical to en
# different thing from en
# different entity from en
# is not same as en
# different entity than en
# different thing than en
# differisce da it
# differente rispetto a it
# non è it
# spesso confuso con it
# confuso spesso con it
# confuso con it
# diverso da it
# da non confondere con it
# erroneamente confuso per it
# فرق می‌کند با fa
# گفته می‌شود یکی نیست با fa
# отличный от ru
# не ru
# owl:differentFrom de
# nicht zu verwechseln mit de
# ungleich de
# zu unterscheiden von de
# anders als de
# unterschiedlich zu de
# no es es
# no confundir con es
# distinguir de es
# difiere de es
# distinto de es
# no es el mismo que es
# não confundir com pt
# niet hetzelfde als nl
# niet te verwarren met nl
# ongelijk aan nl
# verschillend van nl
# nun è scn
# distintu di scn
# di nun cunfùnniri cu scn
# n'autra cosa rispettu a scn
# confondre, ne pas fr
# ne pas confondre avec fr
# différent de fr
# distinct de fr
# n'est pas le même que fr
# ne doit pas être confondu avec fr
# annorlunda sv
# inte samma sv
# inte samma som sv
# ej att förväxla med sv
# różny od pl
# nie mylić z pl
# 不是 zh-tw
# 區別於 zh-tw
# 不是 zh-hant
# 區別於 zh-hant
# 本條目的主題不是 zh-hant
# 本頁面的主題不是 zh-hant
# owl:differentFrom fi
# eri asia kuin fi
# eri kohde kuin fi
# ei ole fi
# ei sama kuin fi
# sekoitetaan tämän kanssa fi
# sekoitetaan usein tämän kanssa fi
# ei ole sama kuin fi
# negali būti painiojama su lt
# is nie af
# não confundir com pt-br
# não é pt-br
# atšķirīgs no lv
# ня блытаць be-tarask
# гэта не be-tarask
# адрозьніваць ад be-tarask
# адрозьніваецца ад be-tarask
# לא זהה עם he
# לא לבלבל עם he
# 다음과 혼동하지 말 것 ko
# 혼동하는 표현 ko
# 아님 ko
# 다음 항목이 아님 ko
# 다음과 다름 ko
# 다음의 것과 다름 ko
# 다음과는 서로 다름 ko
# 서로 다름 ko
# 혼동하는 대상 ko
# 다음과는 다름 ko
# 확실히 다름 ko
# nun ye ast
# distintu de ast
# nun confundir con ast
# 以下とは異なる ja
# 以下と違う ja
# 以下とは違う ja
# más hu
# nem ugyanaz hu
# odlišné od cs
# liší se od cs
# různé od cs
# neplést s cs
# není totéž cs
# není stejné cs
# bukan id
# jangan dibingungkan dengan id
# berbeda dari id
# tidak sama dengan id
# ต่างจาก th
# ไม่เหมือนกับ th
# คนละสิ่งกับ th
# คนละอย่างกับ th
# แตกต่างจาก th
# değil tr
# karıştırılmamalıdır tr
# farklı tr
# aynı değil tr
# diferent de ca
# distint de ca
# confusió ca
# er ikke det samme som da
# er ikke da
# ikke at forveksle med da
# ulig med da
# forveksles ofte med da
# diferent de oc
# drugačen od sl
# ne zamenjaj z sl
# ne zamenjati z sl
# ne zamenjuj z sl
# nie je sk
# nemýliť si s sk
# iné ako sk
# odlišné od sk
# 不同于 zh-hans
# 本条目的主题不是 zh-hans
# 本页面的主题不是 zh-hans
# 相异物 zh-hans
# 不同于 zh-sg
# kìí se yo
# kò papò món yo
# nicht zu verwechseln mit de-at
# nicht zu verwechseln mit de-ch
# 相異于 yue
# 同佢唔同 yue
# skil seg frå nn
# er ikkje nn
# ulik til nn
# ikkje lik nn
# må ikkje forvekslast med nn
# అది కాదు te
# ez bezalakoa eu
# менән бутамаҫҡа ba
# berlainan daripada ms
# bukannya ms
# не uk
# відрізняється від uk
# इस से अलग hi
# није sr
# не треба мешати са sr
# није исто што и sr
# није исто што sr
# другачије од sr
# такође погледајте sr
# меша се са sr
# је другачије од sr
# isnae sco
# nae the same as sco
# पासून वेगळे mr
# पासून अलग mr
# नाही mr
# नाही आहे mr
# फरक आहे mr
# वेगळे आहे mr
# शी गोंधळ करू नका mr
# गल्लत mr
# चुकीने ओळखतात mr
# यासम नाही mr
# diofraichte bho gd
# underschidlich gsw
# uugliich gsw
# anderscht als gsw
# nöd zverwächsle mit gsw
# يختلف عن ar
# muu kui et
# erinev et
# mitte sama kui et
# skiller seg fra nb
# er ikke nb
# ikke lik nb
# må ikke forveksles med nb
# ulik nb
# distinto de gl
# diferente de gl
# non é gl
# non é o mesmo que gl
# adoita confundirse con gl
# အခြားပုံစံသည် my
# နှင့် မတူ my
# မတူ my
# မဟုတ် my
# ဤသည်တို့ ဖြင့် မတူညီပါ my
# ထပ်မံ ကြည့်ရမည်မှာ my
# အခြားသော ပုံစံ my
# မရောထွေ သင့်သည်မှာ my
# မတူညီသော အရာများ my
# အတူတူ မဟုတ်ကြသော my
# ii leat seammá go se
# ߊ߬ ߝߘߏ߬ߣߍ߲߬ ߡߍ߲ ߡߊ߬ nqo
# ߡߍ߲ ߕߍ߫ nqo
# non confunder con ia
# meliyanan sareng ban
# 不同于 zh-cn
# 区别于 zh-cn
# roztōmajty ôd szl
# niy mylić z szl
# P1889
# URL страницы Викимедиа ru
# взято со страницы Викимедиа ru
# взято зі сторінки Вікімедіа uk
# посилання на використану сторінку Вікімедіа uk
# посилання на сторінку Вікімедіа uk
# URL imported from Wikimedia en
# Wikimedia URL en
# Wikipedia import URL en
# Wikimedia reference URL en
# Wikimedia permalink en
# WMF import URL en
# WMF URL en
# Wikipedia URL en
# import URL from a Wikimedia project en
# Wikipedia reference URL en
# reference URL from Wikimedia en
# reference URL from Wikipedia en
# URL importazione Wikimedia it
# URL d'importazione Wikimedia it
# link permanente Wikimedia it
# link Wikimedia it
# URL Wikimedia it
# permalink Wikimedia it
# collegamento Wikimedia it
# 维基媒体导入统一资源定位符 zh
# 维基媒体导入URL zh
# 維基媒體匯入URL zh
# 維基媒體匯入統一資源定位符 zh
# 维基媒体导入网址 zh
# URL van Wikimedia-import nl
# спасылка на старонку Вікімэдыі be-tarask
# Увозни URL Викимедије sr
# Викимедијин URL sr
# URL Викимедије sr
# URL увезен с Викимедије sr
# مسار الاستيراد من مشروع ويكيميديا ar
# مسار ويكيميديا ar
# مسار استيراد ويكيميديا ar
# عنوان الاستيراد من ويكيميديا ar
# zdrojový článok Wikipedie sk
# zdrojová adresa Wikimedia objektu sk
# 维基媒体导入统一资源定位符 zh-hans
# 維基媒體匯入統一資源定位符 zh-hant
# Permanenter Link de
# Diff-Link de
# Wikipedia-Import-URL de
# Import-URL de
# узята са старонкі Вікімедыя be
# URL старонкі Вікімедыя be
# Lien permanent fr
# url wikipedia fr
# ยูอาร์แอลจากโครงการวิกิมีเดีย th
# ดึงมาจากยูอาร์แอลของโครงการในวิกิมีเดีย th
# นำเข้าข้อมูลจากยูอาร์แอลโครงการวิกิมีเดีย th
# ยูอาร์แอลจากโครงการวิกิมีเดียที่นำเข้าข้อมูล th
# Import URL from a Wikimedia project en-gb
# URL imported from Wikimedia en-gb
# Wikimedia URL en-gb
# Wikipedia import URL en-gb
# Wikimedia reference URL en-gb
# Wikimedia permalink en-gb
# bir Wikimedia projesinden içe aktarılan URL tr
# Wikimedia'dan alınan URL tr
# Wikimedia URL'si tr
# Vikipedi içe aktarma URL'si tr
# Wikimedia referans URL'si tr
# Wikimedia kalıcı bağlantısı tr
# Uvozni URL s Wikipedije bs
# Wikipedia URL bs
# Wikipedijin URL bs
# URL Wikipedije bs
# P4656
# medical findings en
# medical finding en
# 医学的所見 ja
# возможные медицинские наблюдения ru
# медицинские наблюдения ru
# медицинские заключения ru
# медичні висновки uk
# могући медицински извештај sr
# posibles hallazgos médicos es
# hallazgos médicos es
# hallazgo médico es
# medisinske funn nn
# descoperire medicală ro
# P5131
# شناسۀ سمپ fa
# MeSH Unique ID en
# UI en
# MeSH ID en
# MeSH ID pt-br
# MeSH ID es
# identificador único MeSH es
# MeSH 고유 ID ko
# 의학주제표목 고유 ID ko
# 의학주제표목 ID ko
# 의학주제표목 식별자 ko
# MeSH 식별자 ko
# MeSH ID ko
# 의학학술정보 분류체계 ID ko
# 의학학술정보 분류체계 식별자 ko
# 의학 학술정보 분류체계 ID ko
# 의학 학술정보 분류체계 식별자 ko
# 의학 주제명 표목표 ID ko
# 의학 주제명 표목 ID ko
# 의학주제명표목표 ID ko
# 의학주제명표목 ID ko
# 의학주제명표목표 식별자 ko
# 의학주제명표목 식별자 ko
# 의학 주제명표목표 식별자 ko
# 의학 주제명표목 식별자 ko
# 의학 주제명표목표 ID ko
# 의학 주제명표목 ID ko
# 의학 주제명 표목표 식별자 ko
# 의학 주제명 표목 식별자 ko
# MeSH 유니크 ID ko
# identifikátor MeSH cs
# MeSH identifikátor cs
# MeSH it
# MeSH cy
# نظام فهرسة المواضيع الطبية ar
# код MeSH be-tarask
# MeSH идентификатор sr
# MeSH ID eu
# MeSH ID fr
# identifiant MeSH fr
# Benzersiz MeSH Kodu tr
# MeSH tamımlayıcı numarası tr
# MeSH tamımlayıcı ID tr
# унікальний ідентифікатор MeSH uk
# MeSH ID pl
# MeSH-ID de
# MeSH коды tt-cyrl
# MeSH коды tt
# P486
# credited as en
# subject stated as en
# authorized as en
# authorized access point en
# established as en
# authorized form en
# authorized heading en
# established form en
# established heading en
# gecrediteerd als nl
# nomeado como pt
# creditado como pt
# acreditado como es
# conocido como es
# تخلص fa
# указан как ru
# в титрах как ru
# обозначен как ru
# под именем ru
# при создании назван как ru
# названо как ru
# accreditato come it
# conosciuto come it
# all’epoca noto come it
# 名義 ja
# クレジット表記名 ja
# acreditat com a ca
# пазначаны як be-tarask
# пададзены як be-tarask
# بإسم ar
# اسم النسبة ar
# اسم نسبة ar
# imenovan kot sl
# z imenom sl
# מופיע בשם he
# crédité comme fr
# isimlendiren tr
# aktarılan tr
# aktarılması tr
# adlandırılması tr
# adını alması tr
# указаний як uk
# вказаний як uk
# acreditáu como ast
# figura como ast
# kreditert som nb
# kreditert som nn
# ในนาม th
# ในชื่อของ th
# ในชื่อ th
# w napisach jako pl
# dinamai ms
# digelar ms
# diberi gelaran ms
# diberikan nama ms
# dengan nama ms
# dengan gelaran ms
# uvedena jako cs
# pseudonym cs
# vytvorený ako sk
# minēts kā lv
# nosaukta kā lv
# minēta kā lv
# quajtur si sq
# dindan an anv a br
# anavezet evel br
# mjenowana jako hsb
# creditado como pt-br
# citado como pt-br
# referido como pt-br
# nomeada como pt-br
# creditada como pt-br
# citada como pt-br
# referida como pt-br
# ponto de acesso autorizado pt-br
# cabeçalho autorizado pt-br
# বর্ণনা করা হয় যে নামে bn
# omnämns som sv
# P1810
# Proleksis enciklopedija ID fr
# Proleksis-enciklopedija-ID de
# Proleksis enciklopedija ID de
# Proleksis enciklopedija kimliği tr
# идентификатор в Энциклопедии Пролексис ru
# P8349
# סימפטומים he
# signes fonctionnels fr
# Symptom de
# symptomy cs
# klinický obraz cs
# síntomas clínicos es
# 症候 ja
# 徴候 ja
# semptom ku-latn
# прояви uk
# belirti tr
# demptom tr
# işaret tr
# delil tr
# fonksiyonel işaretler tr
# semptomlar tr
# semptom tr
# znaki sl
# признаки ru
# 症狀 zh
# symptomat se
# симптом-влак mhr
# symptom hsb
# simptom ms
# P780
# Lista de Encabezamientos de Materia para Bibliotecas Públicas es
# LEMb ID en
# LEMBP ID en
# Lista de Encabezamientos para Bibliotecas Públicas ID en
# Lista de Encabezamientos para Bibliotecas Publicas ID en
# Spanish subject headings for public libraries ID en
# وزارة التربية والتعليم والثقافة والرياضة الإسبانية ar
# معرف عناوين الموضوعات الإسبانية للمكتبات العامة ar
# عناوين الموضوعات الإسبانية للمكتبات العامة ar
# LEMb kimliği tr
# LEMBP kimliği tr
# Lista de Encabezamientos para Bibliotecas Públicas kimliği tr
# LEM kimliği tr
# İspanya'daki halk kütüphaneleri için konu tr
# P920
# KBpedia en
# KKO en
# KBpedia knowledge graph en
# KBpedia ontology en
# kbpedia en
# Kbpedia en
# KBpedia ID fr
# cod KBpedia ro
# ID KBpedia ro
# KBpedia ID ro
# KBpedia uk
# онтологія KBpedia uk
# KBpedia de
# KBpedia ID de
# KBpedia ms
# KBpedia коды tt-cyrl
# KBpedia коды tt
# KBpedia|KKO|Kbpedia pt
# KBpedia ID zh
# KBpedia pl
# ID KBpedia pl
# KBpedia ca
# KBpedia ID ca
# KBpedia eo
# KBpedia ID eo
# KBpedia es
# KBpedia ID es
# KBpedia it
# KBpedia ID it
# KBpedia vec
# КБпедија sr
# KBpedia ID bs
# KBpedia bs
# KKO bs
# KBpedija bs
# KBP bs
# P8408
# التصنيف الإحصائي الدولي للأمراض 11 ar
# ідентифікатор ICD-11 uk
# МКХ-11 uk
# ICD-11 ID fr
# identifiant ICD-11 fr
# P7329
# P7807
# شناسۀ KEGG fa
# شناسۀ کگ fa
# KEGG es
# KEGG fr
# KEGG ID ja
# KEGG ID ru
# KEGG pt-br
# код KEGG be-tarask
# KEGG ID uk
# identigilo laŭ KEGG eo
# Kyoto Encyclopedia of Genes and Genomes ID en
# KEGG: Kyoto Encyclopedia of Genes and Genomes ID en
# P665
# AniDB ID (tag) fr
# P8785
# مكنز برلمان المملكة المتحدة ar
# UK Parliament-tesaurusidentifikator nn
# тезаурус Великої Британії uk
# Parlamentsthesauruskennung (VK) de
# Parlamentsthesauruskennung (UK) de
# UK Parliament thesaurus коды tt-cyrl
# UK Parliament thesaurus коды tt
# İngiltere Parlamentosu thesaurus kimliği tr
# İngiltere Parlamentosu tesarus kimliği tr
# BK Parlamentosu tesarus kimliği tr
# P4527

# %%
for linked_qid in linked_items:
    rdf_item.add((ns["wd"][linked_qid], RDF.type, ns["wikibase"].Item))
    linked_qid_item = wdi_core.WDItemEngine(wd_item_id=linked_qid).get_wd_json_representation()
    transformLabels(linked_qid, linked_qid_item)
# Out:
# Biblioteca Nazionale Centrale di Firenze eo
# BNCF de
# Nationalbibliothek Florenz de
# Nasodnon nga Namumutnga nga Sulod-Barashan war
# National Central Library war
# Nasodnon nga Namumutnga Sulod-Barashan han Florensya war
# Nasodnon nga Namumutnga nga Sulod-Barashan han Florensya war
# Национальная центральная библиотека ru
# Biblioteca Nazionale Centrale di Firenze es
# Biblioteca Nazionale Centrale Firenze fi
# Firenzen kansallinen keskuskirjasto fi
# Italian kansalliskirjasto Firenzessä fi
# Флорентійська бібліотека uk
# BNCF it
# BNCF fr
# Biblioteca nazionale centrale di Firenze fr
# BNCF pt-br
# Biblioteca Nazionale Centrale di Firenze pt-br
# Biblioteca Nazionale Centrale di Firenze ast
# 플로란스 국립중앙도서관 ko
# المكتبة الوطنية المركزية بفلورسنا ar
# BNCF nn
# Нацыянальная цэнтральная бібліятэка be
# BNCF en
# Biblioteca Nazionale Centrale di Firenze en
# Biblioteca Nazionale Centrale en
# Nationale Centrale Bibliotheek van Florence nl
# engelsk Wikipedia nb
# engelskspråklig Wikipedia nb
# https://en.wikipedia.org nb
# en.wikipedia.org fr
# enwiki fr
# enwp fr
# wp:en fr
# Wikipedia en anglais fr
# https://en.wikipedia.org fr
# wiki anglais fr
# enwp es
# enwiki es
# WPEN es
# WP-EN es
# WP EN es
# Wikipedia en ingles es
# https://en.wikipedia.org es
# ENWP en
# English-language Wikipedia en
# Wikipedia in English en
# Wikipedia (en) en
# enwiki en
# en.wikipedia.org en
# en.wp en
# en.Wikipedia en
# enwp en
# https://en.wikipedia.org en
# en wiki en
# English wikipedia en
# Англомовна Вікіпедія uk
# https://en.wikipedia.org uk
# Wikipédia anglófona pt
# https://en.wikipedia.org pt
# anglická jazyková verze Wikipedie cs
# anglická verze Wikipedie cs
# enwiki cs
# Anglická Wikipedie cs
# enwiki en-gb
# ENWP en-gb
# English-language Wikipedia en-gb
# Wikipedia in English en-gb
# Wikipedia (en) en-gb
# en.wikipedia.org en-gb
# en.Wikipedia en-gb
# en.wp en-gb
# https://en.wikipedia.org en-gb
# enwiki en-ca
# En.wikipedia.org en-ca
# En.Wikipedia en-ca
# ENWP en-ca
# English-language Wikipedia en-ca
# Enwiki en-ca
# Wikipedia in English en-ca
# Wikipedia (en) en-ca
# https://en.wikipedia.org en-ca
# en: vi
# Wikipedia Anh ngữ vi
# englische Wikipedia de
# enwiki de
# en.wikipedia.org de
# https://en.wikipedia.org de
# Wikipedia auf englisch de
# enWP de
# enwiki hu
# https://en.wikipedia.org hu
# en.wiki it
# enwiki it
# Wikipedia Inglese it
# https://en.wikipedia.org it
# англовики ru
# енвики ru
# ен-вики ru
# enwiki ru
# enwp ru
# https://en.wikipedia.org ru
# АВП ru
# ଇଂରାଜୀ ୱିକିପିଡ଼ିଆ or
# https://en.wikipedia.org or
# 英语维基百科 zh
# 英文维基百科 zh
# 英语维基 zh
# 英文维基 zh
# https://en.wikipedia.org zh
# en-WP nl
# https://en.wikipedia.org nl
# 英文维基百科 zh-hans
# 英维 zh-hans
# en区 zh-hans
# https://en.wikipedia.org zh-hans
# enwiki ast
# Wikipedia (en) ast
# https://en.wikipedia.org ast
# Ағылшын тіліндегі Уикипедия kk
# https://en.wikipedia.org kk
# Wikipedia angleze sq
# Wikipedia á enskum fo
# https://en.wikipedia.org fo
# 영위백 ko
# 영어위백 ko
# 영어 위백 ko
# 위키백과 영어판 ko
# 영어판 위키백과 ko
# Wikipedya nan angle ht
# Wikipedya ann angle ht
# https://en.wikipedia.org ht
# англовики tg
# enwiki tg
# ен-вики tg
# енвики tg
# enwp tg
# https://en.wikipedia.org tg
# ವಿಕಿಪೀಡಿಯ kn
# :kn kn
# https://en.wikipedia.org kn
# ангельская Вікіпэдыя be-tarask
# ウィキペディア英語版 ja
# https://en.wikipedia.org ja
# enwiki ja
# enwp ja
# en.wikipedia.org ja
# en wiki ja
# ENWP ja
# en:wikipedia.ogg tcy
# ವಿಕಿಪೀಡಿಯೊ tcy
# :tcy tcy
# енглеска Википедија sr
# Википедија на енглеском sr
# ENWP sr
# English-language Wikipedia sr
# English Wikipedia sr
# Wikipedia in English sr
# Wikipedia (en) sr
# enwiki sr
# en.wikipedia.org sr
# en.wp sr
# en.Wikipedia sr
# :en sr
# enwp sr
# enwikipedia sr
# https://en.wikipedia.org sr
# 維基大典諸語文最盛者 lzh
# https://en.wikipedia.org lzh
# הוויקיפדיה האנגלית he
# ויקיפדיה באנגלית he
# https://en.wikipedia.org he
# Wikipedia engleză ro
# https://en.wikipedia.org ro
# enwiki ms
# enwikipedia ms
# en.wikipedia.org ms
# https://en.wikipedia.org ms
# en.wikipedia.org ace
# enwiki ace
# enwp ace
# https://en.wikipedia.org ace
# en.wikipedia.org id
# enwikipedia id
# enwiki id
# enwp id
# https://en.wikipedia.org id
# en.wikipedia.org jv
# enwikipedia jv
# enwiki jv
# enwp jv
# https://en.wikipedia.org jv
# en.wikipedia.org su
# enwikipedia su
# enwiki su
# enwp su
# https://en.wikipedia.org su
# en.wikipedia.org min
# enwikipedia min
# enwiki min
# enwp min
# https://en.wikipedia.org min
# en.wikipedia.org bjn
# enwikipedia bjn
# enwiki bjn
# enwp bjn
# ويكيبيديا الإنغليزية ar
# ويكيبيديا الإنكليزية ar
# ويكيبديا الإنغليزية ar
# ويكيبيديا الإنجليزيه ar
# ويكيبيديا الانجليزية ar
# https://en.wikipedia.org ar
# enwiki pl
# https://en.wikipedia.org pl
# Wikipedia angielskojęzyczna pl
# engelskspråkleg Wikipedia nn
# den engelske wikipediaen nn
# https://en.wikipedia.org nn
# https://en.wikipedia.org th
# ENWP th
# English-language Wikipedia th
# en.wp th
# en.Wikipedia th
# enwiki th
# https://en.wikipedia.org af
# https://en.wikipedia.org as
# https://en.wikipedia.org az
# https://en.wikipedia.org bar
# https://en.wikipedia.org be
# https://en.wikipedia.org bg
# https://en.wikipedia.org br
# https://en.wikipedia.org bs
# https://en.wikipedia.org bxr
# https://en.wikipedia.org ca
# https://en.wikipedia.org ce
# https://en.wikipedia.org da
# https://en.wikipedia.org de-ch
# https://en.wikipedia.org eu
# https://en.wikipedia.org fa
# https://en.wikipedia.org frr
# https://en.wikipedia.org fy
# https://en.wikipedia.org hsb
# https://en.wikipedia.org ku
# https://en.wikipedia.org la
# https://en.wikipedia.org lb
# https://en.wikipedia.org sa
# https://en.wikipedia.org sc
# https://en.wikipedia.org sgs
# https://en.wikipedia.org sh
# https://en.wikipedia.org sk
# https://en.wikipedia.org sl
# https://en.wikipedia.org sw
# https://en.wikipedia.org ta
# https://en.wikipedia.org tg-cyrl
# https://en.wikipedia.org uz
# https://en.wikipedia.org vep
# https://en.wikipedia.org vo
# https://en.wikipedia.org wuu
# https://en.wikipedia.org xmf
# https://en.wikipedia.org yue
# https://en.wikipedia.org zh-cn
# https://en.wikipedia.org zh-hant
# https://en.wikipedia.org zh-hk
# https://en.wikipedia.org zh-mo
# https://en.wikipedia.org zh-my
# https://en.wikipedia.org zh-sg
# https://en.wikipedia.org zh-tw
# https://en.wikipedia.org nds
# https://en.wikipedia.org nds-nl
# https://en.wikipedia.org ne
# https://en.wikipedia.org pa
# https://en.wikipedia.org pih
# https://en.wikipedia.org pt-br
# https://en.wikipedia.org sv
# enwp sv
# https://en.wikipedia.org tr
# https://en.wikipedia.org ckb
# https://en.wikipedia.org cv
# https://en.wikipedia.org cy
# https://en.wikipedia.org diq
# https://en.wikipedia.org el
# https://en.wikipedia.org eo
# https://en.wikipedia.org et
# https://en.wikipedia.org fi
# https://en.wikipedia.org ga
# https://en.wikipedia.org gl
# https://en.wikipedia.org gu
# https://en.wikipedia.org hak
# https://en.wikipedia.org haw
# https://en.wikipedia.org hi
# https://en.wikipedia.org hr
# engleska Wikipedija hr
# https://en.wikipedia.org hy
# https://en.wikipedia.org ig
# https://en.wikipedia.org ilo
# https://en.wikipedia.org is
# https://en.wikipedia.org ka
# https://en.wikipedia.org km
# https://en.wikipedia.org lrc
# https://en.wikipedia.org lt
# https://en.wikipedia.org lv
# https://en.wikipedia.org map-bms
# https://en.wikipedia.org mk
# https://en.wikipedia.org ml
# https://en.wikipedia.org mn
# https://en.wikipedia.org mr
# इंग्रजी विकिपीडिया mr
# https://en.wikipedia.org mzn
# https://en.wikipedia.org nan
# https://en.wikipedia.org oc
# https://en.wikipedia.org roa-tara
# https://en.wikipedia.org scn
# https://en.wikipedia.org sco
# https://en.wikipedia.org sd
# https://en.wikipedia.org sr-ec
# https://en.wikipedia.org te
# https://en.wikipedia.org tt
# https://en.wikipedia.org tt-cyrl
# https://en.wikipedia.org udm
# https://en.wikipedia.org ur
# eaŋgalsgielat Wikipedia se
# Freebase Data Dumps pt
# Dumps de Dados do Freebase pt
# дамп базы Freebase ru
# Google Freebase Data Dumps en
# Google Knowledge Graph Data Dumps en
# Google Freebase数据转储 zh-hans
# Google知识图谱数据转储 zh-hans
# Google Knowledge Graph de
# آزاد پایه fa
# Google Freebase Data Dump ja
# Dumps de Dados do Freebase pt-br
# Google Freebase Data Dumps pt-br
# Freebase Data Dumps pt-br
# Dumps de Dados do Google Freebase pt-br
# মুক্তভিত উপাত্ত আবরজনা bn
# 谷歌知识图谱数据转储 zh
# 谷歌Freebase数据转储 zh
# Google Knowledge Graph el
# Google Freebase Data Dumps el
# Google Freebase Data Dumps id
# Google Knowledge Graph Data Dumps id
# Freebase Data Dumps ast
# Freebase Data Dumps nb
# 德文維基百科 zh
# 德語維基 zh
# Alemanierazko Wikipedia eu
# Wikipedia en aleman es
# De wikipedia org es
# De.wikipedia.org es
# செருமன் விக்கிப்பீடியா ta
# Saksa vikipeedia et
# Wikipedia på tyska sv
# ويكيبيديا الألمانيه ar
# Duitse Wikipedia nl
# Wikipédia germânica pt
# Wikipédia alemã pt
# Germana vikipedio eo
# Германоязычная википедия ru
# Немецкоязычная википедия ru
# Раздел Википедии на немецком языке ru
# dewp ru
# dewiki ru
# Њемачка Википедија sr
# Википедија на њемачком језику sr
# Немачка википедија sr
# ویکیپیدیا ئاڵمانی ckb
# Deutschsprachige Wikipedia fr
# Wikipedia en allemand fr
# Dewiki fr
# De.wikipedia.org fr
# wp:de fr
# WP DE fr
# dewp fr
# ויקיפדיה בגרמנית he
# Vācu valodas Vikipēdija lv
# Vācu Vikipēdija lv
# de.wiki it
# Wikipedia in deutscher Sprache de
# Wikipedia auf Deutsch de
# de.wikipedia.org de
# dewiki de
# deutsche Wikipedia de
# https://de.wikipedia.org de
# 德語維基百科 yue
# Njemačka Vikipedija sh
# Nemačka Vikipedija sh
# Güiquipeya en alemán ext
# วิกิพีเดียเยอรมัน th
# Wikipedia en alemany ca
# Germanijan Vikipedii vep
# Německá jazyková verze Wikipedie cs
# ویکی‌پدیای المانی fa
# ویکی پدیای آلمانی fa
# Немска Уикипедия bg
# Vokiška vikipedija lt
# 德文维基百科 zh-hans
# 德语维基 zh-hans
# 德文維基百科 zh-hant
# 德語維基 zh-hant
# 德文维基百科 zh-cn
# 德语维基 zh-cn
# 德文维基百科 zh-sg
# 德语维基 zh-sg
# 德文维基百科 zh-my
# 德语维基 zh-my
# 德文維基百科 zh-hk
# 德語維基 zh-hk
# 德文維基百科 zh-tw
# 德語維基 zh-tw
# 德文維基百科 zh-mo
# 德語維基 zh-mo
# Dewiki en
# dewiki en
# de.wikipedia en
# de.wikipedia.org en
# Wikipedia (de) en
# deWP en
# dewp en
# dewikipedia en
# German-language Wikipedia en
# wikipedia.de en
# German language Wikipedia en
# ଜର୍ମାନ ୱିକିପିଡ଼ିଆ or
# dewiki hu
# dewiki ast
# Wikipedia á týskum fo
# němskorěčna Wikipedija hsb
# Wikipedia Đức ngữ vi
# de.wikipedia.org ace
# dewikipedia ace
# dewiki ace
# dewp ace
# de.wikipedia.org id
# dewikipedia id
# dewiki id
# dewp id
# de.wikipedia.org jv
# dewikipedia jv
# dewiki jv
# dewp jv
# de.wikipedia.org su
# dewikipedia su
# dewiki su
# dewp su
# de.wikipedia.org min
# dewikipedia min
# dewiki min
# dewp min
# de.wikipedia.org bjn
# dewikipedia bjn
# dewiki bjn
# dewp bjn
# dewiki uk
# de.wikipedia uk
# німецькомовна Вікіпедія uk
# розділ Вікіпедії німецькою uk
# німвікі uk
# njemačka Wikipedija hr
# dewiki hr
# 呼吸學 zh
# Neumologia eu
# ftyzjatra pl
# pneumonologia pl
# ftyzjatria pl
# pulmunologia pl
# 호흡기학 ko
# 호흡기과 ko
# neumológico es
# pulmonología es
# Pneumonologie de
# Pulmologie de
# Pulmonologie de
# Lungenheilkunde de
# 呼吸器内科 ja
# 呼吸器病学 ja
# 呼吸器科 ja
# Pulmologjia sq
# طب الأمراض الصدرية ar
# طب الصدرية ar
# pneumologie nl
# pulmologie nl
# Tisiologia pt
# Pneŭmologio eo
# Pulmonologio eo
# Pulmologio eo
# Pulmonoloji tr
# пульмонолог uk
# пнэўмалёгія be-tarask
# Pneumonologie cs
# طب ریوی ur
# Pulmonology ur
# طب پھیپھڑی ur
# Respirology ur
# pneumologi da
# pulmonologi da
# respirologi da
# luftvejsmedicin da
# pneumonology en
# respiratory medicine en
# respirology en
# pulmonary medicine en
# medicina pulmonar ast
# lungemedisin nn
# lungsjukdom sv
# lungemedisin nb
# pnevmonologiya az
# respirologiya az
# pneumonologia fi
# keuhko-oppi fi
# keuhkosairausoppi fi
# 免疫学 zh
# immunologia weterynaryjna pl
# Inmunologia eu
# Immunología es
# Immunologia es
# Serologico es
# Inmunologia es
# علم المناعه ar
# Immunology ar
# Clinical immunology ar
# Imunoscienco eo
# İmmunoloji tr
# Bağışıklık bilimi tr
# immunologi fi
# 면역학자 ko
# תורת החיסון he
# אימיונולוגיה he
# אימונוביולוגיה he
# Immunologique fr
# Immunobiologie fr
# immunologico it
# Immunbiologie de
# Immunchemie de
# Immunpathologie de
# Medizinische Mikrobiologie: Immunologie de
# Immunologi id
# Immunology id
# miễn nhiễm học vi
# प्रतिरक्षाविज्ञान hi
# इम्म्युनोलॉजी hi
# इम्म्यूनोलॉजी hi
# इम्यूनोलॉजी hi
# इम्युनोलॉजी hi
# วิทยาอิมมูน th
# ภูมิคุ้มกันวิทยา th
# Immunology th
# Immunològica ca
# Immunopatologia ca
# Immuno ca
# Immunoquímica ca
# Immunologia clínica ca
# Immunogenètica ca
# ایمنی شناسی fa
# ایمونولوژی fa
# Имунолог bg
# Klinische Immunologie nds
# Immunbiologie nds
# Immunchemie nds
# Immunpathologie nds
# Generell immunologi nb
# Allergy and Immunology en
# Immunology en
# inmunolohiya tl
# bronchial spasm en
# Bronchospasm en
# disease of bronchus en
# disorder of bronchus en
# bronchus disease en
# bronchial disease en
# espasmo bronquial es
# bronkiespasme nn
# бранхіяльная спазма be-tarask
# 支气管痉挛 zh
# DO en
# جوهره‌شناسی بیماری‌ها fa
# DO nl
# Disease Ontology es
# DO es
# Ontologia de enfermedades es
# DO nn
# 疾病本体库 zh
# 疾病本體庫 zh
# DO uk
# Онтологія хвороб uk
# es.wikipedia.org fr
# eswiki fr
# Wikipedia en espagnol fr
# wp:es fr
# ESWIKI en
# Spanish language Wikipedia en
# esWP en
# eswp en
# eswikipedia en
# eswiki en
# es.wikipedia.org en
# es.wikipedia en
# Spanish-language Wikipedia en
# eswiki de
# spanische Wikipedia de
# spansk Wikipedia nb
# spanskspråklig Wikipedia nb
# Viquipèdia en castellà ca
# eswiki ca
# esWP ca
# Википедия на испанском языке ru
# es.wiki it
# esWiki es
# eswiki es
# es-Wikipedia es
# Eswiki es
# eswiki ast
# Wikipedia n'español ast
# hispana Vikipedio eo
# kastililingva Vikipedio eo
# Wikipedia á sponskum fo
# স্প্যানিশ উইকিপিডিয়া bn
# es.wikipedia.org ace
# eswikipedia ace
# eswiki ace
# eswp ace
# es.wikipedia.org id
# eswikipedia id
# eswiki id
# eswp id
# es.wikipedia.org jv
# eswikipedia jv
# eswiki jv
# eswp jv
# es.wikipedia.org su
# eswikipedia su
# eswiki su
# eswp su
# es.wikipedia.org min
# eswikipedia min
# eswiki min
# eswp min
# es.wikipedia.org bjn
# eswikipedia bjn
# eswiki bjn
# eswp bjn
# Spaanse Wikipedia nl
# Bichipedia in ispagnola sc
# eswiki yi
# eswiki hr
# španjolska Wikipedija hr
# eswiki bs
# es.wiki bs
# Formoterolo it
# C19H24N2O4 it
# FOR258 en
# BD-40A en
# CGP-25827A en
# Foradil® en
# Oxeze/Oxis® en
# YM-08316 en
# 2'-hydroxy-5'-{1-hydroxy-2-[(p-methoxy-alpha-methylphenethyl)amino]ethyl}formanilide en
# N-[2-hydroxy-5-(1-hydroxy-2-{[2-(4-methoxyphenyl)-1-methylethyl]amino}ethyl)phenyl]formamide en
# 2'-hydroxy-5'-(1-hydroxy-2-((p-methoxy-alpha-methylphenethyl)amino)ethyl)formanilide en
# Foster en
# N-[2-Hydroxy-5-(1-hydroxy-2-{[2-(4-methoxyphenyl)-1-methylethyl]amino}ethyl)phenyl]formamide en
# Formoterol en
# 2'-Hydroxy-5'-{1-hydroxy-2-[(P-methoxy-alpha-methylphenethyl)amino]ethyl}formanilide en
# 2'-Hydroxy-5'-(1-hydroxy-2-((P-methoxy-alpha-methylphenethyl)amino)ethyl)formanilide en
# Formoterolum en
# YM-08316 cy
# Oxeze/Oxis® cy
# N-[2-hydroxy-5-(1-hydroxy-2-{[2-(4-methoxyphenyl)-1-methylethyl]amino}ethyl)phenyl]formamide cy
# Foradil® cy
# CGP-25827A cy
# BD-40A cy
# 2'-hydroxy-5'-{1-hydroxy-2-[(p-methoxy-alpha-methylphenethyl)amino]ethyl}formanilide cy
# 2'-hydroxy-5'-(1-hydroxy-2-((p-methoxy-alpha-methylphenethyl)amino)ethyl)formanilide cy
# Foster cy
# National Drug File Reference Terminology en
# National Drug File Reference Terminology nn
# инглисӣ tg
# англисӣ tg
# забони англисӣ tg
# Eng-bûn nan
# 英文 nan
# Eng-gú nan
# ENG fr
# en fr
# langue anglaise fr
# angl fr
# अंग्रेजी भाषा hi
# अंग्रेजी hi
# 英文 zh
# lingua inglese it
# basa Inggris jv
# انگريزي sd
# englannin kieli fi
# English language en-ca
# en en-ca
# English uk
# en uk
# bahasa Inggris id
# Gjuha angleze sq
# idioma inglês pt
# linguagem inglesa pt
# língua inglesa pt
# lingua anglese ia
# ਅੰਗਰੇਜ਼ੀ ਬੋਲੀ pa
# ਅੰਗਰੇਜੀ pa
# ਅੰਗ੍ਰੇਜੀ pa
# ਗ੍ਰੇਜੀ pa
# òyìnbó yo
# èdè òyìnbó yo
# èdè gẹ̀ẹ́sì yo
# انگلیسی fa
# Wikang Ingles tl
# 英文 zh-tw
# en es
# lengua inglesa es
# idioma inglés es
# angielski pl
# en pl
# 英文 zh-hant
# angol nyelv hu
# engelska språket sv
# englische Sprache de
# engl. de
# en de
# lingua ngrisa scn
# ingrisi scn
# Pamyalitang Ingles pam
# Pamialitang Ingles pam
# αγγλική γλώσσα el
# English el
# لغة إنجليزية ar
# اللغة الإنكليزية ar
# الإنكليزية ar
# اللغة الإنجليزية ar
# اللغة إنكليزية ar
# en eu
# ingeles hizkuntza eu
# língua inglesa pt-br
# ಇಂಗ್ಲೀಷ್ kn
# English language en
# en en
# eng en
# (en) en
# English (en) en
# llingua inglesa ast
# îngilîzî ku
# tiếng Mỹ vi
# tiếng Mĩ vi
# jendźelska rěč hsb
# en da
# eng da
# инглизчә tt
# ингл. tt
# English tt-latn
# anglicky cs
# angl. cs
# angleški jezik sl
# jenźelšćina dsb
# engleză ro
# engleza ro
# English ro
# en ro
# eng ro
# англійская мова be-tarask
# анґельская мова be-tarask
# en gl
# inglés gl
# englesch Sprooch lb
# English language en-gb
# en en-gb
# инглизчә tt-cyrl
# ингл. tt-cyrl
# اللوغة الإنڨليزية aeb-arab
# အင်္ဂလိပ်ဘာသာစကား my
# Englische Schprooch pdc
# 英語 yue
# 英吉利文 yue
# 英吉利話 yue
# 英吉利語 yue
# ఇంగ్లీషు te
# ఆంగ్ల భాష te
# енглески sr
# en sr
# eng sr
# енгл. sr
# енг. sr
# en ca
# llengua anglesa ca
# idioma anglès ca
# anglés ca
# idioma anglés ca
# Lulwimi lweSingisi ss
# eŋgelasgiella se
# eaŋgalasgiella se
# Engelse taal nl
# English nl
# en nl
# ENG nl
# eng nl
# English language nl
# Tataramon na Ingles bcl
# BI ms
# B.I. ms
# İngilizce dili tr
# en tr
# eng tr
# EN tr
# ENG tr
# ingiliscə az
# Béarla ga
# Lengua nglese nap
# ߊ߲߬ߜ߭ nqo
# En nqo
# englisch bar
# engl. bar
# زمانی ئینگلیزی ckb
# ئینگلیسی ckb
# 英吉利語 ja
# 英吉利語 lzh
# 英文 lzh
# lingua Anglica la
# lingua inglese co
# Ingelske taal fy
# новоанглийский язык ru
# англ. ru
# En dag
# Harshen turanci ha
# lingwa Ingliża mt
# l-Ingliż mt
# en mt
# Ағылшынша kk
# ағылш. kk
# Тролеандаміцын be-tarask
# Трыяцэтылолеандаміцын be-tarask
# 竹桃霉素三乙酸酯 zh
# TAO en
# Triacetyloleandomycin en
# Troleandomycin en
# Tribiocillina en
# Oleandocetine en
# Oleandomycin triacetyl ester en
# Oleandomycin triacetate en
# ترولياندومايسين ar
# Troleandomycin cy
# Tribiocillina cy
# Triacetyloleandomycin cy
# Oleandomycin triacetyl ester cy
# Oleandomycin triacetate cy
# Oleandocetine cy
# TAO cy
# C31H33N3O6S1 it
# Accolate® en
# ICI-204219 en
# 4-(5-cyclopentyloxycarbonylamino-1-methyl-1H-indol-3-ylmethyl)-3-methoxy-N-o-tolylsulfonylbenzamide en
# cyclopentyl 3-(2-methoxy-4-((o-tolylsulfonyl)carbamoyl)benzyl)-1-methylindole-5-carbamate en
# 4-(5-Cyclopentyloxycarbonylamino-1-methyl-1H-indol-3-ylmethyl)-3-methoxy-N-O-tolylsulfonylbenzamide en
# ICI-204,219 en
# Cyclopentyl 3-(2-methoxy-4-((O-tolylsulfonyl)carbamoyl)benzyl)-1-methylindole-5-carbamate en
# Zafirlukast en
# ZD9188 en
# zafirlukaste pt-br
# zafirlukast pt-br
# Zafirlukast uk
# Accolate® uk
# זפירלוקאסט uk
# ICI-204219 cy
# cyclopentyl 3-(2-methoxy-4-((o-tolylsulfonyl)carbamoyl)benzyl)-1-methylindole-5-carbamate cy
# Accolate® cy
# 4-(5-cyclopentyloxycarbonylamino-1-methyl-1H-indol-3-ylmethyl)-3-methoxy-N-o-tolylsulfonylbenzamide cy
# Choledyl SA en
# Oxtriphylline Pediatric en
# Choledyl en
# Theophyline - choline mixt en
# Theocolin en
# Choline theophyllinate en
# Choline theophylline en
# Theophyline - choline mixt cy
# Theocolin cy
# Oxtriphylline Pediatric cy
# Choline theophylline cy
# Choline theophyllinate cy
# Choledyl SA cy
# Choledyl cy
# okstryfilina pl
# Sulfato de salbutamol pt
# 벤톨린 ko
# 34391-04-3 fr
# 18559-94-9 fr
# 34271-50-6 fr
# אירומיר he
# אלבוטרול he
# סולטנול he
# סלמול he
# ונטולין he
# אסתלין he
# סלבוטאמול he
# אסמול he
# אסטלין he
# סלבוטמול he
# נטולין he
# פרוונטיל he
# בוונטול he
# ולמקס he
# Саламол ru
# Астахалин ru
# Циклокапс ru
# Асталин ru
# Сальгим ru
# Альбутерол ru
# Цибутол ru
# Сальбен ru
# Вентолин ru
# Вентокол ru
# Ventolin es
# Asthalin es
# ProAir es
# Ventolín es
# Albuterol es
# Proventil es
# Salbutamolisulfaatti fi
# Albuterolo it
# C13H21NO3 it
# Salbutamolsulfat de
# Sultanol de
# Albuterol de
# サルタノール インヘラー ja
# サルタノールインヘラー ja
# 硫酸サルブタモール ja
# Ventolin nl
# Albuterol nl
# Cyclocaps nl
# فنتولين ar
# Ventolin ar
# سالبيوتومول ar
# BTA204 en
# albuterol en
# SCH-13949W en
# Salbutamol en
# Albuterol en
# (±)-salbutamol en
# 151-67-7 fr
# C2HBrClF3 fr
# Фторотан ru
# C2HBrClF3 it
# CF3-CHClBr it
# 2-Brom-2-chlor-1,1,1-trifluorethan de
# Halon-2311 de
# 2-brom-2-chlor-1,1,1-trifluorethan cs
# Halothan cs
# 2-brom-2-chlor-1,1,1-trifluoretan cs
# Fluothane cs
# Halothane ur
# ہيلوتھين ur
# Fluothane sv
# الهالوثان ar
# Rhodialothan en
# Fluothane en
# 2-bromo-2-chloro-1,1,1-trifluoroethane en
# 2,2,2-trifluoro-1-chloro-1-bromoethane en
# 1-bromo-1-chloro-2,2,2-trifluoroethane en
# 1,1,1-trifluoro-2-chloro-2-bromoethane en
# 1,1,1-trifluoro-2-bromo-2-chloroethane en
# bromochlorotrifluoroethane en
# Phthorothanum en
# Narcotane en
# Halon-2311 en
# Rhodialothan cy
# Phthorothanum cy
# Narcotane cy
# Fluothane® cy
# Fluothane cy
# bromochlorotrifluoroethane cy
# 2,2,2-trifluoro-1-chloro-1-bromoethane cy
# 2-bromo-2-chloro-1,1,1-trifluoroethane cy
# 1,1,1-trifluoro-2-chloro-2-bromoethane cy
# 1,1,1-trifluoro-2-bromo-2-chloroethane cy
# Bricanyl pt
# Bricanyl de
# Terbutalinsulfat de
# 23031-25-6 fr
# 23031-32-5 fr
# Terbasmin es
# Bricanyl da
# Brethine® en
# Bricanyl® en
# KWD-2019 en
# terbutalin en
# Terbutaline (sulfate de) en
# Terbutalini sulfas en
# Terbutaline en
# Terbutalin en
# Terbutalinum en
# Terbutalina en
# Terbutalinsulfat en
# terbutalin cy
# KWD-2019 cy
# Bricanyl® cy
# Brethine® cy
# Aminophylline ml
# امینوفیلین fa
# أمينوفللين ar
# Aminophylline sr
# ATC kod R03DA05 sr
# ATCvet kod QR03DA05 sr
# Aminocardol sr
# Aminodur sr
# Aminophyllin sr
# Ammophyllin sr
# C16H24N10O4 sr
# Cardiofilina sr
# Cardiomin sr
# Cardophylin sr
# Cardophyllin sr
# Carena sr
# Cariomin sr
# Diaphylline sr
# Diophllin sr
# Diuxanthine sr
# Dobo sr
# Ethophylline sr
# Eurphyllin sr
# Euufillin sr
# Genophyllin sr
# Grifomin sr
# Inophylline sr
# Lasodex sr
# Linampheta sr
# Lixaminol sr
# Metaphyllin sr
# Metaphylline sr
# Methophylline sr
# Minaphil sr
# Miofilin sr
# Neophyiline sr
# Norofilina sr
# Peterphyllin sr
# Phylcardin sr
# Phyllindon sr
# Phyllocontin sr
# Rectalad Aminophylline sr
# Stenovasan sr
# Syntophyllin sr
# Theodrox sr
# Theolamine sr
# Theolone sr
# Theophyldine sr
# Theophyllaminum sr
# Thephyldine sr
# Truphylline sr
# Variaphylline sr
# Vasofilina sr
# aminophilline en
# Somophyllin en
# Truphylline en
# Phyllocontin en
# Peterphyllin en
# Aminophylline Dye Free en
# Aminophylline In Sodium Chloride en
# Somophyllin-Df en
# Ammophyllin en
# Aminophyllin en
# Theophylline ethylenediamine en
# Aminophylline en
# Truphylline cy
# Theophylline ethylenediamine cy
# Somophyllin-Df cy
# Somophyllin cy
# Phyllocontin cy
# Peterphyllin cy
# Ammophyllin cy
# Aminophylline In Sodium Chloride cy
# Aminophylline Dye Free cy
# Aminophyllin cy
# ATC kod R03AC17 sr
# ATCvet kod QR03AC17 sr
# Bitolterol mesylate sr
# C28H31NO5 sr
# Tornalate sr
# Tornalat sr
# Bitolterol Mesylate en
# Bitolterolum en
# 4-[2-(tert-butylamino)-1-hydroxyethyl]-o-phenylene di-p-toluate en
# bis(4-methylbenzoic acid) 4-[2-(tert-butylamino)-1-hydroxyethyl]-1,2-phenylene ester en
# 4-(2-(tert-butylamino)-1-hydroxyethyl)-o-phenylene di-p-toluate en
# Bitolterol en
# Bitolterolum cy
# Bitolterol Mesylate cy
# bis(4-methylbenzoic acid) 4-[2-(tert-butylamino)-1-hydroxyethyl]-1,2-phenylene ester cy
# 4-[2-(tert-butylamino)-1-hydroxyethyl]-o-phenylene di-p-toluate cy
# 4-(2-(tert-butylamino)-1-hydroxyethyl)-o-phenylene di-p-toluate cy
# 麻黃素 zh
# 134-71-4 fr
# 299-42-3 fr
# Ephedrine fr
# Ephedrine lv
# Ephedrinum lv
# C10H15N1O1 it
# افدرین ps
# Ephedrine ps
# Ephedrinhydrochlorid de
# Ephedrin-Hemihydrat de
# 2-methylamino-1-phenyl-propan-1-ol de
# endrine nl
# ephedrine nl
# ephedronguent nl
# أفدرين ar
# Ephedrine ar
# الافدرين ar
# افدرين ar
# Franol pt
# Pseudoefedriini fi
# L(-)-ephedrine en
# L-erythro-2-(methylamino)-1-phenylpropan-1-ol en
# l-ephedrine en
# (-)-Ephedrine en
# (1R,2S)-1-Phenyl-1-hydroxy-2-methylaminopropane en
# L-erythro-2-(Methylamino)-1-phenylpropan-1-ol en
# L(−)-ephedrine en
# L-Ephedrine en
# Ephedrine en
# L(-)-ephedrine cy
# L-erythro-2-(methylamino)-1-phenylpropan-1-ol cy
# l-ephedrine cy
# Singulair de
# مونتهٔ لوکاست fa
# C35H36ClNO3S fr
# 158966-92-8 fr
# C35H36N1O3S1 it
# Singulair nb
# Singulair® en
# Montelukast en
# (R-(e))-1-(((1-(3-(2-(7-Chloro-2-quinolinyl)ethenyl)phenyl)-3-(2-(1-hydroxy-1-methylethyl)phenyl)propyl)thio)methyl)cyclopropaneacetic acid en
# Montelukastum en
# Montélukast en
# 1-[[[(1 R)-1-[3-[(1e)-2-(7-chloro-2-Quinolinyl)ethenyl] phenyl]-3-[2-(1-hydroxy-1-methylethyl)phenyl]propyl]sulfanyl]methyl]cyclopropaneacetic acid en
# Singulair pt
# Montelucaste pt
# Мілукант uk
# Singulair® uk
# Montelukast uk
# Алмонт uk
# Singulair® cy
# Montelukast cy
# Atmadisc de
# Seretide de
# Salmeterolxinafoat de
# aliflus de
# セレベント ja
# Serevent nl
# Seretide nl
# GR 33343X en
# Serevent® en
# Salmeterolum en
# Salmeterol en
# Salmaterol en
# A-64077 en
# ZYFLO® en
# Leutrol en
# N-(1-Benzo(b)thien-2-ylethyl)-N-hydroxyurea en
# N-[1-(benzo[b]thiophen-2-yl)ethyl]-N-hydroxyurea en
# (+-)-1-(1-Benzo[b]thien-2-ylethyl)-1-hydroxyurea en
# Zileuton en
# N-[1-(Benzo[b]thiophen-2-yl)ethyl]-N-hydroxyurea en
# Zileutonum en
# Zileuton es
# ZYFLO® cy
# Zileuton cy
# N-[1-(benzo[b]thiophen-2-yl)ethyl]-N-hydroxyurea cy
# N-(1-Benzo(b)thien-2-ylethyl)-N-hydroxyurea cy
# Leutrol cy
# A-64077 cy
# (+-)-1-(1-Benzo[b]thien-2-ylethyl)-1-hydroxyurea cy
# C12H20N2O3 it
# CP-24314-1 en
# CP-24314-14 en
# CP-2431414 en
# Maxair® en
# Pirbuterol en
# Pirbuterolum en
# (+/-)-pirbuterol en
# Maxair® cy
# CP-2431414 cy
# CP-24314-14 cy
# CP-24314-1 cy
# Diméthylxanthine fr
# 58-55-9 fr
# Theophylline fr
# Teofílina es
# 1,3-Dimethyl-xanthin de
# Bronchoparat de
# テオドール ja
# Nuelin sr
# Theocontin sr
# Slo-bid sr
# Physpan sr
# Dimethylxanthine sr
# Theolair sr
# Uniphyl sr
# Euphylline sr
# Telb-DS sr
# Theal Tablets sr
# Theochron sr
# Unidur sr
# Tefamin sr
# Armophylline sr
# Theona P sr
# ATCvet kod QR03DA04 sr
# Teofilina ca
# 1,3-dimetyyliksantiini fi
# Teofyliini fi
# 3,7-dihydro-1,3-dimetyyli-1H-puriini-2,6-dioni fi
# Dimetylxantin cs
# Teofylin cs
# Dimethylxantin cs
# Theophylin cs
# Theophyllin cs
# tefoliino eo
# Nuelin® en
# Slo-Bid® en
# Theolair® en
# 1,3-dimethyl-7H-purine-2,6-dione en
# Somophyllin-T en
# Theobid en
# Maphylline en
# Theophyl en
# Respbid en
# Nuelin en
# Elixophyllin en
# Theophyl-225 en
# Theona P en
# Theal tabl. en
# Medaphyllin en
# Uni-Dur en
# Theograd en
# Theovent en
# 1,3-dimethyl-2,3,6,7-tetrahydro-1H-purine-2,6-dione en
# Quibron-T en
# Theophyline en
# Theo-Dur en
# Quibron T/SR en
# Spophyllin retard en
# Theodel en
# Asmax en
# Tefamin en
# Theochron en
# Bronkodyl SR en
# Optiphyllin en
# Elixicon en
# Aquaphyllin en
# Elixomin en
# Teofyllamin en
# Euphylong en
# Theostat 80 en
# Teolair en
# Constant-T en
# Theocontin en
# Elixex en
# Accurbron en
# Parkophyllin en
# Theolair en
# Asbron en
# Aminophylline en
# T-Phyl en
# Choledyl SA en
# Theoclear LA en
# Xantivent en
# Theobid Jr. en
# Slo-Phyllin en
# Aerolate SR en
# Pseudotheophylline en
# Elixophylline en
# Theophylline-Sr en
# Armophylline en
# Doraphyllin en
# Theal tablets en
# Somophyllin-Crt en
# Theolixir en
# Elixophyllin SR en
# Austyn en
# Labid en
# Euphylline en
# Diphyllin en
# Quibron-T/Sr en
# Liquophylline en
# Aerolate III en
# Lanophyllin en
# Theolair-Sr en
# Theoclear-200 en
# Duraphyl en
# Uniphyl en
# Synophylate en
# Uniphyllin en
# Bronkodyl en
# Theacitin en
# Theofol en
# Theoclear-80 en
# Theolix en
# Theoclear 80 en
# Theo-Dur-Sprinkle en
# Slo-Bid en
# Aerolate en
# Xanthium en
# Theoclair-SR en
# Teofilina en
# Synophylate-L.A. Cenules en
# Sustaire en
# Solosin en
# Theoclear L.A.-130 en
# Unifyl en
# Theophyl-Sr en
# Somophyllin-DF en
# Acet-theocin en
# Theocin en
# Dyspne-Inhal en
# theophylline anhydrous en
# Theophylline en
# Theophylline, anhydrous en
# Theophylline anhydrous en
# Theophyllin en
# 1,3-dimethylxanthine en
# Optiphyllin cy
# Nuelin® cy
# Nuelin cy
# Medaphyllin cy
# Maphylline cy
# Liquophylline cy
# Lanophyllin cy
# Labid cy
# Euphylong cy
# Euphylline cy
# ephedra nn
# 麻黃 zh
# pseudoephedrine hydrochloride en
# pseudophedrine sulphate en
# Sinutab® en
# Sudafed® en
# (+)-(1S,2S)-Pseudoephedrine en
# trans-Ephedrine en
# d-psi-Ephedrine en
# d-psi-2-Methylamino-1-phenyl-1-propanol en
# d-Pseudoephedrine en
# d-Isoephedrine en
# Psi-ephedrine en
# Psi-ephedrin en
# L-(+)-Pseudoephedrine en
# L(+)-psi-Ephedrine en
# Isoephedrine en
# (+)-threo-Ephedrine en
# (+)-psi-Ephedrine en
# (+)-Pseudoephedrine en
# Pseudoephedrine en
# Pseudoephedrine D-form en
# 2-(Methylamino)-1-phenyl-1-propanol en
# (1S,2S)-Pseudoephedrine en
# (1S,2S)-(+)-Pseudoephedrine en
# D-Pseudoephedrine base en
# (+) threo-2-(methylamino)-1-phenyl-1-propanol en
# Pseudoephedrinum en
# pseudoéphédrine en
# ψ-ephedrine en
# Pseudoefedrina en
# 蘇達菲 zh
# pseudoefedrina hidroklorida id
# pseudoefedrina sulfat id
# trans-Efedrina id
# (+)-(1S,2S)-Pseudoefedrina id
# d-psi-Efedrina id
# L-(+)-Pseudoephedrine cy
# Isoephedrine cy
# d-psi-Ephedrine cy
# d-psi-2-Methylamino-1-phenyl-1-propanol cy
# D-Pseudoephedrine base cy
# d-Pseudoephedrine cy
# d-Isoephedrine cy
# 2-(Methylamino)-1-phenyl-1-propanol cy
# (1S,2S)-Pseudoephedrine cy
# (1S,2S)-(+)-Pseudoephedrine cy
# DNCG de
# Cromoglykat de
# Vividrin de
# kromoglikan pl
# kromoglikan dwusodowy pl
# 16110-51-3 fr
# Cromoglicate fr
# Cromoglicato de sodio es
# Acido cromoglicico es
# Chromoniclinezuur nl
# Nalcrom nl
# C23H16O11 it
# cromoglycate en
# FPL-670 en
# Intal® en
# Opticrom® en
# Cromoglicic acid en
# Cromoglicate en
# Cromoglycic acid en
# Acido Cromoglicico en
# Cromoglycate en
# Cromolyn en
# Acide Cromoglicique en
# Acidum Cromoglicicum en
# 5-[3-(2-carboxy-4-oxo-4H-5-chromenyloxy)-2-hydroxypropoxy]-4-oxo-4H-2-chromenecarboxylic acid en
# kromoglykat nn
# Opticrom® cy
# Intal® cy
# FPL-670 cy
# cromoglycate cy
# Cromoglicic acid cy
# Alupent de
# Орципреналина сульфат ru
# Metaproterenolo it
# Alupent® en
# TH-152 en
# orciprenaline en
# Metaproterenol en
# Orciprenaline en
# metaproterenol nn
# TH-152 cy
# orciprenaline cy
# Alupent® cy
# Betamethasonacetat de
# Betamethasonvalerat de
# Бетазон ru
# Кутерид ru
# Бетакортен ru
# Целедерм ru
# Флостерон ru
# Бетновейт ru
# Акридерм ru
# Белодерм ru
# Целестон ru
# Дипроспан ru
# Целестодерм-В ru
# Betamethasone fr
# 378-44-9 fr
# Célestène fr
# Bentelan it
# SCH-4831 en
# Rinderon en
# Betadexamethasone en
# 9alpha-Fluoro-16beta-methylprednisolone en
# 9-Fluoro-16beta-methylprednisolone en
# 16beta-Methyl-1,4-pregnadiene-9alpha-fluoro-11beta,17alpha,21-triol-3,20-dione en
# beta-Methasone alcohol en
# Betamethasonvalerat Mikron en
# Besamestazona en
# Betamethasone en
# 16β-Methyl-1,4-pregnadiene-9α-fluoro-11β,17α,21-triol-3,20-dione en
# 9α-Fluoro-16β-methylprednisolone en
# Betamethasonum en
# 9-Fluoro-16β-methylprednisolone en
# SCH-4831 cy
# Rinderon cy
# Betadexamethasone cy
# beta-Methasone alcohol cy
# 9alpha-Fluoro-16beta-methylprednisolone cy
# 9-Fluoro-16beta-methylprednisolone cy
# 16beta-Methyl-1,4-pregnadiene-9alpha-fluoro-11beta,17alpha,21-triol-3,20-dione cy
# betamethazon cs
# 美国食品药品监督局 zh
# 美國食品藥物管理局 zh
# 美国食品药物监督局 zh
# 食品及藥物管理局 zh
# 美国食品和药品管理局 zh
# 美国食品药物管理局 zh
# 美国食品药品管理局 zh
# 美國食品及藥物安全局 zh
# 美國食品藥品監督管理局 zh
# 美國食品及藥物管理局 zh
# 美国食品和药物管理局 zh
# 食品及藥物安全局 zh
# 美国联邦食品和药品管理局 zh
# 美国食品与药品管理局 zh
# 美國食品暨藥物管理局 zh
# 食品藥物管理機構 zh
# FDA eu
# Food and Drug Administration eu
# FDA pl
# Food and Drug Administration pl
# Fédération américaine des aliments et drogues fr
# United States Food and Drug Administration fr
# Food and drugs administration fr
# US Food and Drug Administration fr
# FDA fr
# U S Food and Drug Administration fr
# Food & Drug Administration fr
# Agence Fédérale américaine des produits alimentaires et médicamenteux fr
# FDA ko
# 미국식품의약국 ko
# 미국 FDA ko
# מנהל התרופות האמריקני he
# FDA he
# מנהל המזון והתרופות he
# מינהל המזון והתרופות האמריקני he
# מנהל המזון והתרופות האמריקני he
# מינהל המזון והתרופות האמריקאי he
# اداره الاغذيه والادويه الامريكيه arz
# U.S. Food and Drug Administration es
# Administración de Alimentos y Medicamentos de Estados Unidos es
# Administracion de Fármacos y Alimentos es
# Administración de Drogas y Alimentos de los EE.UU. es
# U S. Food and Drug Administration es
# Administracion de Drogas y Alimentos es
# Administración de Alimentos y Drogas es
# Administración de Fármacos y Alimentos es
# Administración de Drogas y Alimentos es
# Food and Drug Administration es
# FDA es
# Administración de Farmacos y Alimentos es
# U S Food and Drug Administration es
# Administracion de Alimentos y Medicamentos de Estados Unidos es
# Administración de Alimentos y Fármacos de EU es
# Agencia de Alimentos y Medicamentos es
# Agencia de Drogas y Alimentos es
# Administracion de Alimentos y Medicamentos es
# Administracion de Farmacos y Alimentos es
# Administracion de Drogas y Alimentos de los EE.UU. es
# Administracion de Alimentos y Drogas es
# Administracion de Alimentos y Farmacos de EU es
# Pentadbiran Makanan Dan Ubat-Ubatan ms
# FDA de
# FDA id
# Administrasi Makanan dan Obat-obatan id
# Food and Drug Administration id
# 連邦食品医薬品局 ja
# 米食品医薬品局 ja
# 米国食品医薬品局 ja
# アメリカ食料医薬品局 ja
# 食品医薬品局 ja
# 米国食品薬品局 ja
# アメリカ食品医薬局 ja
# FDA sv
# U. S. Food and Drug Administration sv
# U.S. Food and Drug Administration sv
# United States Food and Drug Administration sv
# FDA nl
# إف دي أيه ar
# إدارة الغذاء والدواء ar
# Food and Drug Administration ar
# إدارة الأغذية والأدوية الأمريكية ar
# FDA pt
# Food and drug administration pt
# Drug pt
# FDA sk
# Food and Drug Administration sk
# FDA ru
# Управление контроля качества продуктов и лекарств ru
# Управление по контролю качества продуктов и лекарств ru
# Food and Drug Administration ru
# FDA sr
# USFDA sr
# Food and Drug Administration sr
# Amerikan İlaç Gıda Dairesi tr
# Amerikan Gıda ve İlaç Dairesi tr
# Food and Drug Administration tr
# FDA ro
# FDA ca
# U.S. Food and Drug Administration ca
# USFDA ca
# Administració de Drogues i Aliments ca
# Food and Drug Administration ca
# Food and Drug Administration fi
# FDA sl
# Urad za prehrano in zdravila sl
# FDA cs
# Správa potravin a léčiv cs
# Food and Drug Administration cs
# ادارهٔ مواد دارویی و غذایی آمریکا fa
# اداره کل خوراک و داروی ایالات متحده fa
# ادارهٔ غذا و داروی ایالات متحدهٔ آمریکا fa
# اداره مواد غذایی و دارویی ایالات متحده امریکا fa
# سازمان غذا و داروی امریکا fa
# ادارهٔ مواد غذائی و داروئی ایالات متحده fa
# ادارهٔ غذا و داروی امریکا fa
# سازمان غذا و داروی آمریکا fa
# اداره مواد دارویی و غذایی آمریکا fa
# FDA nb
# FDA en
# USFDA en
# U.S. Food and Drug Administration en
# United States Food and Drug Administration en
# US Food and Drug Administration en
# FDA it
# Agenzia per gli alimenti e i medicinali it
# 美國食品與藥品管理局 zh-hant
# 食品藥物管理機構 zh-hant
# FDA nn
# USFDA nn
# FDA mk
# USFDA mk
# Cục quản lý Thực phẩm và Dược phẩm Hoa Ky vi
# Cục quản lý Thực phẩm và Dược phẩm Hoa Kì vi
# Cơ quan Quản lý Thực phẩm và Thuốc vi
# Cơ quan Quản lý Thực phẩm và Thuốc Hoa Kỳ vi
# Cơ quan Quản lý Thực phẩm và Thuốc Hoa Kì vi
# FDA vi
# USFDA vi
# NAB-365 en
# 4-amino-α-((tert-butylamino)methyl)-3,5-dichlorobenzyl alcohol en
# (±)-clenbuterol en
# 1-(4-amino-3,5-dichloro-phenyl)-2-tert-butylamino-ethanol en
# (+-)-clenbuterol en
# 4-amino-3,5-dichloro-alpha-(((1,1-dimethylethyl)amino)methyl)benzenemethanol en
# 4-amino-alpha-((tert-butylamino)methyl)-3,5-dichlorobenzyl alcohol en
# 1-(4-Amino-3,5-dichloro-phenyl)-2-tert-butylamino-ethanol en
# 4-amino-3,5-Dichloro-alpha-(((1,1-dimethylethyl)amino)methyl)benzenemethanol en
# 4-amino-alpha-((Tert-butylamino)methyl)-3,5-dichlorobenzyl alcohol en
# 克伦特罗 zh
# 瘦肉精 zh
# 瘦肉精 zh-hans
# Acefylline sr
# Acefilin piperazin sr
# C9H10N4O4 sr
# Dilor® en
# Diprophylline en
# (+-)-diprophylline en
# (+-)-dyphylline en
# (1,2-dihydroxy-3-propyl)thiophyllin en
# 7-(beta,gamma-dihydroxypropyl)theophylline en
# 1,3-dimethyl-7-(2,3-dihydroxypropyl)xanthine en
# 7-(2,3-dihydroxypropyl)-3,7-dihydro-1,3-dimethyl-1H-purine-2,6-dione en
# (+-)-7-(2,3-dihydroxypropyl)theophylline en
# 7-(2,3-dihydroxypropyl)theophylline en
# 7-(2,3-dihydroxypropyl)-1,3-dimethylxanthine en
# 7-(beta,gamma-Dihydroxypropyl)theophylline en
# Diprofilina en
# (±)-dyphylline en
# (+-)-Dyphylline en
# 7-(2,3-Dihydroxypropyl)-1,3-dimethylxanthine en
# Dyphylline en
# (+-)-Diprophylline en
# 7-(β,γ-dihydroxypropyl)theophylline en
# Diprophyllinum en
# 7-(2,3-Dihydroxypropyl)theophylline en
# Dihydroxypropyl theopylin en
# (±)-diprophylline en
# 1,3-Dimethyl-7-(2,3-dihydroxypropyl)xanthine en
# (+-)-7-(2,3-Dihydroxypropyl)theophylline en
# (1,2-Dihydroxy-3-propyl)thiophyllin en
# 7-(2,3-Dihydroxypropyl)-3,7-dihydro-1,3-dimethyl-1H-purine-2,6-dione en
# Bambuterolo it
# C18H29N3O5 it
# Bambec® en
# Oxeol® en
# terbutaline bis(dimethylcarbamate) en
# terbutaline bisdimethylcarbamate en
# (+-)-5-(2-(tert-butylamino)-1-hydroxyethyl)-m-phenylene bis(dimethylcarbamate) en
# Bambuterolum en
# bambutérol en
# (±)-5-(2-(tert-butylamino)-1-hydroxyethyl)-m-phenylene bis(dimethylcarbamate) en
# Bambuterol en
# budesonide pt
# Тафен назаль ru
# Будекорт ru
# Будерин ru
# Буденофальк ru
# Апулеин ru
# Бенакорт ru
# Тафен ru
# Тафен Новолайзер ru
# Бенарин ru
# Пульмикорт ru
# Цикортид Циклокапс ru
# BUD124 en
# S-1320 en
# (11beta,16alpha)-16,17-(butylidenebis(oxy))-11,21-dihydroxypregna-1,4-diene-3,20-dione en
# S-1320 cy
# (11beta,16alpha)-16,17-(butylidene) cy
# budezonid cs
# ALS19 en
# HER4 en
# p180erbB4 en
# erb-b2 receptor tyrosine kinase 4 en
# ErbB-4 ru
# GWAS et
# GWAS de
# étude d’association pangénomique fr
# étude d'association pan-génomique fr
# genome-wide association study fr
# GWAS fr
# GWA studija sr
# WGA studija sr
# GWAS nn
# GWAS-studie nn
# GWAS en
# Genome-Wide Association Study en
# ゲノムワイド関連研究 ja
# Traceable Author Statement nl
# Traceable Author Statement en
# GARNL4 en
# RAP1GA3 en
# RAP1 GTPase activating protein 2 en
# RAP١GAP٢ ar
# FBL6 en
# FBL7 en
# F-box and leucine-rich repeat protein 7 en
# F-box and leucine rich repeat protein 7 en
# FBXL٧ ar
# CDH28 en
# cadherin related family member 3 en
# GSDML en
# PRO2521 en
# PP4052 en
# gasdermin B en
# GSDMB-1 en
# C9orf26 en
# DVS27 en
# IL1F11 en
# NF-HEV en
# NFEHEV en
# Interleukin 33 en
# IL-33 en
# IL-1F11 en
# Интерлейкин-33 ru
# C9ORF26 sr
# IL1F11 sr
# IL33 sr
# NFHEV sr
# DV27 sr
# ИЛ-33 sr
# IL-33 cs
# NBSLD en
# RAD502 en
# hRad50 en
# Rad50 en
# RAD50 double strand break repair protein en
# GSDM en
# GSDM1 en
# FKSG9 en
# gasdermin A en
# IL-13 en
# P600 en
# interleukin 13 en
# IL-13 nn
# P600 nn
# interleukin-13 nn
# IL-13 cs
# IL13 cs
# 白细胞介素-13 zh
# EWI-3 en
# V8 en
# LCDD en
# immunoglobulin superfamily member 3 en
# HPA2 en
# HPR2 en
# UFS en
# UFS1 en
# heparanase 2 (inactive) en
# GLBA en
# SAP1 en
# prosaposin en
# SAP2 en
# ATG3 en
# APG3 en
# APG3-LIKE en
# APG3L en
# PC3-96 en
# autophagy related 3 en
# TWA2 en
# muskelin 1 en
# SYG1 en
# X3 en
# IBGC6 en
# xenotropic and polytropic retrovirus receptor 1 en
# SLC53A1 en
# NESHBP en
# TARSH en
# ABI family member 3 binding protein en
# ABI٣BP ar
# kelch like family member 5 en
# collagen, type XXII, alpha 1 en
# collagen type XXII alpha 1 chain en
# CD en
# CELIAC1 en
# DQ-A1 en
# GSE en
# HLA-DQA en
# Major histocompatibility complex, class II, DQ alpha 1 en
# DQA1 en
# Complexo principal de histocompatibilidade, classe II, DQ alfa 1 pt
# chromosome 5 open reading frame 56 en
# IRF1 antisense RNA 1 en
# C5orf56 en
# ACONS en
# HEL60 en
# IREB1 en
# IREBP en
# IREBP1 en
# IRP1 en
# aconitase 1 en
# ACO١ ar
# ZFP160L en
# zinc finger protein 665 en
# AAT8 en
# PKG en
# PRKG1B en
# PRKGR1B en
# cGK en
# cGK 1 en
# cGK1 en
# cGKI en
# cGKI-BETA en
# cGKI-alpha en
# protein kinase, cGMP-dependent, type I en
# PKG1 en
# protein kinase cGMP-dependent 1 en
# CD126 en
# IL-6R-1 en
# IL-6RA en
# IL6Q en
# IL6RA en
# IL6RQ en
# gp80 en
# Interleukin-6 receptor en
# interleukin 6 receptor en
# 抗白介素-6 受體 zh
# 白细胞介素-6受体 zh
# GRB2 associated binding protein 1 en
# DFNB26 en
# G17 en
# HOX12 en
# PBX2MHC en
# PBX homeobox 2 en
# PBX٢ ar
# INT3 en
# notch 4 en
# notch receptor 4 en
# TSBP en
# chromosome 6 open reading frame 10 en
# testis expressed basic protein 1 en
# C6orf10 en
# TSBP nn
# kromosom 6, open leseramme 10 nn
# C٦orf١٠ ar
# EOS en
# ZNFN1A4 en
# IKAROS family zinc finger 4 en
# EOS nn
# ZNFN1A4 nn
# IKZF٤ ar
# IFIX en
# pyrin and HIN domain family member 1 en
# DER4 en
# FIT-1 en
# IL33R en
# ST2 en
# ST2L en
# ST2V en
# T1 en
# interleukin 1 receptor like 1 en
# IL١RL١ ar
# IL1RL1 cs
# ST2 cs
# ZNT8 en
# ZnT-8 en
# solute carrier family 30 member 8 en
# CD218a en
# CDw218a en
# IL-1Rrp en
# IL18RA en
# IL1RRP en
# interleukin 18 receptor 1 en
# IL-18R-alpha en
# IL18Ralpha2 en
# IL-18Ralpha en
# HSPC193 en
# HsT17436 en
# JV15-2 en
# LDS1C en
# LDS3 en
# MADH3 en
# SMAD family member 3 en
# CD122 en
# IL15RB en
# P70-75 en
# interleukin 2 receptor subunit beta en
# IMD63 en
# CDSP en
# OCTN2 en
# solute carrier family 22 member 5 en
# NR1F1 en
# ROR1 en
# ROR2 en
# ROR3 en
# RZR-ALPHA en
# RZRA en
# RAR related orphan receptor A en
# IDDECA en
# ACRDYS2 en
# DPDE3 en
# HSPDE4D en
# PDE43 en
# PDE4DN2 en
# STRK1 en
# phosphodiesterase 4D en
# ARVD13 en
# VR22 en
# catenin alpha 3 en
# Minimum Information Required In the Annotation of Models en
# MIRIAM Registry en
# Minimum Information Required In the Annotation of Models nn
# MIRIAM Registry nn
# Minimum Information Required In the Annotation of Models sr
# MIRIAM регистар sr
# реєстр MIRIAM uk
# русскоязычная Википедия ru
# рувики ru
# ру-вики ru
# рувп ru
# ru.wikipedia.org ru
# РВП ru
# Русская Википедия ru
# Russische Wikipedia de
# ru.wiki it
# ruwiki fr
# ru.wikipedia.org fr
# rusa Vikipedio eo
# ru.wikipedia.org eo
# ruwiki ast
# ru.wikipedia.org ast
# рувики tg
# ru.wikipedia.org tg
# ruwiki es
# ru.wikipedia.org es
# російськомовна Вікіпедія uk
# рувікі uk
# ру-вікі uk
# рувп uk
# ru.wikipedia.org uk
# ru.wikipedia.org ace
# ruwikipedia ace
# ruwiki ace
# ruwp ace
# ru.wikipedia.org id
# ruwikipedia id
# ruwiki id
# ruwp id
# ru.wikipedia.org jv
# ruwikipedia jv
# ruwiki jv
# ruwp jv
# ru.wikipedia.org su
# ruwikipedia su
# ruwiki su
# ruwp su
# ru.wikipedia.org min
# ruwikipedia min
# ruwiki min
# ruwp min
# ru.wikipedia.org bjn
# ruwikipedia bjn
# ruwiki bjn
# ruwp bjn
# ruwiki et
# ru.wikipedia.org et
# ruwp en
# ruwikipedia en
# ru.wikipedia.org en
# ruwiki en
# РусВики ba
# ru.wikipedia.org ba
# Орус Уикипедиясы ky
# Russischtalige Wikipedia nl
# ru.wikipedia.org ja
# ru.wikipedia.org th
# วิกิพีเดียรุ่นภาษารัสเซีย th
# ruwp th
# ruwikipedia th
# ruwiki th
# ru.wikipedia.org zh
# ru.wikipedia.org as
# ru.wikipedia.org az
# ru.wikipedia.org be
# ru.wikipedia.org be-tarask
# ru.wikipedia.org bn
# ru.wikipedia.org bs
# ruwiki bs
# ru.wiki bs
# ru.wp bs
# ru.wikipedia.org bxr
# ru.wikipedia.org ca
# ru.wikipedia.org ce
# ru.wikipedia.org cs
# ru.wikipedia.org cv
# ru.wikipedia.org cy
# ru.wikipedia.org da
# ru.wikipedia.org diq
# ru.wikipedia.org el
# ru.wikipedia.org en-ca
# ru.wikipedia.org en-gb
# ru.wikipedia.org eu
# ru.wikipedia.org fy
# ru.wikipedia.org gl
# ru.wikipedia.org haw
# ru.wikipedia.org he
# ru.wikipedia.org tt
# ru.wikipedia.org tt-cyrl
# ru.wikipedia.org udm
# ru.wikipedia.org uz
# ru.wikipedia.org vep
# ru.wikipedia.org vi
# ru.wikipedia.org vo
# ru.wikipedia.org xmf
# ru.wikipedia.org yi
# ru.wikipedia.org yue
# ru.wikipedia.org zh-cn
# ru.wikipedia.org zh-hans
# ru.wikipedia.org zh-hant
# ru.wikipedia.org zh-hk
# ru.wikipedia.org zh-tw
# ru.wikipedia.org af
# ru.wikipedia.org ka
# ru.wikipedia.org kk
# ru.wikipedia.org km
# ru.wikipedia.org ko
# ru.wikipedia.org la
# ru.wikipedia.org lb
# ru.wikipedia.org lt
# ru.wikipedia.org lv
# ru.wikipedia.org lzh
# ru.wikipedia.org map-bms
# ru.wikipedia.org mk
# ru.wikipedia.org mn
# ru.wikipedia.org ms
# ru.wikipedia.org nan
# ru.wikipedia.org nb
# ru.wikipedia.org nds
# ru.wikipedia.org pl
# rosyjskojęzyczna Wikipedia pl
# rosyjska Wikipedia pl
# ru.wikipedia.org pt
# ru.wikipedia.org pt-br
# ru.wikipedia.org ro
# ru.wikipedia.org rue
# ru.wikipedia.org sc
# ru.wikipedia.org scn
# ru.wikipedia.org sco
# ru.wikipedia.org sh
# ru.wikipedia.org sk
# ru.wikipedia.org sv
# ru.wikipedia.org sw
# ru.wikipedia.org ta
# ru.wikipedia.org tg-cyrl
# ru.wikipedia.org tl
# ru.wikipedia.org tr
# ruska Wikipedija hr
# ruwp nqo
# fumo it
# دخان التبغ ar
# تدخين التبغ ar
# مشاكل صحية للتدخين ar
# التدخين ar
# مدخن ar
# 🚬 ar
# تدخين السجائر ar
# паленьне be-tarask
# røykjing nn
# fumar pt-br
# паленне be
# 患病率 zh
# 發生率 (流行病學) zh
# zachorowalność pl
# İnsidans oranı tr
# İH tr
# İnsidans hızı tr
# Incidence th
# Incidència acumulada ca
# Pojavnost sl
# voorkomen nl
# sairastuvuus fi
# insidenssi fi
# 발생 수 ko
# 발생수 ko
# инциденција mk
# первинна захворюваність uk
# захворвальнасьць be-tarask
# 空气污染 zh
# 尾气 zh
# 大气污染 zh
# 空污 zh
# 廢氣 zh
# Aire kutsadura eu
# Kutsadura atmosferiko eu
# Kutsadura atmosferikoa eu
# airearen poluzio eu
# poluzio atmosferiko eu
# Contaminación atmosferica es
# Contaminacion atmosferica es
# Polución atmosferica es
# Contaminación del aire es
# Polución atmosférica es
# Polucion atmosférica es
# Polución del aire es
# Polucion del aire es
# Contaminacion atmosférica es
# Polucion atmosferica es
# Contaminacion del aire es
# Õhusaaste et
# Õhu saastumine et
# Õhureostus et
# Saastatud õhk et
# Õhu saastamine et
# luftförorening sv
# Air pollution ar
# تلوث الغلاف الجوي ar
# تلوث هوائي ar
# تلوث جوي ar
# La pollution de l'air ar
# Uitstoot nl
# Luchtverontreiniging nl
# Gases poluentes pt
# Poluição do ar pt
# Poluentes atmosféricos pt
# לופט פארפעסטיגונג yi
# לופט פארקויטיקונג yi
# загрязнение воздуха ru
# загрязнение атмосферы ru
# Zagađivač vazduha sr
# Загађивање ваздуха sr
# Kirli hava tr
# Ilmansaasteet fi
# Ilmansaaste fi
# Забруднення атмосферного повітря uk
# Забруднення атмосфери uk
# Mannixhaedje di l’ air wa
# 공기오염 ko
# 대기오염 ko
# 공기 오염 ko
# Pollution de l’air fr
# Polluants atmosphériques fr
# Pollutions atmosphérique fr
# Pollution atmosphérique fr
# La pollution de l'air fr
# זיהום אויר he
# Atmosfēras piesārņojums lv
# Inquinamento dell'aria it
# polusi udara id
# Luftverunreinigung de
# § 325 StGB de
# Luftverunreinigungen de
# Air pollution ml
# അന്തരീക്ഷ മലിനീകരണം ml
# 大気汚染問題 ja
# 大気汚染物質 ja
# 空気の質 ja
# pol·lució atmosfèrica ca
# contaminació de l'aire ca
# Inquinatio aeris la
# znečištění vzduchu cs
# हवा प्रदूषण mr
# वायूप्रदूषण mr
# Замърсители на въздуха bg
# الودگی هوا fa
# Air pollution ur
# Oro užterštumas lt
# Atmosferos tarša lt
# aerpoluo eo
# znečistenie vzduchu sk
# atmospheric pollution en
# वायु प्रदूषण bho
# वायुमंडल प्रदूषण bho
# légszennyezés hu
# luftureining nn
# забруджваньне атмасфэры be-tarask
# वायु प्रदूषण ne
# 医学术语系统命名法－临床术语 zh
# SNOMED de
# SNOMED CT es
# SNOMED en
# SNOMED Clinical Terms en
# SNOMED he
# SNOMED cs
# skos:exactMatch en
# exactMatch en
# = en
# skos:exactMatch es
# exactMatch es
# całkowita zgodność zakresowa pl
# skos:exactMatch pl
# exactMatch pl
# dopasowanie pojęcia o identycznym znaczeniu pl
# skos:exactMatch uk
# exactMatch uk
# skos:exactMatch da
# זיהוי מדויק he
# skos:exactMatch id
# skos:дакладнаяАдпаведнасьць be-tarask
# 精确匹配 zh
# përputhje ekzakte sq
# skos:exactMatch nb
# skos:exactMatch ro
# exactMatch ro
# = ro
# skos:tamEşleşme tr
# YSO-Wikidata fi
# YSO-Wikidata en
# ALLFO-Wikidata sv
# Wikipedia:WikiProject Medicine en
# School:Medicine en
# WPMED en
# ΒΠ:ΙΑΤΡ el
# School:医学 ja
# WP:PMED sv
# ВікіПраект:Мэдыцына be-tarask
# ВікіПраект Мэдыцына be-tarask
# WP:COVID-19 en
# WP:CORONA en
# WP:CORONAVIRUS en
# WP:COVID en
# WP:COVID19 en
# وڪيپيڊيا:وڪي منصوبو ڪوويڊ-19 sd
# وڪيپيڊيا:وڪي پروجيڪٽ ڪوويڊ-19 sd
# وڪيپيڊيا:وڪي رٿا ڪوويڊ-19 sd
# وڪيپيڊيا:وڪيمنصوبو ڪوويڊ-19 sd
# وڪيپيڊيا:وڪيرٿا ڪوويڊ-19 sd
# WP:COVID-19 hy
# WikiProject COVID-19 hr
# WP:COVID-19 fr
# WP:CORONA fr
# WP:CORONAVIRU fr
# WP:COVID fr
# WP:COVID19 fr
# WP:COVID19 pt
# WP:COVID-19 pt-br
# 嚴重特殊傳染性肺炎專題 zh
# 2019冠状病毒疾病专题 zh
# 2019冠狀病毒病專題 zh
# Wikipedie:WikiProjekt SARS-CoV-2 cs
# fr.wikipedia.org fr
# frwiki fr
# Wikipédia francophone fr
# Wikipedia en français fr
# wp:fr fr
# fr.wiki fr
# fr WP fr
# wp fr fr
# frwiki en
# frwp en
# fr.wiki en
# frwikipedia en
# fr.wikipedia.org en
# fr.wiki it
# fr.wikipedia.org it
# франкоязычная Википедия ru
# französische Wikipedia de
# frwiki de
# ଫ୍ରେଞ୍ଚ ଉଇକିପିଡ଼ିଆ or
# frwiki hu
# frwiki es
# Wikipedia en frances es
# frwiki ast
# fr.wikipedia.org ast
# Wikipedia á fronskum fo
# fr.wikipedia.org fo
# franca Vikipedio eo
# פראנצייזיש-וויקיפעדיע yi
# Wikipedia Pháp ngữ vi
# fr.wikipedia.org ace
# frwikipedia ace
# frwiki ace
# frwp ace
# fr.wikipedia.org id
# frwikipedia id
# frwiki id
# frwp id
# fr.wikipedia.org jv
# frwikipedia jv
# frwiki jv
# frwp jv
# fr.wikipedia.org su
# frwikipedia su
# frwiki su
# frwp su
# fr.wikipedia.org min
# frwikipedia min
# frwiki min
# frwp min
# fr.wikipedia.org bjn
# frwikipedia bjn
# frwiki bjn
# frwp bjn
# फ़्रांसिसी विकिपीडिया hi
# fr.wikipedia.org hi
# Француз Википедиясе tt
# fr.wikipedia.org tt
# Француз Википедиясе tt-cyrl
# fr.wikipedia.org tt-cyrl
# fr.wikipedia.org ja
# fr.wikipedia.org th
# fr.wikipedia.org zh
# fr.wikipedia.org af
# fr.wikipedia.org arz
# fr.wikipedia.org az
# fr.wikipedia.org be
# fr.wikipedia.org be-tarask
# Француская Вікіпэдыя be-tarask
# fr.wikipedia.org br
# fr.wikipedia.org bs
# frwiki bs
# fr.wiki bs
# fr.wikipedia.org bxr
# fr.wikipedia.org ca
# fr.wikipedia.org ce
# fr.wikipedia.org cs
# fr.wikipedia.org cv
# fr.wikipedia.org cy
# fr.wikipedia.org da
# fr.wikipedia.org de-ch
# fr.wikipedia.org diq
# fr.wikipedia.org el
# fr.wikipedia.org en-ca
# fr.wikipedia.org en-gb
# fr.wikipedia.org et
# fr.wikipedia.org eu
# fr.wikipedia.org ext
# fr.wikipedia.org fi
# fr.wikipedia.org frr
# fr.wikipedia.org fy
# fr.wikipedia.org ga
# fr.wikipedia.org gl
# fr.wikipedia.org hak
# fr.wikipedia.org hr
# francuska Wikipedija hr
# fr.wikipedia.org hsb
# fr.wikipedia.org hy
# fr.wikipedia.org ka
# fr.wikipedia.org kk
# fr.wikipedia.org lb
# fr.wikipedia.org lt
# fr.wikipedia.org lzh
# fr.wikipedia.org map-bms
# fr.wikipedia.org mk
# fr.wikipedia.org ml
# fr.wikipedia.org mn
# fr.wikipedia.org nan
# fr.wikipedia.org nds
# fr.wikipedia.org oc
# fr.wikipedia.org pt-br
# fr.wikipedia.org ro
# fr.wikipedia.org scn
# fr.wikipedia.org sco
# fr.wikipedia.org sgs
# fr.wikipedia.org sh
# fr.wikipedia.org sk
# fr.wikipedia.org sl
# fr.wikipedia.org sr
# fr.wikipedia.org sv
# fr.wikipedia.org tg
# fr.wikipedia.org tl
# fr.wikipedia.org tr
# frwp tr
# frwiki tr
# fr.wiki tr
# fr.wikipedia tr
# frwikipedia tr
# fr.wikipedia.org uk
# fr.wikipedia.org uz
# fr.wikipedia.org vep
# fr.wikipedia.org vo
# fr.wikipedia.org wuu
# fr.wikipedia.org xmf
# fr.wikipedia.org yue
# fr.wikipedia.org zh-cn
# fr.wikipedia.org zh-hans
# fr.wikipedia.org zh-hant
# fr.wikipedia.org zh-tw
# fr.wikipedia.org kab
# frwiki kab
# frwp kab
# fr.wiki kab
# frwikipedia kab
# Mwp:fr kab
# frwiki ms
# frwp ms
# Wężownice Curschmanna pl
# Curschmann spirals en
# 咳 zh
# Eztula eu
# Qusuy qu
# Ch'uju qu
# Ch'uhuy qu
# Uhuy qu
# Chuquy qu
# Toser qu
# Uju qu
# Tos qu
# Chuhuy qu
# Ujuy qu
# Chuhu qu
# Ch'uqhuy qu
# Ch'uquy qu
# Chuju qu
# Ch'uqhu qu
# Qusu qu
# Ch'uqu qu
# Ch'ujuy qu
# Chujuy qu
# Tussis qu
# Ch'uhu qu
# Kašljanje bs
# الكحة ar
# السعال ar
# العلاج الذاتي للسعال ar
# كحة ar
# rökhosta sv
# hostar sv
# hostreflex sv
# hoesten nl
# hoestbui nl
# kriebelhoest nl
# кашлять ru
# Öksürme tr
# Kašljanje hr
# tousse fr
# toussote fr
# Tussis lv
# klepošana lv
# Reizhusten de
# Tussis de
# Cough ml
# 咳 ja
# せき ja
# Tussidda scn
# Tussicedda scn
# Cough th
# อาการไอ th
# การไอ th
# Pesychu cy
# Expektorace cs
# Vykašlávání cs
# Kašlání cs
# Kosėjimas lt
# Hosting nb
# Harking nb
# Yo‘tal uz
# Yo`tal uz
# Yo'tal uz
# harke nn
# kremte nn
# coughing en
# باتوق ms
# tusado eo
# ማሳል am
# йөткерү tt
# Tussinte ia
# йөткерү tt-cyrl
# chripa hsb
# kašlowanje hsb
# dolor de pecho es
# dolor de tórax es
# dolor toracico es
# dolor de torax es
# 胸口疼痛 zh
# brystverk nn
# pektoralgi nn
# stetalgi nn
# torakalgi nn
# torakodyni nn
# ألم صدري ar
# ألم صدر ar
# боль у грудзях be-tarask
# ێشانا سینگی ckb
# ئازاری سینگ ckb
# Кардиалгический синдром ru
# brystsmerter da
# пектаральны боль be
# кардыялгічны боль be
# bolest na hrudi cs
# Հայերեն Վիքիփեդիա hy
# Վիքիպեդիա Ազատ հանրագիտարան hy
# Հայերեն Վիքիփեդիա sr
# Vik'ipedia es
# ویکی پدیای ارمنی fa
# hywiki en
# hywp en
# hywikipedia en
# hy.wikipedia.org en
# Armenische Wikipedi de
# armena Vikipedio eo
# Wikipedia tiếng Ác-mê-ni-a vi
# hywiki ca
# Vik'ipedia ca
# Den armenske Wikipedia da
# hy.wikipedia.org ace
# hywikipedia ace
# hywiki ace
# hywp ace
# hy.wikipedia.org id
# hywikipedia id
# hywiki id
# hywp id
# hy.wikipedia.org jv
# hywikipedia jv
# hywiki jv
# hywp jv
# hy.wikipedia.org su
# hywikipedia su
# hywiki su
# hywp su
# hy.wikipedia.org min
# hywikipedia min
# hywiki min
# hywp min
# hy.wikipedia.org bjn
# hywikipedia bjn
# hywiki bjn
# hywp bjn
# hywiki zh
# hy.wikipedia.org zh
# hywiki ms
# hywp ms
# hywikipedia ms
# hy.wikipedia.org ms
# Vikipedia Azat Hanragitaran ms
# 發炎反應 zh
# 发炎 zh
# 發炎 zh
# Inflamazio eu
# Stan zapalny pl
# Reakcja zapalna pl
# Zapalenia pl
# Proces zapalny pl
# respuesta inflamatoria es
# reacción inflamatoria es
# antiflogística es
# inflamacion es
# reaccion inflamatoria es
# antiflogistica es
# Inflammatio et
# inflammatie nl
# inflammatoire nl
# ontstekingsreactie nl
# التهاب حاد ar
# إلتهاب ar
# Inflammationer sv
# Functio laesa sv
# Inflamatória pt
# Inflamado pt
# Inflamatórias pt
# Inflamações pt
# Inflamatório pt
# Processo inflamatório pt
# איינצינדונג yi
# אנטצינדונג yi
# ענטצינדונג yi
# Inflammatio sr
# هەوکردن ckb
# Yangı tr
# запальний процес uk
# Inflamation da
# Xenoftalmi da
# Pus da
# Inflammation da
# catarrhe fr
# inflammatoire fr
# maladies inflammatoires fr
# réaction inflammatoire fr
# Flogosi it
# Affezioni flogistiche it
# Malattia infiammatoria it
# Infiammazioni it
# Processo flogistico it
# التهاب ps
# Entzündungsreaktion de
# Inflammation de
# Inflamasi id
# Peradangan id
# 炎症反応 ja
# 慢性炎症 ja
# Inflammation ml
# Zapaljenje sh
# Inflammatio sk
# อาการอักเสบ th
# Inflammation th
# อักเสบ th
# Inflamaţie ro
# Inflamatie ro
# Resposta inflamatòria ca
# Retenció de líquids ca
# Inflamacions ca
# Reacció inflamatòria ca
# Enynfa cy
# Enyniad cy
# سوزش ur
# انفلامیشن ur
# ملتہب ur
# انفلامیٹری ur
# Inflammations ur
# التہابات ur
# Inflammatory ur
# Inflammation ur
# Entzündung nds
# Inflammatio nds
# Inflammasjon nb
# Betennelse nb
# inflamacija hr
# hyperchemokinemia en
# inflammatory reaction en
# φλόγωση el
# inflammasjon nn
# phồng vi
# Vnetje sl
# ятрасьць be-tarask
# kûlbûnî ku
# sibilant rhonchi de
# sibilant rhonchi en
# wheezing en
# wheezes en
# gasping en
# panting en
# puffing en
# pískot cs
# kvesing nn
# kvese nn
# ウィーズ ja
# ふえ音 ja
# sibilància ca
# kbpedia en
# KBPedia en
# KGpedia en
# kbpedia pt
# KBPedia pt
# KGpedia pt
# kbpedia gl
# KBPedia gl
# KGpedia gl

# %%
compareRDF = Graph()
compareRDF.parse("http://www.wikidata.org/entity/"+qid+".ttl")
# Out:
# <Graph identifier=N2ea2c8aeda724743a1ac155701b2d36c (<class 'rdflib.graph.Graph'>)>

# %%
diffRdf = compareRDF-rdf_item
for prefix in wdi_config.prefix.keys():
    ns[prefix] = Namespace( wdi_config.prefix[prefix])
    diffRdf.namespace_manager.bind(prefix, ns[prefix])
diffRdf.serialize(format="turtle", destination="1.ttl")
print(len(diffRdf))
print(len(rdf_item))
# Out:
# 496
# 42354

# %%
rdf_item.serialize(format="turtle", destination="2.ttl")

# %%
rdf_item.serialize(format="turtle", destination="3.ttl")

# %%
json_item
# Out:
# {'pageid': 38533,
#  'ns': 0,
#  'title': 'Q35869',
#  'lastrevid': 1418631634,
#  'modified': '2021-05-10T19:39:37Z',
#  'type': 'item',
#  'id': 'Q35869',
#  'labels': {'zh': {'language': 'zh', 'value': '哮喘'},
#   'ky': {'language': 'ky', 'value': 'Бронх астмасы'},
#   'jv': {'language': 'jv', 'value': 'asma'},
#   'pl': {'language': 'pl', 'value': 'astma oskrzelowa'},
#   'eu': {'language': 'eu', 'value': 'asma'},
#   'qu': {'language': 'qu', 'value': 'Qharqayuy'},
#   'bs': {'language': 'bs', 'value': 'bronhijalna astma'},
#   'es': {'language': 'es', 'value': 'asma'},
#   'ta': {'language': 'ta', 'value': 'ஈழை நோய்'},
#   'af': {'language': 'af', 'value': 'asma'},
#   'ms': {'language': 'ms', 'value': 'asma'},
#   'hu': {'language': 'hu', 'value': 'asztma'},
#   'et': {'language': 'et', 'value': 'bronhiaalastma'},
#   'bn': {'language': 'bn', 'value': 'হাঁপানি'},
#   'el': {'language': 'el', 'value': 'άσθμα'},
#   'ia': {'language': 'ia', 'value': 'asthma'},
#   'ga': {'language': 'ga', 'value': 'asma'},
#   'ar': {'language': 'ar', 'value': 'الربو'},
#   'sv': {'language': 'sv', 'value': 'astma'},
#   'nl': {'language': 'nl', 'value': 'astma'},
#   'pt': {'language': 'pt', 'value': 'asma'},
#   'eo': {'language': 'eo', 'value': 'astmo'},
#   'is': {'language': 'is', 'value': 'astmi'},
#   'new': {'language': 'new', 'value': 'आज्मा'},
#   'su': {'language': 'su', 'value': 'asma'},
#   'ru': {'language': 'ru', 'value': 'бронхиальная астма'},
#   'sr': {'language': 'sr', 'value': 'астма'},
#   'tr': {'language': 'tr', 'value': 'astım'},
#   'ckb': {'language': 'ckb', 'value': 'ئاسم'},
#   'mk': {'language': 'mk', 'value': 'астма'},
#   'fi': {'language': 'fi', 'value': 'astma'},
#   'uk': {'language': 'uk', 'value': 'бронхіальна астма'},
#   'si': {'language': 'si', 'value': 'ඇදුම'},
#   'nn': {'language': 'nn', 'value': 'astma'},
#   'io': {'language': 'io', 'value': 'astmo'},
#   'hr': {'language': 'hr', 'value': 'astma'},
#   'az': {'language': 'az', 'value': 'bronxial astma'},
#   'tl': {'language': 'tl', 'value': 'Hika'},
#   'kk': {'language': 'kk', 'value': 'Бронхтық атопиялық демікпе'},
#   'da': {'language': 'da', 'value': 'astma'},
#   'nan': {'language': 'nan', 'value': 'He-ku'},
#   'pam': {'language': 'pam', 'value': 'Mausang'},
#   'wa': {'language': 'wa', 'value': "Coûtresse d' alinne"},
#   'fr': {'language': 'fr', 'value': 'asthme'},
#   'he': {'language': 'he', 'value': 'אסתמה'},
#   'ko': {'language': 'ko', 'value': '천식'},
#   'bjn': {'language': 'bjn', 'value': 'Manggah'},
#   'lv': {'language': 'lv', 'value': 'bronhiālā astma'},
#   'it': {'language': 'it', 'value': 'asma'},
#   'gl': {'language': 'gl', 'value': 'asma'},
#   'ps': {'language': 'ps', 'value': 'سالنډي'},
#   'id': {'language': 'id', 'value': 'asma'},
#   'de': {'language': 'de', 'value': 'Asthma'},
#   'ml': {'language': 'ml', 'value': 'ആസ്മ'},
#   'ja': {'language': 'ja', 'value': '気管支喘息'},
#   'vi': {'language': 'vi', 'value': 'hen phế quản'},
#   'en': {'language': 'en', 'value': 'asthma'},
#   'sa': {'language': 'sa', 'value': 'श्वासरोगः'},
#   'hi': {'language': 'hi', 'value': 'दमा'},
#   'ht': {'language': 'ht', 'value': 'Las'},
#   'sk': {'language': 'sk', 'value': 'astma'},
#   'hy': {'language': 'hy', 'value': 'Բրոնխիալ ասթմա'},
#   'ro': {'language': 'ro', 'value': 'astm bronșic'},
#   'th': {'language': 'th', 'value': 'โรคหืด'},
#   'ca': {'language': 'ca', 'value': 'asma'},
#   'la': {'language': 'la', 'value': 'Asthma bronchiale'},
#   'cy': {'language': 'cy', 'value': 'asthma'},
#   'sl': {'language': 'sl', 'value': 'astma'},
#   'cs': {'language': 'cs', 'value': 'astma'},
#   'bg': {'language': 'bg', 'value': 'Астма'},
#   'fa': {'language': 'fa', 'value': 'آسم'},
#   'mr': {'language': 'mr', 'value': 'दमा'},
#   'te': {'language': 'te', 'value': 'ఉబ్బసము'},
#   'ur': {'language': 'ur', 'value': 'دمہ'},
#   'lt': {'language': 'lt', 'value': 'Astma'},
#   'pa': {'language': 'pa', 'value': 'ਦਮਾ'},
#   'uz': {'language': 'uz', 'value': 'bronxial astma'},
#   'or': {'language': 'or', 'value': 'ଆଜ୍\u200cମା'},
#   'nb': {'language': 'nb', 'value': 'astma'},
#   'so': {'language': 'so', 'value': 'Neefta'},
#   'war': {'language': 'war', 'value': 'Asma'},
#   'sh': {'language': 'sh', 'value': 'Astma'},
#   'tk': {'language': 'tk', 'value': 'Bronhial astma'},
#   'bcl': {'language': 'bcl', 'value': 'Hapo'},
#   'sw': {'language': 'sw', 'value': 'Ugonjwa wa mapafu'},
#   'hak': {'language': 'hak', 'value': 'Pông-hâ'},
#   'ak': {'language': 'ak', 'value': 'Ntehyewa'},
#   'ilo': {'language': 'ilo', 'value': 'angkit'},
#   'bar': {'language': 'bar', 'value': 'Asthma'},
#   'srn': {'language': 'srn', 'value': 'bronchiale-bezetting'},
#   'cdo': {'language': 'cdo', 'value': 'Hău-chuāng'},
#   'yue': {'language': 'yue', 'value': '哮喘'},
#   'ne': {'language': 'ne', 'value': 'दम'},
#   'aeb-arab': {'language': 'aeb-arab', 'value': 'فدة'},
#   'aeb-latn': {'language': 'aeb-latn', 'value': 'fadda'},
#   'kn': {'language': 'kn', 'value': 'ಗೂರಲು'},
#   'tt': {'language': 'tt', 'value': 'быранхиял асмы'},
#   'ka': {'language': 'ka', 'value': 'ბრონქული ასთმა'},
#   'ceb': {'language': 'ceb', 'value': 'Hubak'},
#   'oc': {'language': 'oc', 'value': 'asma'},
#   'gu': {'language': 'gu', 'value': 'અસ્થમા'},
#   'sah': {'language': 'sah', 'value': 'Бронха астмата'},
#   'ast': {'language': 'ast', 'value': 'asma'},
#   'chr': {'language': 'chr', 'value': 'ᎤᎭᏬᏍᏗᏍᎩ'},
#   'se': {'language': 'se', 'value': 'ástmá'},
#   'sd': {'language': 'sd', 'value': 'دم'},
#   'za': {'language': 'za', 'value': 'Haebgyawh'},
#   'de-ch': {'language': 'de-ch', 'value': 'Asthma bronchiale'},
#   'en-ca': {'language': 'en-ca', 'value': 'Asthma'},
#   'en-gb': {'language': 'en-gb', 'value': 'asthma'},
#   'pt-br': {'language': 'pt-br', 'value': 'Asma'},
#   'wuu': {'language': 'wuu', 'value': '哮喘'},
#   'hyw': {'language': 'hyw', 'value': 'Շնչարգելք'},
#   'gcr': {'language': 'gcr', 'value': 'Asm'},
#   'arz': {'language': 'arz', 'value': 'ربو'},
#   'br': {'language': 'br', 'value': 'astma'},
#   'kab': {'language': 'kab', 'value': 'Aneggaf'},
#   'awa': {'language': 'awa', 'value': 'दमा'},
#   'be-tarask': {'language': 'be-tarask', 'value': 'астма'},
#   'bo': {'language': 'bo', 'value': 'དབུགས་མི་བདེ་བའི་ནད་'},
#   'zh-hant': {'language': 'zh-hant', 'value': '氣喘'}},
#  'descriptions': {'es': {'language': 'es',
#    'value': 'enfermedad crónica del sistema respiratorio'},
#   'en': {'language': 'en',
#    'value': 'long-term disease involving inflamed airways'},
#   'it': {'language': 'it', 'value': "malattia dell'apparato respiratorio"},
#   'nl': {'language': 'nl', 'value': 'longziekte'},
#   'pl': {'language': 'pl',
#    'value': 'przewlekła, zapalna choroba dróg oddechowych'},
#   'hr': {'language': 'hr', 'value': 'kronična upalna bolest dišnih puteva'},
#   'fr': {'language': 'fr', 'value': 'maladie du système respiratoire'},
#   'de': {'language': 'de',
#    'value': 'chronische, entzündliche Erkrankung der Atemwege'},
#   'or': {'language': 'or',
#    'value': 'ଅତି ସାଧାରଣ ଦୀର୍ଘସ୍ଥାୟୀ ରୋଗ ଯେଉଁଥିରେ ଶ୍ୱାସନଳୀର ପ୍ରଦାହ ହୁଏ'},
#   'hu': {'language': 'hu',
#    'value': 'a légutak krónikus gyulladásos betegsége'},
#   'fi': {'language': 'fi', 'value': 'keuhkosairaus'},
#   'cs': {'language': 'cs', 'value': 'onemocnění dýchacích cest'},
#   'tr': {'language': 'tr', 'value': 'solunum yolları rahatsızlığı'},
#   'ru': {'language': 'ru',
#    'value': 'хроническое воспалительное заболевание дыхательных путей'},
#   'uk': {'language': 'uk',
#    'value': 'хронічне захворювання дихальних шляхів людини'},
#   'ko': {'language': 'ko', 'value': '호흡기에 발생하는 질병 중 하나'},
#   'el': {'language': 'el',
#    'value': 'χρόνια φλεγμονώδης πάθηση που χαρακτηρίζεται από αναστρέψιμες ή τουλάχιστον μερικώς αναστρέψιμες στενώσεις των βρόγχων των πνευμόνων'},
#   'ja': {'language': 'ja', 'value': '呼吸困難、喘鳴、咳などの呼吸器症状をきたす症候群'},
#   'ar': {'language': 'ar', 'value': 'التهاب وتضيق الشعب الهوائية في الرئة'},
#   'id': {'language': 'id', 'value': 'Asma penyakit pada alat pernapasan'},
#   'sl': {'language': 'sl',
#    'value': 'dolgotgrajno obolenje v obliki vnetih dihalnih poti'},
#   'ne': {'language': 'ne', 'value': 'सास फेर्न समस्या हुन थाल्नु'},
#   'ta': {'language': 'ta', 'value': 'மூச்சுத்திணரல் நோய்'},
#   'nb': {'language': 'nb', 'value': 'Åndedrettslidelse'},
#   'af': {'language': 'af', 'value': 'Simptome'},
#   'hi': {'language': 'hi', 'value': 'सांस लेने में तकलीफ होना'},
#   'bn': {'language': 'bn', 'value': 'শ্বাসকষ্ট সম্বলিত রোগ'},
#   'ht': {'language': 'ht', 'value': 'maladi sistèm respiratwa a'},
#   'tl': {'language': 'tl',
#    'value': 'pangmatagalang karamdaman na may kinalaman sa kakulangan sa hanging pumapasok sa baga'},
#   'da': {'language': 'da', 'value': 'respiratorisk lidelse'},
#   'he': {'language': 'he', 'value': 'מחלת ריאות'},
#   'vi': {'language': 'vi',
#    'value': 'bệnh viêm dài hạn của đường hô hấp của phổi'},
#   'be-tarask': {'language': 'be-tarask',
#    'value': 'рэсьпіраторнае захворваньне'},
#   'sv': {'language': 'sv',
#    'value': 'långvarig sjukdom med imflammerade luftvägar'},
#   'ast': {'language': 'ast',
#    'value': "enfermedá de los bronquios que produz dificultá p'alendar"},
#   'pt': {'language': 'pt', 'value': 'Doença Inflamatória Crônica'},
#   'ms': {'language': 'ms', 'value': 'penyakit'}},
#  'aliases': {'zh': [{'language': 'zh', 'value': '氣喘'},
#    {'language': 'zh', 'value': '哮喘病'},
#    {'language': 'zh', 'value': '气喘病'},
#    {'language': 'zh', 'value': '支气管哮喘'}],
#   'pl': [{'language': 'pl', 'value': 'astma'},
#    {'language': 'pl', 'value': 'dychawica oskrzelowa'}],
#   'qu': [{'language': 'qu', 'value': 'Qarqayuy'},
#    {'language': 'qu', 'value': 'Qharqa unquy'},
#    {'language': 'qu', 'value': 'Asthma'},
#    {'language': 'qu', 'value': 'Asma'},
#    {'language': 'qu', 'value': 'Qharqaykuy'},
#    {'language': 'qu', 'value': 'Asthma bronchiale'},
#    {'language': 'qu', 'value': 'Astma'},
#    {'language': 'qu', 'value': 'Qarqaykuy'}],
#   'bs': [{'language': 'bs', 'value': 'Astmatični napad'}],
#   'es': [{'language': 'es', 'value': 'ataque de asma'},
#    {'language': 'es', 'value': 'asmático'},
#    {'language': 'es', 'value': 'asmatico'},
#    {'language': 'es', 'value': 'asma bronquial'}],
#   'ta': [{'language': 'ta', 'value': 'ஆஸ்த்துமா'},
#    {'language': 'ta', 'value': 'மூச்சுத்தடை நோய்'},
#    {'language': 'ta', 'value': 'ஈழைநோய்'}],
#   'ms': [{'language': 'ms', 'value': 'lelah'},
#    {'language': 'ms', 'value': 'penyakit asma'}],
#   'et': [{'language': 'et', 'value': 'Kopsuastma'}],
#   'ga': [{'language': 'ga', 'value': 'Múchadh'}],
#   'sv': [{'language': 'sv', 'value': 'Barnastma'}],
#   'nl': [{'language': 'nl', 'value': 'Asthma'},
#    {'language': 'nl', 'value': 'asthma bronchiale'}],
#   'pt': [{'language': 'pt', 'value': 'asma brônquica'}],
#   'is': [{'language': 'is', 'value': 'Asma'}],
#   'su': [{'language': 'su', 'value': 'Mengi'},
#    {'language': 'su', 'value': 'Ampeg'},
#    {'language': 'su', 'value': 'Bengék'}],
#   'ru': [{'language': 'ru', 'value': 'Астма бронхиальная'}],
#   'sr': [{'language': 'sr', 'value': 'Бронхијална астма'},
#    {'language': 'sr', 'value': 'Астматични напад'}],
#   'tr': [{'language': 'tr', 'value': 'yelpik'},
#    {'language': 'tr', 'value': 'kronik obstrüktif astım'}],
#   'ckb': [{'language': 'ckb', 'value': 'ڕەبۆ'}],
#   'fi': [{'language': 'fi', 'value': 'astmaatikko'},
#    {'language': 'fi', 'value': 'astmapotilas'},
#    {'language': 'fi', 'value': 'keuhkoastma'}],
#   'uk': [{'language': 'uk', 'value': 'астма'}],
#   'si': [{'language': 'si', 'value': 'Asthma'},
#    {'language': 'si', 'value': 'ඇදුම රෝගය'}],
#   'tl': [{'language': 'tl', 'value': 'Asthma episode'},
#    {'language': 'tl', 'value': 'Hikain'},
#    {'language': 'tl', 'value': 'Asmatiko'},
#    {'language': 'tl', 'value': 'Asthma'},
#    {'language': 'tl', 'value': 'Hagok'},
#    {'language': 'tl', 'value': 'Asthma attack'},
#    {'language': 'tl', 'value': 'Nakapagpapahika'},
#    {'language': 'tl', 'value': 'Sumpong ng hika'},
#    {'language': 'tl', 'value': 'Nagpapahika'},
#    {'language': 'tl', 'value': 'Asthmatic'},
#    {'language': 'tl', 'value': 'Pampahika'},
#    {'language': 'tl', 'value': 'Hingal'},
#    {'language': 'tl', 'value': 'Asthma bronchiale'}],
#   'pam': [{'language': 'pam', 'value': 'Sigasig'}],
#   'wa': [{'language': 'wa', 'value': 'Asse'}],
#   'fr': [{'language': 'fr', 'value': 'Anti-asthmatique'},
#    {'language': 'fr', 'value': "Crise d'asthme"},
#    {'language': 'fr', 'value': 'Asthmatiforme'},
#    {'language': 'fr', 'value': 'Antiasthmatique'},
#    {'language': 'fr', 'value': 'asthmatique'}],
#   'he': [{'language': 'he', 'value': 'גנחת הסימפונות'},
#    {'language': 'he', 'value': 'אסטמה'},
#    {'language': 'he', 'value': 'גנחת'},
#    {'language': 'he', 'value': 'קצרת'}],
#   'ko': [{'language': 'ko', 'value': '기관지 천식'}],
#   'lv': [{'language': 'lv', 'value': 'Astma'}],
#   'it': [{'language': 'it', 'value': 'crisi asmatica'},
#    {'language': 'it', 'value': 'asma bronchiale'}],
#   'ps': [{'language': 'ps', 'value': 'استما'}],
#   'id': [{'language': 'id', 'value': 'Sesak nafas'},
#    {'language': 'id', 'value': 'Asthma'},
#    {'language': 'id', 'value': 'Bengek'},
#    {'language': 'id', 'value': 'Astma'}],
#   'de': [{'language': 'de', 'value': 'Bronchiale Hyperreagibilität'},
#    {'language': 'de', 'value': 'Bronchialasthma'},
#    {'language': 'de', 'value': 'Asthmaanfall'},
#    {'language': 'de', 'value': 'Belastungsasthma'},
#    {'language': 'de', 'value': 'Asthma bronchiale'}],
#   'ml': [{'language': 'ml', 'value': 'ആസ്മാ'},
#    {'language': 'ml', 'value': 'ആസ്ത്മ'},
#    {'language': 'ml', 'value': 'Asthma'},
#    {'language': 'ml', 'value': 'ആസ്തമ'},
#    {'language': 'ml', 'value': 'ആസ്ത്\u200cമ'}],
#   'ja': [{'language': 'ja', 'value': '喘息'},
#    {'language': 'ja', 'value': 'ぜんそく'},
#    {'language': 'ja', 'value': 'アスピリン喘息'}],
#   'vi': [{'language': 'vi', 'value': 'suyễn'},
#    {'language': 'vi', 'value': 'bệnh suyễn'},
#    {'language': 'vi', 'value': 'hen'},
#    {'language': 'vi', 'value': 'hen suyễn'},
#    {'language': 'vi', 'value': 'bệnh hen suyễn'},
#    {'language': 'vi', 'value': 'hệnh hen'}],
#   'sa': [{'language': 'sa', 'value': 'अस्तमा'}],
#   'hi': [{'language': 'hi', 'value': 'अस्थमा'}],
#   'sk': [{'language': 'sk', 'value': 'Záduch'}],
#   'hy': [{'language': 'hy', 'value': 'Բրոնխիալ աստմա'},
#    {'language': 'hy', 'value': 'Բրոնխային հեղձուկ'}],
#   'en': [{'language': 'en', 'value': 'exercise-induced asthma'},
#    {'language': 'en', 'value': 'chronic obstructive asthma'},
#    {'language': 'en',
#     'value': 'chronic obstructive asthma with status asthmaticus'},
#    {'language': 'en',
#     'value': 'chronic obstructive asthma with acute exacerbation'},
#    {'language': 'en', 'value': 'bronchial hyperreactivity'},
#    {'language': 'en', 'value': 'Exercise induced asthma'},
#    {'language': 'en', 'value': 'Asthma'},
#    {'language': 'en', 'value': 'asthma brionchiole'}],
#   'ro': [{'language': 'ro', 'value': 'Astm bronşic'},
#    {'language': 'ro', 'value': 'Astm'},
#    {'language': 'ro', 'value': 'Astmă'},
#    {'language': 'ro', 'value': 'Astma'}],
#   'th': [{'language': 'th', 'value': 'โรคหืดหอบ'},
#    {'language': 'th', 'value': 'โรคหอบหืด'}],
#   'ca': [{'language': 'ca', 'value': 'Asmàtic'}],
#   'la': [{'language': 'la', 'value': 'Asthma'}],
#   'cy': [{'language': 'cy', 'value': 'Asma'}],
#   'sl': [{'language': 'sl', 'value': 'Naduha'}],
#   'cs': [{'language': 'cs', 'value': 'Asthma'},
#    {'language': 'cs', 'value': 'Asthma bronchiale'}],
#   'mr': [{'language': 'mr', 'value': 'रजनीश'}],
#   'te': [{'language': 'te', 'value': 'ఆస్తమా'},
#    {'language': 'te', 'value': 'ఉబ్బసం'}],
#   'ur': [{'language': 'ur', 'value': 'Asthma'},
#    {'language': 'ur', 'value': 'ایزما'},
#    {'language': 'ur', 'value': 'تضیق النفس'}],
#   'lt': [{'language': 'lt', 'value': 'Bronchinė astma'}],
#   'nb': [{'language': 'nb', 'value': 'Astmasykdom'},
#    {'language': 'nb', 'value': 'Asthma'},
#    {'language': 'nb', 'value': 'Reversibel obstruktiv luftveissjukdom'},
#    {'language': 'nb', 'value': 'Astmatiker'},
#    {'language': 'nb', 'value': 'Reversibel obstruktiv luftveissykdom'},
#    {'language': 'nb', 'value': 'Asma'},
#    {'language': 'nb', 'value': 'Reversibel obstruktiv luftvegssjukdom'},
#    {'language': 'nb', 'value': 'Asthma bronchiale'},
#    {'language': 'nb', 'value': 'Astma'}],
#   'mk': [{'language': 'mk', 'value': 'задув'}],
#   'or': [{'language': 'or', 'value': 'ଶ୍ଵାସ,ଦମା'}],
#   'hu': [{'language': 'hu', 'value': 'Asthma'}],
#   'ar': [{'language': 'ar', 'value': 'نسمة'},
#    {'language': 'ar', 'value': 'ربو'},
#    {'language': 'ar', 'value': 'أزمة'}],
#   'zh-hant': [{'language': 'zh-hant', 'value': '哮喘'}]},
#  'claims': {'P373': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P373',
#      'datavalue': {'value': 'Asthma', 'type': 'string'},
#      'datatype': 'string'},
#     'type': 'statement',
#     'id': 'q35869$6CF35AD3-56CE-45D0-93B0-FD86648388DF',
#     'rank': 'normal'}],
#   'P508': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P508',
#      'datavalue': {'value': '11749', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'q35869$903808FD-1D87-48D4-9C2C-158610445B60',
#     'rank': 'normal',
#     'references': [{'hash': 'a235ba3d92daf43853b23688674b7ab464b4eea8',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 460907,
#            'id': 'Q460907'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}]},
#       'snaks-order': ['P248']}]}],
#   'P604': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P604',
#      'datavalue': {'value': '000141', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'q35869$D126DE63-7D4D-436D-AF4A-12167C27B090',
#     'rank': 'normal',
#     'references': [{'hash': 'fa278ebfc458360e5aed63d5058cca83c46134f1',
#       'snaks': {'P143': [{'snaktype': 'value',
#          'property': 'P143',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 328,
#            'id': 'Q328'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}]},
#       'snaks-order': ['P143']}]}],
#   'P557': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P557',
#      'datavalue': {'value': '1006', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'q35869$B94DDEE8-66E3-45C3-9070-359D88904BCE',
#     'rank': 'normal',
#     'references': [{'hash': 'fa278ebfc458360e5aed63d5058cca83c46134f1',
#       'snaks': {'P143': [{'snaktype': 'value',
#          'property': 'P143',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 328,
#            'id': 'Q328'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}]},
#       'snaks-order': ['P143']}]}],
#   'P673': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P673',
#      'datavalue': {'value': '806890', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'q35869$05FA195E-DEB2-49FA-A810-4ABB02D50F56',
#     'rank': 'normal',
#     'references': [{'hash': 'fa278ebfc458360e5aed63d5058cca83c46134f1',
#       'snaks': {'P143': [{'snaktype': 'value',
#          'property': 'P143',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 328,
#            'id': 'Q328'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}]},
#       'snaks-order': ['P143']}]},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P673',
#      'datavalue': {'value': '296301', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q35869$93DC9404-25F3-430B-8C8A-5520B228DB23',
#     'rank': 'normal'}],
#   'P910': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P910',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 8272902,
#        'id': 'Q8272902'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'Q35869$480DD8A9-5F13-44BE-BBBC-1E26F11F7DA8',
#     'rank': 'normal'}],
#   'P646': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P646',
#      'datavalue': {'value': '/m/0c78m', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q35869$44BD4595-4368-44B7-BA79-35C97E81F440',
#     'rank': 'normal',
#     'references': [{'hash': '2b00cb481cddcac7623114367489b5c194901c4a',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 15241312,
#            'id': 'Q15241312'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P577': [{'snaktype': 'value',
#          'property': 'P577',
#          'datavalue': {'value': {'time': '+2013-10-28T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'snaks-order': ['P248', 'P577']}]}],
#   'P227': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P227',
#      'datavalue': {'value': '4069674-1', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q35869$D8EAEA09-6681-4EFE-857B-CB6E87DFF6DA',
#     'rank': 'normal',
#     'references': [{'hash': '9a24f7c0208b05d6be97077d855671d1dfdbc0dd',
#       'snaks': {'P143': [{'snaktype': 'value',
#          'property': 'P143',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 48183,
#            'id': 'Q48183'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}]},
#       'snaks-order': ['P143']}]}],
#   'P244': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P244',
#      'datavalue': {'value': 'sh85008860', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q35869$F709A1FA-BA29-4551-BAEE-73E1A82934D4',
#     'rank': 'normal',
#     'references': [{'hash': '9a24f7c0208b05d6be97077d855671d1dfdbc0dd',
#       'snaks': {'P143': [{'snaktype': 'value',
#          'property': 'P143',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 48183,
#            'id': 'Q48183'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}]},
#       'snaks-order': ['P143']}]}],
#   'P1461': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P1461',
#      'datavalue': {'value': 'bronchial-asthma', 'type': 'string'},
#      'datatype': 'string'},
#     'type': 'statement',
#     'id': 'Q35869$FC799FF7-DF93-40DC-BB7E-D18082466BD4',
#     'rank': 'normal',
#     'references': [{'hash': '33da6746fe2a7f54f22bcaecc5f36b5c8bbeef00',
#       'snaks': {'P854': [{'snaktype': 'value',
#          'property': 'P854',
#          'datavalue': {'value': 'http://www.patient.co.uk/patientplus/a.htm',
#           'type': 'string'},
#          'datatype': 'url'}]},
#       'snaks-order': ['P854']}]}],
#   'P1051': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P1051',
#      'datavalue': {'value': '12690', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q35869$788D01E1-DCD0-4989-90D1-386329329F56',
#     'rank': 'normal'}],
#   'P1995': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P1995',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 203337,
#        'id': 'Q203337'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'Q35869$8578570C-34B2-44B1-9ABA-DC5FB6730197',
#     'rank': 'normal'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P1995',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 101929,
#        'id': 'Q101929'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'Q35869$63d5cb30-4416-c1fd-6d33-016adb2139cf',
#     'rank': 'normal'}],
#   'P279': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P279',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 279330,
#        'id': 'Q279330'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'Q35869$96535C51-620B-47CB-BB78-85F381065385',
#     'rank': 'normal',
#     'references': [{'hash': '78415cbddf73cc30dc360eafb708557fda926901',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 5282129,
#            'id': 'Q5282129'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'datavalue': {'value': {'time': '+2021-05-10T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}],
#        'P699': [{'snaktype': 'value',
#          'property': 'P699',
#          'datavalue': {'value': 'DOID:2841', 'type': 'string'},
#          'datatype': 'external-id'}]},
#       'snaks-order': ['P248', 'P813', 'P699']}]}],
#   'P935': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P935',
#      'datavalue': {'value': 'Asthma', 'type': 'string'},
#      'datatype': 'string'},
#     'type': 'statement',
#     'id': 'Q35869$CFF92742-1C67-4E12-B3DF-35F8641EAC32',
#     'rank': 'normal'}],
#   'P667': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P667',
#      'datavalue': {'value': 'R96', 'type': 'string'},
#      'datatype': 'string'},
#     'type': 'statement',
#     'id': 'Q35869$764D740C-10E1-4C2E-A6FC-8ACBDA042D73',
#     'rank': 'normal',
#     'references': [{'hash': 'c456dc5cd2117249948c288206ff3f8b1bf574f0',
#       'snaks': {'P143': [{'snaktype': 'value',
#          'property': 'P143',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 8449,
#            'id': 'Q8449'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}]},
#       'snaks-order': ['P143']}]}],
#   'P2176': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P2176',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 637247,
#        'id': 'Q637247'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'Q35869$7EE22EA3-9D2A-41D5-A75C-C4985D914DFD',
#     'rank': 'normal',
#     'references': [{'hash': 'c95ee06bb07b8a2bb9517904e0cbf8b9fb3b9010',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 21008030,
#            'id': 'Q21008030'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P2115': [{'snaktype': 'value',
#          'property': 'P2115',
#          'datavalue': {'value': 'N0000148706', 'type': 'string'},
#          'datatype': 'external-id'}],
#        'P407': [{'snaktype': 'value',
#          'property': 'P407',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 1860,
#            'id': 'Q1860'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'datavalue': {'value': {'time': '+2016-12-13T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'snaks-order': ['P248', 'P2115', 'P407', 'P813']}]},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P2176',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 1087499,
#        'id': 'Q1087499'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'Q35869$819FB6E7-BDBA-445D-B190-962C98366DAF',
#     'rank': 'normal',
#     'references': [{'hash': '1ca35ce643ddd7f451a23aa2a64894866b852dad',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 21008030,
#            'id': 'Q21008030'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P2115': [{'snaktype': 'value',
#          'property': 'P2115',
#          'datavalue': {'value': 'N0000146829', 'type': 'string'},
#          'datatype': 'external-id'}],
#        'P407': [{'snaktype': 'value',
#          'property': 'P407',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 1860,
#            'id': 'Q1860'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'datavalue': {'value': {'time': '+2016-12-13T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'snaks-order': ['P248', 'P2115', 'P407', 'P813']}]},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P2176',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 928378,
#        'id': 'Q928378'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'Q35869$061C5DE0-1A41-4E7B-84C5-6AB2786F10D3',
#     'rank': 'normal',
#     'references': [{'hash': '573e91bca684803b2f2f6e6e888ee7ed9dd76d0a',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 21008030,
#            'id': 'Q21008030'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P2115': [{'snaktype': 'value',
#          'property': 'P2115',
#          'datavalue': {'value': 'N0000148457', 'type': 'string'},
#          'datatype': 'external-id'}],
#        'P407': [{'snaktype': 'value',
#          'property': 'P407',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 1860,
#            'id': 'Q1860'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'datavalue': {'value': {'time': '+2016-12-13T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'snaks-order': ['P248', 'P2115', 'P407', 'P813']}]},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P2176',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 5104342,
#        'id': 'Q5104342'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'Q35869$69338C5D-341B-4A2F-978F-EA4499474647',
#     'rank': 'normal',
#     'references': [{'hash': '3dba56ea3698cab6315b8e0e10c4f8b6fb5baeed',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 21008030,
#            'id': 'Q21008030'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P2115': [{'snaktype': 'value',
#          'property': 'P2115',
#          'datavalue': {'value': 'N0000146943', 'type': 'string'},
#          'datatype': 'external-id'}],
#        'P407': [{'snaktype': 'value',
#          'property': 'P407',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 1860,
#            'id': 'Q1860'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'datavalue': {'value': {'time': '+2016-12-13T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'snaks-order': ['P248', 'P2115', 'P407', 'P813']}]},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P2176',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 410358,
#        'id': 'Q410358'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'Q35869$D34CA002-4102-4B5E-B3C5-FB46EACE0AA5',
#     'rank': 'normal',
#     'references': [{'hash': 'db15b3ccb457eac7392ed0ba63eab2af178d2391',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 21008030,
#            'id': 'Q21008030'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P2115': [{'snaktype': 'value',
#          'property': 'P2115',
#          'datavalue': {'value': 'N0000147099', 'type': 'string'},
#          'datatype': 'external-id'}],
#        'P407': [{'snaktype': 'value',
#          'property': 'P407',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 1860,
#            'id': 'Q1860'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'datavalue': {'value': {'time': '+2016-12-13T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'snaks-order': ['P248', 'P2115', 'P407', 'P813']}]},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P2176',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 32921,
#        'id': 'Q32921'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'Q35869$CECEB4CA-1B9F-4F6B-A029-FEF9A2FEC197',
#     'rank': 'normal',
#     'references': [{'hash': 'e1f6d23d455fd543036c662b142ee64639cc0ec8',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 21008030,
#            'id': 'Q21008030'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P2115': [{'snaktype': 'value',
#          'property': 'P2115',
#          'datavalue': {'value': 'N0000146821', 'type': 'string'},
#          'datatype': 'external-id'}],
#        'P407': [{'snaktype': 'value',
#          'property': 'P407',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 1860,
#            'id': 'Q1860'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'datavalue': {'value': {'time': '+2016-12-13T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'snaks-order': ['P248', 'P2115', 'P407', 'P813']}]},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P2176',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 424340,
#        'id': 'Q424340'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'Q35869$2A3A9502-1668-4CA9-8E49-D1759CEA408D',
#     'rank': 'normal',
#     'references': [{'hash': '3bcd1d57f42af8a9efe7165461bf303d978bad71',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 21008030,
#            'id': 'Q21008030'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P2115': [{'snaktype': 'value',
#          'property': 'P2115',
#          'datavalue': {'value': 'N0000148026', 'type': 'string'},
#          'datatype': 'external-id'}],
#        'P407': [{'snaktype': 'value',
#          'property': 'P407',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 1860,
#            'id': 'Q1860'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'datavalue': {'value': {'time': '+2016-12-13T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'snaks-order': ['P248', 'P2115', 'P407', 'P813']}]},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P2176',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 471763,
#        'id': 'Q471763'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'Q35869$77963393-C8EE-43D0-A5A1-C6CF588FE521',
#     'rank': 'normal',
#     'references': [{'hash': '82671483e4551650f8bb4dbc947401a0ef558def',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 21008030,
#            'id': 'Q21008030'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P2115': [{'snaktype': 'value',
#          'property': 'P2115',
#          'datavalue': {'value': 'N0000146397', 'type': 'string'},
#          'datatype': 'external-id'}],
#        'P407': [{'snaktype': 'value',
#          'property': 'P407',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 1860,
#            'id': 'Q1860'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'datavalue': {'value': {'time': '+2016-12-13T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'snaks-order': ['P248', 'P2115', 'P407', 'P813']}]},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P2176',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 4918914,
#        'id': 'Q4918914'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'Q35869$B1FF221D-9B9A-436A-8F8B-F8A713A0AA63',
#     'rank': 'normal',
#     'references': [{'hash': '9b4bc0d76abd55ed72c516eb12d5f526b96069d9',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 21008030,
#            'id': 'Q21008030'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P2115': [{'snaktype': 'value',
#          'property': 'P2115',
#          'datavalue': {'value': 'N0000147729', 'type': 'string'},
#          'datatype': 'external-id'}],
#        'P407': [{'snaktype': 'value',
#          'property': 'P407',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 1860,
#            'id': 'Q1860'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'datavalue': {'value': {'time': '+2016-12-13T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'snaks-order': ['P248', 'P2115', 'P407', 'P813']}]},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P2176',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 219626,
#        'id': 'Q219626'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'Q35869$45AF4723-D0E0-4282-A431-8EAFC0CADADD',
#     'rank': 'normal',
#     'references': [{'hash': '4afc129b651ed53af509d404de397346d9ef4f4f',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 21008030,
#            'id': 'Q21008030'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P2115': [{'snaktype': 'value',
#          'property': 'P2115',
#          'datavalue': {'value': 'N0000147478', 'type': 'string'},
#          'datatype': 'external-id'}],
#        'P407': [{'snaktype': 'value',
#          'property': 'P407',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 1860,
#            'id': 'Q1860'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'datavalue': {'value': {'time': '+2016-12-13T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'snaks-order': ['P248', 'P2115', 'P407', 'P813']}]},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P2176',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 417767,
#        'id': 'Q417767'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'Q35869$2C9FDCB3-DE1A-47BC-8836-D010AD0E9C42',
#     'rank': 'normal',
#     'references': [{'hash': 'c864c34a1f7a8a45911d227f94981a4962045360',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 21008030,
#            'id': 'Q21008030'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P2115': [{'snaktype': 'value',
#          'property': 'P2115',
#          'datavalue': {'value': 'N0000022122', 'type': 'string'},
#          'datatype': 'external-id'}],
#        'P407': [{'snaktype': 'value',
#          'property': 'P407',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 1860,
#            'id': 'Q1860'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'datavalue': {'value': {'time': '+2016-12-13T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'snaks-order': ['P248', 'P2115', 'P407', 'P813']}]},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P2176',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 424333,
#        'id': 'Q424333'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'Q35869$9FBA9301-18FB-4DC2-8508-F8E13189C413',
#     'rank': 'normal',
#     'references': [{'hash': '8b87ffeccb83a6ab179494faafd1afc773b1fcee',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 21008030,
#            'id': 'Q21008030'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P2115': [{'snaktype': 'value',
#          'property': 'P2115',
#          'datavalue': {'value': 'N0000021960', 'type': 'string'},
#          'datatype': 'external-id'}],
#        'P407': [{'snaktype': 'value',
#          'property': 'P407',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 1860,
#            'id': 'Q1860'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'datavalue': {'value': {'time': '+2016-12-13T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'snaks-order': ['P248', 'P2115', 'P407', 'P813']}]},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P2176',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 202998,
#        'id': 'Q202998'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'Q35869$F22C6F49-216C-4753-8C00-D98F3CEA9589',
#     'rank': 'normal',
#     'references': [{'hash': 'e4a6c4e4308701b11dd053626298a4f731f378ba',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 21008030,
#            'id': 'Q21008030'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P2115': [{'snaktype': 'value',
#          'property': 'P2115',
#          'datavalue': {'value': 'N0000148478', 'type': 'string'},
#          'datatype': 'external-id'}],
#        'P407': [{'snaktype': 'value',
#          'property': 'P407',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 1860,
#            'id': 'Q1860'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'datavalue': {'value': {'time': '+2016-12-13T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'snaks-order': ['P248', 'P2115', 'P407', 'P813']}]},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P2176',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 1236526,
#        'id': 'Q1236526'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'Q35869$A7BAF18A-C671-48A8-8E3B-1B5D95944599',
#     'rank': 'normal',
#     'references': [{'hash': '778b4302b1904aae81e44ccd24dabdaeaa926c6e',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 21008030,
#            'id': 'Q21008030'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P2115': [{'snaktype': 'value',
#          'property': 'P2115',
#          'datavalue': {'value': 'N0000147983', 'type': 'string'},
#          'datatype': 'external-id'}],
#        'P407': [{'snaktype': 'value',
#          'property': 'P407',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 1860,
#            'id': 'Q1860'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'datavalue': {'value': {'time': '+2016-12-13T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'snaks-order': ['P248', 'P2115', 'P407', 'P813']}]},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P2176',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 407308,
#        'id': 'Q407308'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'Q35869$FCDDFFD2-5BDF-478F-A55D-F56FC5F1D5C7',
#     'rank': 'normal',
#     'references': [{'hash': '2d8e526bcb66cde30dfd97310772888162ab425a',
#       'snaks': {'P248': [{'snaktype': 'value',
# ...
#     'rank': 'normal'}]},
#  'sitelinks': {'afwiki': {'site': 'afwiki',
#    'title': 'Asma',
#    'badges': [],
#    'url': 'https://af.wikipedia.org/wiki/Asma'},
#   'arwiki': {'site': 'arwiki',
#    'title': 'ربو',
#    'badges': ['Q17437796'],
#    'url': 'https://ar.wikipedia.org/wiki/%D8%B1%D8%A8%D9%88'},
#   'arzwiki': {'site': 'arzwiki',
#    'title': 'ربو',
#    'badges': [],
#    'url': 'https://arz.wikipedia.org/wiki/%D8%B1%D8%A8%D9%88'},
#   'astwiki': {'site': 'astwiki',
#    'title': 'Asma',
#    'badges': [],
#    'url': 'https://ast.wikipedia.org/wiki/Asma'},
#   'awawiki': {'site': 'awawiki',
#    'title': 'दमा',
#    'badges': [],
#    'url': 'https://awa.wikipedia.org/wiki/%E0%A4%A6%E0%A4%AE%E0%A4%BE'},
#   'azwiki': {'site': 'azwiki',
#    'title': 'Bronxial astma',
#    'badges': [],
#    'url': 'https://az.wikipedia.org/wiki/Bronxial_astma'},
#   'barwiki': {'site': 'barwiki',
#    'title': 'Asthma',
#    'badges': [],
#    'url': 'https://bar.wikipedia.org/wiki/Asthma'},
#   'bclwiki': {'site': 'bclwiki',
#    'title': 'Hapo',
#    'badges': [],
#    'url': 'https://bcl.wikipedia.org/wiki/Hapo'},
#   'bgwiki': {'site': 'bgwiki',
#    'title': 'Астма',
#    'badges': [],
#    'url': 'https://bg.wikipedia.org/wiki/%D0%90%D1%81%D1%82%D0%BC%D0%B0'},
#   'bjnwiki': {'site': 'bjnwiki',
#    'title': 'Manggah',
#    'badges': [],
#    'url': 'https://bjn.wikipedia.org/wiki/Manggah'},
#   'bnwiki': {'site': 'bnwiki',
#    'title': 'হাঁপানি',
#    'badges': [],
#    'url': 'https://bn.wikipedia.org/wiki/%E0%A6%B9%E0%A6%BE%E0%A6%81%E0%A6%AA%E0%A6%BE%E0%A6%A8%E0%A6%BF'},
#   'bowiki': {'site': 'bowiki',
#    'title': 'དབུགས་མི་བདེ་བའི་ནད་',
#    'badges': [],
#    'url': 'https://bo.wikipedia.org/wiki/%E0%BD%91%E0%BD%96%E0%BD%B4%E0%BD%82%E0%BD%A6%E0%BC%8B%E0%BD%98%E0%BD%B2%E0%BC%8B%E0%BD%96%E0%BD%91%E0%BD%BA%E0%BC%8B%E0%BD%96%E0%BD%A0%E0%BD%B2%E0%BC%8B%E0%BD%93%E0%BD%91%E0%BC%8B'},
#   'bswiki': {'site': 'bswiki',
#    'title': 'Bronhijalna astma',
#    'badges': [],
#    'url': 'https://bs.wikipedia.org/wiki/Bronhijalna_astma'},
#   'cawiki': {'site': 'cawiki',
#    'title': 'Asma',
#    'badges': [],
#    'url': 'https://ca.wikipedia.org/wiki/Asma'},
#   'cdowiki': {'site': 'cdowiki',
#    'title': 'Hău-chuāng',
#    'badges': [],
#    'url': 'https://cdo.wikipedia.org/wiki/H%C4%83u-chu%C4%81ng'},
#   'cebwiki': {'site': 'cebwiki',
#    'title': 'Hubak',
#    'badges': [],
#    'url': 'https://ceb.wikipedia.org/wiki/Hubak'},
#   'chrwiki': {'site': 'chrwiki',
#    'title': 'ᎤᎭᏬᏍᏗᏍᎩ',
#    'badges': [],
#    'url': 'https://chr.wikipedia.org/wiki/%E1%8E%A4%E1%8E%AD%E1%8F%AC%E1%8F%8D%E1%8F%97%E1%8F%8D%E1%8E%A9'},
#   'ckbwiki': {'site': 'ckbwiki',
#    'title': 'ئاسم',
#    'badges': [],
#    'url': 'https://ckb.wikipedia.org/wiki/%D8%A6%D8%A7%D8%B3%D9%85'},
#   'commonswiki': {'site': 'commonswiki',
#    'title': 'Asthma',
#    'badges': [],
#    'url': 'https://commons.wikimedia.org/wiki/Asthma'},
#   'cswiki': {'site': 'cswiki',
#    'title': 'Astma',
#    'badges': [],
#    'url': 'https://cs.wikipedia.org/wiki/Astma'},
#   'cywiki': {'site': 'cywiki',
#    'title': 'Asthma',
#    'badges': [],
#    'url': 'https://cy.wikipedia.org/wiki/Asthma'},
#   'dawiki': {'site': 'dawiki',
#    'title': 'Astma',
#    'badges': ['Q17559452'],
#    'url': 'https://da.wikipedia.org/wiki/Astma'},
#   'dewiki': {'site': 'dewiki',
#    'title': 'Asthma bronchiale',
#    'badges': [],
#    'url': 'https://de.wikipedia.org/wiki/Asthma_bronchiale'},
#   'elwiki': {'site': 'elwiki',
#    'title': 'Άσθμα',
#    'badges': [],
#    'url': 'https://el.wikipedia.org/wiki/%CE%86%CF%83%CE%B8%CE%BC%CE%B1'},
#   'enwiki': {'site': 'enwiki',
#    'title': 'Asthma',
#    'badges': ['Q17437798'],
#    'url': 'https://en.wikipedia.org/wiki/Asthma'},
#   'eowiki': {'site': 'eowiki',
#    'title': 'Astmo',
#    'badges': [],
#    'url': 'https://eo.wikipedia.org/wiki/Astmo'},
#   'eswiki': {'site': 'eswiki',
#    'title': 'Asma',
#    'badges': [],
#    'url': 'https://es.wikipedia.org/wiki/Asma'},
#   'etwiki': {'site': 'etwiki',
#    'title': 'Bronhiaalastma',
#    'badges': [],
#    'url': 'https://et.wikipedia.org/wiki/Bronhiaalastma'},
#   'etwikiquote': {'site': 'etwikiquote',
#    'title': 'Astma',
#    'badges': [],
#    'url': 'https://et.wikiquote.org/wiki/Astma'},
#   'euwiki': {'site': 'euwiki',
#    'title': 'Asma',
#    'badges': [],
#    'url': 'https://eu.wikipedia.org/wiki/Asma'},
#   'fawiki': {'site': 'fawiki',
#    'title': 'آسم',
#    'badges': [],
#    'url': 'https://fa.wikipedia.org/wiki/%D8%A2%D8%B3%D9%85'},
#   'fiwiki': {'site': 'fiwiki',
#    'title': 'Astma',
#    'badges': [],
#    'url': 'https://fi.wikipedia.org/wiki/Astma'},
#   'frwiki': {'site': 'frwiki',
#    'title': 'Asthme',
#    'badges': [],
#    'url': 'https://fr.wikipedia.org/wiki/Asthme'},
#   'gawiki': {'site': 'gawiki',
#    'title': 'Asma',
#    'badges': [],
#    'url': 'https://ga.wikipedia.org/wiki/Asma'},
#   'gcrwiki': {'site': 'gcrwiki',
#    'title': 'Asm',
#    'badges': [],
#    'url': 'https://gcr.wikipedia.org/wiki/Asm'},
#   'glwiki': {'site': 'glwiki',
#    'title': 'Asma (doenza)',
#    'badges': [],
#    'url': 'https://gl.wikipedia.org/wiki/Asma_(doenza)'},
#   'guwiki': {'site': 'guwiki',
#    'title': 'અસ્થમા',
#    'badges': [],
#    'url': 'https://gu.wikipedia.org/wiki/%E0%AA%85%E0%AA%B8%E0%AB%8D%E0%AA%A5%E0%AA%AE%E0%AA%BE'},
#   'hakwiki': {'site': 'hakwiki',
#    'title': 'Pông-hâ',
#    'badges': [],
#    'url': 'https://hak.wikipedia.org/wiki/P%C3%B4ng-h%C3%A2'},
#   'hewiki': {'site': 'hewiki',
#    'title': 'אסתמה',
#    'badges': [],
#    'url': 'https://he.wikipedia.org/wiki/%D7%90%D7%A1%D7%AA%D7%9E%D7%94'},
#   'hiwiki': {'site': 'hiwiki',
#    'title': 'दमा',
#    'badges': [],
#    'url': 'https://hi.wikipedia.org/wiki/%E0%A4%A6%E0%A4%AE%E0%A4%BE'},
#   'hrwiki': {'site': 'hrwiki',
#    'title': 'Astma',
#    'badges': ['Q17437796'],
#    'url': 'https://hr.wikipedia.org/wiki/Astma'},
#   'htwiki': {'site': 'htwiki',
#    'title': 'Las (maladi)',
#    'badges': [],
#    'url': 'https://ht.wikipedia.org/wiki/Las_(maladi)'},
#   'huwiki': {'site': 'huwiki',
#    'title': 'Asztma',
#    'badges': ['Q17437798'],
#    'url': 'https://hu.wikipedia.org/wiki/Asztma'},
#   'hywiki': {'site': 'hywiki',
#    'title': 'Բրոնխիալ ասթմա',
#    'badges': [],
#    'url': 'https://hy.wikipedia.org/wiki/%D4%B2%D6%80%D5%B8%D5%B6%D5%AD%D5%AB%D5%A1%D5%AC_%D5%A1%D5%BD%D5%A9%D5%B4%D5%A1'},
#   'hywwiki': {'site': 'hywwiki',
#    'title': 'Շնչարգելք',
#    'badges': [],
#    'url': 'https://hyw.wikipedia.org/wiki/%D5%87%D5%B6%D5%B9%D5%A1%D6%80%D5%A3%D5%A5%D5%AC%D6%84'},
#   'iawiki': {'site': 'iawiki',
#    'title': 'Asthma',
#    'badges': [],
#    'url': 'https://ia.wikipedia.org/wiki/Asthma'},
#   'idwiki': {'site': 'idwiki',
#    'title': 'Asma',
#    'badges': [],
#    'url': 'https://id.wikipedia.org/wiki/Asma'},
#   'iowiki': {'site': 'iowiki',
#    'title': 'Astmo',
#    'badges': [],
#    'url': 'https://io.wikipedia.org/wiki/Astmo'},
#   'iswiki': {'site': 'iswiki',
#    'title': 'Astmi',
#    'badges': [],
#    'url': 'https://is.wikipedia.org/wiki/Astmi'},
#   'itwiki': {'site': 'itwiki',
#    'title': 'Asma',
#    'badges': [],
#    'url': 'https://it.wikipedia.org/wiki/Asma'},
#   'itwikiquote': {'site': 'itwikiquote',
#    'title': 'Asma',
#    'badges': [],
#    'url': 'https://it.wikiquote.org/wiki/Asma'},
#   'jawiki': {'site': 'jawiki',
#    'title': '気管支喘息',
#    'badges': [],
#    'url': 'https://ja.wikipedia.org/wiki/%E6%B0%97%E7%AE%A1%E6%94%AF%E5%96%98%E6%81%AF'},
#   'jvwiki': {'site': 'jvwiki',
#    'title': 'Mengi',
#    'badges': [],
#    'url': 'https://jv.wikipedia.org/wiki/Mengi'},
#   'kabwiki': {'site': 'kabwiki',
#    'title': 'Aneggaf',
#    'badges': [],
#    'url': 'https://kab.wikipedia.org/wiki/Aneggaf'},
#   'kawiki': {'site': 'kawiki',
#    'title': 'ბრონქული ასთმა',
#    'badges': [],
#    'url': 'https://ka.wikipedia.org/wiki/%E1%83%91%E1%83%A0%E1%83%9D%E1%83%9C%E1%83%A5%E1%83%A3%E1%83%9A%E1%83%98_%E1%83%90%E1%83%A1%E1%83%97%E1%83%9B%E1%83%90'},
#   'kkwiki': {'site': 'kkwiki',
#    'title': 'Бронхтық демікпе',
#    'badges': [],
#    'url': 'https://kk.wikipedia.org/wiki/%D0%91%D1%80%D0%BE%D0%BD%D1%85%D1%82%D1%8B%D2%9B_%D0%B4%D0%B5%D0%BC%D1%96%D0%BA%D0%BF%D0%B5'},
#   'knwiki': {'site': 'knwiki',
#    'title': 'ಗೂರಲು',
#    'badges': [],
#    'url': 'https://kn.wikipedia.org/wiki/%E0%B2%97%E0%B3%82%E0%B2%B0%E0%B2%B2%E0%B3%81'},
#   'kowiki': {'site': 'kowiki',
#    'title': '천식',
#    'badges': [],
#    'url': 'https://ko.wikipedia.org/wiki/%EC%B2%9C%EC%8B%9D'},
#   'kywiki': {'site': 'kywiki',
#    'title': 'Бронх астмасы',
#    'badges': [],
#    'url': 'https://ky.wikipedia.org/wiki/%D0%91%D1%80%D0%BE%D0%BD%D1%85_%D0%B0%D1%81%D1%82%D0%BC%D0%B0%D1%81%D1%8B'},
#   'lawiki': {'site': 'lawiki',
#    'title': 'Asthma bronchiale',
#    'badges': [],
#    'url': 'https://la.wikipedia.org/wiki/Asthma_bronchiale'},
#   'ltwiki': {'site': 'ltwiki',
#    'title': 'Astma',
#    'badges': [],
#    'url': 'https://lt.wikipedia.org/wiki/Astma'},
#   'lvwiki': {'site': 'lvwiki',
#    'title': 'Bronhiālā astma',
#    'badges': [],
#    'url': 'https://lv.wikipedia.org/wiki/Bronhi%C4%81l%C4%81_astma'},
#   'mkwiki': {'site': 'mkwiki',
#    'title': 'Астма',
#    'badges': [],
#    'url': 'https://mk.wikipedia.org/wiki/%D0%90%D1%81%D1%82%D0%BC%D0%B0'},
#   'mlwiki': {'site': 'mlwiki',
#    'title': 'ആസ്മ',
#    'badges': ['Q17437796'],
#    'url': 'https://ml.wikipedia.org/wiki/%E0%B4%86%E0%B4%B8%E0%B5%8D%E0%B4%AE'},
#   'mrwiki': {'site': 'mrwiki',
#    'title': 'दमा',
#    'badges': [],
#    'url': 'https://mr.wikipedia.org/wiki/%E0%A4%A6%E0%A4%AE%E0%A4%BE'},
#   'mswiki': {'site': 'mswiki',
#    'title': 'Penyakit asma',
#    'badges': [],
#    'url': 'https://ms.wikipedia.org/wiki/Penyakit_asma'},
#   'newiki': {'site': 'newiki',
#    'title': 'दम',
#    'badges': [],
#    'url': 'https://ne.wikipedia.org/wiki/%E0%A4%A6%E0%A4%AE'},
#   'newwiki': {'site': 'newwiki',
#    'title': 'आज्मा',
#    'badges': [],
#    'url': 'https://new.wikipedia.org/wiki/%E0%A4%86%E0%A4%9C%E0%A5%8D%E0%A4%AE%E0%A4%BE'},
#   'nlwiki': {'site': 'nlwiki',
#    'title': 'Astma',
#    'badges': [],
#    'url': 'https://nl.wikipedia.org/wiki/Astma'},
#   'nnwiki': {'site': 'nnwiki',
#    'title': 'Astma',
#    'badges': [],
#    'url': 'https://nn.wikipedia.org/wiki/Astma'},
#   'nowiki': {'site': 'nowiki',
#    'title': 'Astma',
#    'badges': [],
#    'url': 'https://no.wikipedia.org/wiki/Astma'},
#   'ocwiki': {'site': 'ocwiki',
#    'title': 'Asma',
#    'badges': [],
#    'url': 'https://oc.wikipedia.org/wiki/Asma'},
#   'orwiki': {'site': 'orwiki',
#    'title': 'ଆଜ୍\u200cମା',
#    'badges': [],
#    'url': 'https://or.wikipedia.org/wiki/%E0%AC%86%E0%AC%9C%E0%AD%8D%E2%80%8C%E0%AC%AE%E0%AC%BE'},
#   'pamwiki': {'site': 'pamwiki',
#    'title': 'Mausang',
#    'badges': [],
#    'url': 'https://pam.wikipedia.org/wiki/Mausang'},
#   'pawiki': {'site': 'pawiki',
#    'title': 'ਦਮਾ',
#    'badges': [],
#    'url': 'https://pa.wikipedia.org/wiki/%E0%A8%A6%E0%A8%AE%E0%A8%BE'},
#   'plwiki': {'site': 'plwiki',
#    'title': 'Astma oskrzelowa',
#    'badges': ['Q17437798'],
#    'url': 'https://pl.wikipedia.org/wiki/Astma_oskrzelowa'},
#   'pswiki': {'site': 'pswiki',
#    'title': 'سابندي',
#    'badges': [],
#    'url': 'https://ps.wikipedia.org/wiki/%D8%B3%D8%A7%D8%A8%D9%86%D8%AF%D9%8A'},
#   'ptwiki': {'site': 'ptwiki',
#    'title': 'Asma',
#    'badges': ['Q17437796'],
#    'url': 'https://pt.wikipedia.org/wiki/Asma'},
#   'quwiki': {'site': 'quwiki',
#    'title': 'Qharqayuy',
#    'badges': [],
#    'url': 'https://qu.wikipedia.org/wiki/Qharqayuy'},
#   'rowiki': {'site': 'rowiki',
#    'title': 'Astm bronșic',
#    'badges': ['Q17437798'],
#    'url': 'https://ro.wikipedia.org/wiki/Astm_bron%C8%99ic'},
#   'ruwiki': {'site': 'ruwiki',
#    'title': 'Бронхиальная астма',
#    'badges': ['Q17437796'],
#    'url': 'https://ru.wikipedia.org/wiki/%D0%91%D1%80%D0%BE%D0%BD%D1%85%D0%B8%D0%B0%D0%BB%D1%8C%D0%BD%D0%B0%D1%8F_%D0%B0%D1%81%D1%82%D0%BC%D0%B0'},
#   'sahwiki': {'site': 'sahwiki',
#    'title': 'Бронха астмата',
#    'badges': [],
#    'url': 'https://sah.wikipedia.org/wiki/%D0%91%D1%80%D0%BE%D0%BD%D1%85%D0%B0_%D0%B0%D1%81%D1%82%D0%BC%D0%B0%D1%82%D0%B0'},
#   'sawiki': {'site': 'sawiki',
#    'title': 'श्वासरोगः',
#    'badges': [],
#    'url': 'https://sa.wikipedia.org/wiki/%E0%A4%B6%E0%A5%8D%E0%A4%B5%E0%A4%BE%E0%A4%B8%E0%A4%B0%E0%A5%8B%E0%A4%97%E0%A4%83'},
#   'sdwiki': {'site': 'sdwiki',
#    'title': 'دم (بيماري)',
#    'badges': [],
#    'url': 'https://sd.wikipedia.org/wiki/%D8%AF%D9%85_(%D8%A8%D9%8A%D9%85%D8%A7%D8%B1%D9%8A)'},
#   'sewiki': {'site': 'sewiki',
#    'title': 'Ástmá',
#    'badges': [],
#    'url': 'https://se.wikipedia.org/wiki/%C3%81stm%C3%A1'},
#   'shwiki': {'site': 'shwiki',
#    'title': 'Astma',
#    'badges': [],
#    'url': 'https://sh.wikipedia.org/wiki/Astma'},
#   'simplewiki': {'site': 'simplewiki',
#    'title': 'Asthma',
#    'badges': [],
#    'url': 'https://simple.wikipedia.org/wiki/Asthma'},
#   'siwiki': {'site': 'siwiki',
#    'title': 'ඇදුම',
#    'badges': [],
#    'url': 'https://si.wikipedia.org/wiki/%E0%B6%87%E0%B6%AF%E0%B7%94%E0%B6%B8'},
#   'skwiki': {'site': 'skwiki',
#    'title': 'Astma',
#    'badges': [],
#    'url': 'https://sk.wikipedia.org/wiki/Astma'},
#   'slwiki': {'site': 'slwiki',
#    'title': 'Astma',
#    'badges': [],
#    'url': 'https://sl.wikipedia.org/wiki/Astma'},
#   'sowiki': {'site': 'sowiki',
#    'title': 'Neefta',
#    'badges': [],
#    'url': 'https://so.wikipedia.org/wiki/Neefta'},
#   'srwiki': {'site': 'srwiki',
#    'title': 'Астма',
#    'badges': [],
#    'url': 'https://sr.wikipedia.org/wiki/%D0%90%D1%81%D1%82%D0%BC%D0%B0'},
#   'suwiki': {'site': 'suwiki',
#    'title': 'Asma',
#    'badges': [],
#    'url': 'https://su.wikipedia.org/wiki/Asma'},
#   'svwiki': {'site': 'svwiki',
#    'title': 'Astma',
#    'badges': [],
#    'url': 'https://sv.wikipedia.org/wiki/Astma'},
#   'swwiki': {'site': 'swwiki',
#    'title': 'Pumu',
#    'badges': [],
#    'url': 'https://sw.wikipedia.org/wiki/Pumu'},
#   'tawiki': {'site': 'tawiki',
#    'title': 'ஈழை நோய்',
#    'badges': [],
#    'url': 'https://ta.wikipedia.org/wiki/%E0%AE%88%E0%AE%B4%E0%AF%88_%E0%AE%A8%E0%AF%8B%E0%AE%AF%E0%AF%8D'},
#   'tewiki': {'site': 'tewiki',
#    'title': 'ఉబ్బసము',
#    'badges': [],
#    'url': 'https://te.wikipedia.org/wiki/%E0%B0%89%E0%B0%AC%E0%B1%8D%E0%B0%AC%E0%B0%B8%E0%B0%AE%E0%B1%81'},
#   'thwiki': {'site': 'thwiki',
#    'title': 'โรคหืด',
#    'badges': [],
#    'url': 'https://th.wikipedia.org/wiki/%E0%B9%82%E0%B8%A3%E0%B8%84%E0%B8%AB%E0%B8%B7%E0%B8%94'},
#   'tkwiki': {'site': 'tkwiki',
#    'title': 'Bronhial astma',
#    'badges': [],
#    'url': 'https://tk.wikipedia.org/wiki/Bronhial_astma'},
#   'tlwiki': {'site': 'tlwiki',
#    'title': 'Hika',
#    'badges': [],
#    'url': 'https://tl.wikipedia.org/wiki/Hika'},
#   'trwiki': {'site': 'trwiki',
#    'title': 'Astım',
#    'badges': [],
#    'url': 'https://tr.wikipedia.org/wiki/Ast%C4%B1m'},
#   'ukwiki': {'site': 'ukwiki',
#    'title': 'Бронхіальна астма',
#    'badges': [],
#    'url': 'https://uk.wikipedia.org/wiki/%D0%91%D1%80%D0%BE%D0%BD%D1%85%D1%96%D0%B0%D0%BB%D1%8C%D0%BD%D0%B0_%D0%B0%D1%81%D1%82%D0%BC%D0%B0'},
#   'urwiki': {'site': 'urwiki',
#    'title': 'دمہ',
#    'badges': [],
#    'url': 'https://ur.wikipedia.org/wiki/%D8%AF%D9%85%DB%81'},
#   'uzwiki': {'site': 'uzwiki',
#    'title': 'Bronxial astma',
#    'badges': [],
#    'url': 'https://uz.wikipedia.org/wiki/Bronxial_astma'},
#   'viwiki': {'site': 'viwiki',
#    'title': 'Hen phế quản',
#    'badges': [],
#    'url': 'https://vi.wikipedia.org/wiki/Hen_ph%E1%BA%BF_qu%E1%BA%A3n'},
#   'warwiki': {'site': 'warwiki',
#    'title': 'Hika',
#    'badges': [],
#    'url': 'https://war.wikipedia.org/wiki/Hika'},
#   'wawiki': {'site': 'wawiki',
#    'title': "Coûtresse d' alinne",
#    'badges': [],
#    'url': 'https://wa.wikipedia.org/wiki/Co%C3%BBtresse_d%27_alinne'},
#   'wuuwiki': {'site': 'wuuwiki',
#    'title': '哮喘',
#    'badges': [],
#    'url': 'https://wuu.wikipedia.org/wiki/%E5%93%AE%E5%96%98'},
#   'zawiki': {'site': 'zawiki',
#    'title': 'Haebgyawh',
#    'badges': [],
#    'url': 'https://za.wikipedia.org/wiki/Haebgyawh'},
#   'zh_min_nanwiki': {'site': 'zh_min_nanwiki',
#    'title': 'He-ku',
#    'badges': [],
#    'url': 'https://zh-min-nan.wikipedia.org/wiki/He-ku'},
#   'zh_yuewiki': {'site': 'zh_yuewiki',
#    'title': '哮喘',
#    'badges': [],
#    'url': 'https://zh-yue.wikipedia.org/wiki/%E5%93%AE%E5%96%98'},
#   'zhwiki': {'site': 'zhwiki',
#    'title': '哮喘',
#    'badges': [],
#    'url': 'https://zh.wikipedia.org/wiki/%E5%93%AE%E5%96%98'}}}

# %%
json_item2 == json_item
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-3331274af02b> in <module>
# ----> 1 json_item2 == json_item
#
# NameError: name 'json_item2' is not defined

# %%
value = { k : json_item2["claims"][k] for k in set(json_item2["claims"]) - set(json_item["claims"]) }

# %%
value

# %%
wdi_config.property_value_types
